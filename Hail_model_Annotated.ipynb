# %% [markdown]
# # Hail Model Notebook
#
# The hail model notebook performed rudimentary feature engineering from the cleaned dataset before submission to Darwin for automatic processing. The order of operations was:
#
# 1) Import Data and Libraries
#
# 2) Feature Engineering
#
# 3) Uploading and Cleaning the data in Darwin
#
# 4) Training a Model in Darwin
#
# 5) Analyzing the Model in Darwin
#
# 6) Testing a model with Darwin
#
# 7) Analyzing the model using the results of the test data

# %% [markdown]
# ## Import Data and Libraries
#
# Import the required libraries, start the darwin session, and upload the dataset from the cwd.

# %%
import pandas as pd
import datetime
from datetime import timedelta
import numpy as np
import sklearn.metrics

#displays all datasets' columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)


from amb_sdk.sdk import DarwinSdk
s = DarwinSdk()
s.set_url('https://amb-demo-api.sparkcognition.com/v1/')
s.auth_login_user('--User Name--','--Password--')
# Out:
# (True,
#  'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJleHAiOjE1NTYwODQwOTMsImlhdCI6MTU1NjA3Njg5MywibmJmIjoxNTU2MDc2ODkzLCJqdGkiOiI0Y2VmOWYwZi1lZDExLTQ2ZWYtODMxMC1mN2UyM2FjZTQzYmYiLCJpZGVudGl0eSI6ImEzZjlkNjBhLTRmMzgtMTFlOS1iNTZiLTFiYmE4ZjhlNzJhZiIsImZyZXNoIjpmYWxzZSwidHlwZSI6ImFjY2VzcyJ9.1AE98f7ubYPgRIMtDDUu_8Ikktbh3E5eztiO0ozEP1U')

# %%
data = pd.read_csv('clean_storm_dataset.csv') # path needs to be set to wherever the clean data is, if not in the cwd
data.head()
# Out:
#            STATE  YEAR MONTH_NAME                EVENT_TYPE  \
# 0       ARKANSAS  2008   February                      Hail
# 1       ARKANSAS  2008    January         Thunderstorm Wind
# 2        ARIZONA  2008    January                     Flood
# 3       ILLINOIS  2008   December         Thunderstorm Wind
# 4  LAKE MICHIGAN  2008   December  Marine Thunderstorm Wind
#
#                    CZ_NAME     BEGIN_DATE_TIME  DAMAGE_PROPERTY  \
# 0                    SCOTT  05-FEB-08 16:15:00              0.0
# 1                   MONROE  08-JAN-08 13:20:00              0.0
# 2                     PIMA  28-JAN-08 03:00:00              0.0
# 3                 IROQUOIS  27-DEC-08 14:04:00              0.0
# 4  GARY TO BURNS HARBOR IN  27-DEC-08 15:20:00              0.0
#
#             SOURCE  MAGNITUDE MAGNITUDE_TYPE FLOOD_CAUSE TOR_F_SCALE  \
# 0  Law Enforcement       1.75            NaN         NaN         NaN
# 1  Law Enforcement      50.00             EG         NaN         NaN
# 2        Newspaper        NaN            NaN  Heavy Rain         NaN
# 3           Public      65.00             EG         NaN         NaN
# 4    C-MAN Station      39.00             MG         NaN         NaN
#
#    TOR_LENGTH  TOR_WIDTH BEGIN_LOCATION  END_LOCATION  BEGIN_LAT  BEGIN_LON  \
# 0         NaN        NaN            HON           HON     34.930   -94.1800
# 1         NaN        NaN    HOLLY GROVE   HOLLY GROVE     34.600   -91.2000
# 2         NaN        NaN       CASCABEL      CASCABEL     32.375  -111.0101
# 3         NaN        NaN         ASHKUM        ASHKUM     40.880   -87.9500
# 4         NaN        NaN   BURNS HARBOR  BURNS HARBOR     41.647   -87.1470
#
#    END_LAT   END_LON                                  EPISODE_NARRATIVE  \
# 0  34.9300  -94.1800  Early on the 5th, a strong storm system approa...
# 1  34.6000  -91.2000  Severe thunderstorms affected a large part of ...
# 2  32.3691 -111.0156  A trough of low pressure off the Western U.S. ...
# 3  40.8800  -87.9500  Heavy rain fell across northern Illinois durin...
# 4  41.6470  -87.1470  Strong thunderstorms moved across parts of far...
#
#                                      EVENT_NARRATIVE  DURATION_seconds  \
# 0                                                NaN               0.0
# 1             Trees and power lines were blown down.               0.0
# 2  A swift water rescue occurred about 4 am at th...            7200.0
# 3  A farmer reported buildings and vehicles moved...               0.0
# 4                                                NaN               0.0
#
#    WIND_SPEED  HAIL_SIZE
# 0         NaN       1.75
# 1        50.0        NaN
# 2         NaN        NaN
# 3        65.0        NaN
# 4        39.0        NaN

# %% [markdown]
# ## Feature Engineering
#
# The property damage values were binned to reflect the rounding of the inputs and allow the problem to be solved as a labeling instead of regression problem.

# %%
#bin the property damages
bins = [0, 1000, 10000, 50000, 200000, 1000000, 1000000000,1000000000000]
labels = [str('0 to 1k'), str('1k to 10k'),str('10k to 50k'),str('50k to 200k'),
          str('200k to 1M'),str('1M to 1B'), str('greater than 1B')]

data['BINNED_PROPERTY_DAMAGE'] = pd.cut(data['DAMAGE_PROPERTY'],include_lowest=True, bins=bins, labels=labels)
hail_data = data.loc[(data['EVENT_TYPE'] == 'Hail') | (data['EVENT_TYPE'] == 'Marine Hail')]

#divide the data into 12 distinct groups by event type:
print(pd.value_counts(hail_data.BINNED_PROPERTY_DAMAGE))
# Out:
# 0 to 1k            121072
# 1k to 10k            4463
# 10k to 50k           2406
# 50k to 200k           774
# 200k to 1M            585
# 1M to 1B              366
# greater than 1B         3
# Name: BINNED_PROPERTY_DAMAGE, dtype: int64

# %% [markdown]
# Select the subset of data that is applicable only to this model, as defined by the breakdown under the explore_clean_engineer notebook.

# %%
hail_data = data.loc[(data['EVENT_TYPE'] == 'Hail') | (data['EVENT_TYPE'] == 'Marine Hail')]

# %% [markdown]
# Drop unnecessary columns. The `DAMAGE_PROPERTY` column is redundant with the binned values, and the other values are not populated in the subset.

# %%
# Drop data that we don't want included in the model
hail_data = hail_data.drop('DAMAGE_PROPERTY', axis = 1)

# Drap data irrevelent to the Wind Model
hail_data = hail_data.drop(['WIND_SPEED','MAGNITUDE_TYPE','FLOOD_CAUSE','TOR_F_SCALE', 'TOR_LENGTH', 'TOR_WIDTH','HAIL_SIZE'], axis = 1)
hail_data.head(50)
# Out:
#               STATE  YEAR MONTH_NAME EVENT_TYPE       CZ_NAME  \
# 0          ARKANSAS  2008   February       Hail         SCOTT
# 8    SOUTH CAROLINA  2008        May       Hail  CHESTERFIELD
# 9    SOUTH CAROLINA  2008        May       Hail        SUMTER
# 10          GEORGIA  2008        May       Hail       LINCOLN
# 11          GEORGIA  2008        May       Hail         BURKE
# 12   SOUTH CAROLINA  2008        May       Hail     MCCORMICK
# 14   SOUTH CAROLINA  2008        May       Hail     EDGEFIELD
# 15   SOUTH CAROLINA  2008        May       Hail         AIKEN
# 16            TEXAS  2008      April       Hail          BELL
# 17            TEXAS  2008      April       Hail          BELL
# 18            TEXAS  2008      April       Hail          BELL
# 24        MINNESOTA  2008       July       Hail    BLUE EARTH
# 25        MINNESOTA  2008       July       Hail          RICE
# 26        MINNESOTA  2008       July       Hail     FARIBAULT
# 27        MINNESOTA  2008       July       Hail      FREEBORN
# 28        MINNESOTA  2008       July       Hail      FREEBORN
# 36            TEXAS  2008   February       Hail    MONTGOMERY
# 45         ILLINOIS  2008       June       Hail    JO DAVIESS
# 47   SOUTH CAROLINA  2008        May       Hail      BARNWELL
# 48   SOUTH CAROLINA  2008        May       Hail       BAMBERG
# 49   SOUTH CAROLINA  2008        May       Hail         AIKEN
# 50   SOUTH CAROLINA  2008        May       Hail    ORANGEBURG
# 51   SOUTH CAROLINA  2008        May       Hail    ORANGEBURG
# 52   SOUTH CAROLINA  2008        May       Hail       BAMBERG
# 54          GEORGIA  2008        May       Hail         BURKE
# 55   SOUTH CAROLINA  2008        May       Hail     EDGEFIELD
# 59      MISSISSIPPI  2008   December       Hail          PIKE
# 63            TEXAS  2008   February       Hail      CHAMBERS
# 64            TEXAS  2008   February       Hail       HOUSTON
# 65            TEXAS  2008   February       Hail       HOUSTON
# 66            TEXAS  2008   February       Hail        HARRIS
# 69       NEW MEXICO  2008       June       Hail          MORA
# 70       NEW MEXICO  2008       June       Hail          MORA
# 71       NEW MEXICO  2008       June       Hail          MORA
# 72       NEW MEXICO  2008       June       Hail        COLFAX
# 74       NEW MEXICO  2008       June       Hail     ROOSEVELT
# 95            TEXAS  2008      April       Hail          HILL
# 96            TEXAS  2008      April       Hail      MCLENNAN
# 97            TEXAS  2008      April       Hail      MCLENNAN
# 99   SOUTH CAROLINA  2008        May       Hail     EDGEFIELD
# 100  SOUTH CAROLINA  2008        May       Hail        SALUDA
# 101  SOUTH CAROLINA  2008        May       Hail        SALUDA
# 103       MINNESOTA  2008       July       Hail         SCOTT
# 105       MINNESOTA  2008       July       Hail      FREEBORN
# 111       MINNESOTA  2008       July       Hail        CARVER
# 112       MINNESOTA  2008       July       Hail     SHERBURNE
# 120  SOUTH CAROLINA  2008      March       Hail     MCCORMICK
# 124           TEXAS  2008      April       Hail      MCLENNAN
# 125           TEXAS  2008      April       Hail      MCLENNAN
# 126           TEXAS  2008      April       Hail      MCLENNAN
#
#         BEGIN_DATE_TIME                  SOURCE  MAGNITUDE  \
# 0    05-FEB-08 16:15:00         Law Enforcement       1.75
# 8    05-MAY-08 18:30:00                  Public       0.88
# 9    05-MAY-08 14:15:00         Law Enforcement       1.75
# 10   10-MAY-08 04:30:00         Law Enforcement       0.88
# 11   10-MAY-08 19:47:00  Fire Department/Rescue       1.00
# 12   10-MAY-08 04:42:00         Law Enforcement       0.88
# 14   10-MAY-08 05:12:00           Amateur Radio       0.88
# 15   10-MAY-08 05:30:00           Amateur Radio       1.75
# 16   25-APR-08 17:49:00           Amateur Radio       1.75
# 17   25-APR-08 17:58:00           Amateur Radio       1.75
# 18   25-APR-08 18:00:00           Amateur Radio       1.50
# 24   11-JUL-08 20:20:00         Trained Spotter       0.75
# 25   11-JUL-08 20:36:00         Trained Spotter       0.75
# 26   11-JUL-08 20:45:00         Trained Spotter       0.75
# 27   11-JUL-08 21:11:00         Trained Spotter       0.88
# 28   11-JUL-08 21:14:00         Trained Spotter       0.75
# 36   05-FEB-08 19:40:00         Law Enforcement       1.75
# 45   08-JUN-08 18:52:00         Trained Spotter       0.75
# 47   10-MAY-08 06:30:00         Law Enforcement       0.88
# 48   10-MAY-08 06:50:00         Law Enforcement       0.75
# 49   10-MAY-08 15:26:00                  Public       0.75
# 50   10-MAY-08 15:19:00       Emergency Manager       0.75
# 51   10-MAY-08 15:45:00                  Public       0.88
# 52   10-MAY-08 16:24:00                  Public       0.88
# 54   11-MAY-08 06:18:00         Law Enforcement       0.88
# 55   11-MAY-08 03:07:00           Amateur Radio       1.75
# 59   09-DEC-08 22:40:00       Emergency Manager       0.75
# 63   12-FEB-08 12:50:00         Law Enforcement       0.75
# 64   16-FEB-08 17:36:00         Law Enforcement       1.00
# 65   16-FEB-08 17:49:00       Emergency Manager       0.75
# 66   16-FEB-08 21:14:00       Emergency Manager       0.75
# 69   21-JUN-08 13:22:00         Trained Spotter       1.00
# 70   21-JUN-08 13:27:00         Trained Spotter       1.75
# 71   21-JUN-08 13:54:00         Trained Spotter       1.00
# 72   21-JUN-08 14:26:00         Trained Spotter       0.75
# 74   25-JUN-08 17:34:00                  Public       0.75
# 95   25-APR-08 15:09:00                  Public       1.00
# 96   25-APR-08 15:16:00         Broadcast Media       0.75
# 97   25-APR-08 15:29:00         Broadcast Media       0.75
# 99   11-MAY-08 03:20:00         Broadcast Media       1.75
# 100  11-MAY-08 03:40:00         Law Enforcement       0.75
# 101  11-MAY-08 03:22:00                  Public       0.75
# 103  11-JUL-08 19:35:00           Amateur Radio       0.75
# 105  11-JUL-08 21:16:00           Amateur Radio       0.75
# 111  11-JUL-08 19:16:00         Trained Spotter       0.75
# 112  11-JUL-08 19:16:00         Trained Spotter       0.75
# 120  04-MAR-08 18:42:00             Post Office       0.75
# 124  25-APR-08 15:32:00         Broadcast Media       1.50
# 125  25-APR-08 15:34:00         Broadcast Media       0.88
# 126  25-APR-08 16:05:00         Broadcast Media       1.75
#
#              BEGIN_LOCATION            END_LOCATION  BEGIN_LAT  BEGIN_LON  \
# 0                       HON                     HON    34.9300   -94.1800
# 8          CHERAW MUNI ARPT        CHERAW MUNI ARPT    34.7200   -79.9700
# 9                 CLAREMONT               CLAREMONT    33.9460   -80.6280
# 10               LINCOLNTON              LINCOLNTON    33.7800   -82.4800
# 11               WAYNESBORO              WAYNESBORO    33.0800   -82.1927
# 12               MERIWETHER              MERIWETHER    33.6500   -82.1700
# 14                  MORGANA                 MORGANA    33.5900   -82.0200
# 15                    AIKEN                   AIKEN    33.5211   -81.7200
# 16               TAYLOR VLY              TAYLOR VLY    31.0300   -97.4200
# 17   LITTLE RIVER - ACADEMY  LITTLE RIVER - ACADEMY    30.9864   -97.3554
# 18                   TEMPLE                  TEMPLE    31.1000   -97.3500
# 24                  MANKATO                 MANKATO    44.1400   -93.9900
# 25              BRIDGEWATER             BRIDGEWATER    44.4000   -93.2400
# 26           MINNESOTA LAKE          MINNESOTA LAKE    43.8400   -93.8300
# 27                 FREEBORN                FREEBORN    43.8000   -93.5600
# 28                 FREEBORN                FREEBORN    43.8100   -93.5600
# 36               SHENANDOAH              SHENANDOAH    30.1800   -95.4500
# 45                 STOCKTON                STOCKTON    42.3500   -90.0100
# 47               BLACKVILLE              BLACKVILLE    33.3500   -81.2700
# 48                  DENMARK                 DENMARK    33.3200   -81.1500
# 49                  WINDSOR                 WINDSOR    33.5005   -81.4955
# 50              BRANCHVILLE             BRANCHVILLE    33.2500   -80.8200
# 51              SPRINGFIELD             SPRINGFIELD    33.4898   -81.2677
# 52                  DENMARK                 DENMARK    33.3302   -81.1623
# 54                  VIDETTE                 VIDETTE    33.0300   -82.2500
# 55                 JOHNSTON                JOHNSTON    33.8095   -81.8046
# 59                  MC COMB                 MC COMB    31.2500   -90.4700
# 63                  ANAHUAC                 ANAHUAC    29.7600   -94.6800
# 64                 CROCKETT                CROCKETT    31.3200   -95.4600
# 65                 CROCKETT                CROCKETT    31.3300   -95.4400
# 66                  WEBSTER                 WEBSTER    29.5300   -95.1200
# 69                    OCATE                   OCATE    36.2107  -105.0880
# 70                    OCATE                   OCATE    36.2107  -105.0880
# 71                OJO FELIZ               OJO FELIZ    36.0700  -105.1200
# 72                 UTE PARK                UTE PARK    36.5700  -105.1000
# 74                   ROGERS                  ROGERS    33.9800  -103.3173
# 95                   MALONE                  MALONE    31.9300   -96.8900
# 96                     OCEE                    OCEE    31.6600   -97.4700
# 97                     OCEE                    OCEE    31.6300   -97.3900
# 99                EDGEFIELD               EDGEFIELD    33.7800   -81.9200
# 100               RIDGE SPG               RIDGE SPG    33.8500   -81.6700
# 101               RIDGE SPG               RIDGE SPG    33.8500   -81.6700
# 103            BELLE PLAINE            BELLE PLAINE    44.6300   -93.7700
# 105                FREEBORN                FREEBORN    43.8134   -93.5700
# 111                 NORWOOD                 NORWOOD    44.7800   -93.9200
# 112            LAKE FREMONT            LAKE FREMONT    45.4400   -93.5900
# 120               MT CARMEL               MT CARMEL    34.0000   -82.5000
# 124                    OCEE                    OCEE    31.6300   -97.3900
# 125                 GHOLSON                 GHOLSON    31.7000   -97.2200
# 126                 WOODWAY                 WOODWAY    31.5328   -97.2029
#
#      END_LAT   END_LON                                  EPISODE_NARRATIVE  \
# 0    34.9300  -94.1800  Early on the 5th, a strong storm system approa...
# 8    34.7200  -79.9700  A cluster of pulse storms moved through the Mi...
# 9    33.9460  -80.6280  A cluster of pulse storms moved through the Mi...
# 10   33.7800  -82.4800  Cluster pulse storms moved through the CSRA an...
# 11   33.0800  -82.1582  Cluster pulse storms moved through the CSRA an...
# 12   33.6500  -82.1700  Clusters of pulse storms moved across the CSRA...
# 14   33.5900  -82.0200  Clusters of pulse storms moved across the CSRA...
# 15   33.5500  -81.7200  Clusters of pulse storms moved across the CSRA...
# 16   31.0300  -97.4200  A strong line of storms as well as several dis...
# 17   30.9864  -97.3554  A strong line of storms as well as several dis...
# 18   31.1000  -97.3500  A strong line of storms as well as several dis...
# 24   44.1400  -93.9900  Instability ahead of a cold front which moved ...
# 25   44.4000  -93.2400  Instability ahead of a cold front which moved ...
# 26   43.8400  -93.8300  Instability ahead of a cold front which moved ...
# 27   43.8000  -93.5600  Instability ahead of a cold front which moved ...
# 28   43.8100  -93.5600  Instability ahead of a cold front which moved ...
# 36   30.1800  -95.4500  Isolated severe thunderstorms passed across th...
# 45   42.3500  -90.0100  Thunderstorms moved across parts of northwest ...
# 47   33.3500  -81.2700  Clusters of pulse storms moved across the CSRA...
# 48   33.3200  -81.1500  Clusters of pulse storms moved across the CSRA...
# 49   33.5005  -81.4955  Clusters of pulse storms moved across the CSRA...
# 50   33.2500  -80.8200  Clusters of pulse storms moved across the CSRA...
# 51   33.4898  -81.2677  Clusters of pulse storms moved across the CSRA...
# 52   33.3302  -81.1623  Clusters of pulse storms moved across the CSRA...
# 54   33.0300  -82.2500  A few supercells moved through the CSRA and pr...
# 55   33.7993  -81.7431  Several supercells moved through the midlands ...
# 59   31.2500  -90.4700  Isolated severe thunderstorms affected southwe...
# 63   29.7600  -94.6800  Isolated severe thunderstorms produced straigh...
# 64   31.3200  -95.4600  Scattered thunderstorms became better organize...
# 65   31.3300  -95.4400  Scattered thunderstorms became better organize...
# 66   29.5300  -95.1200  Scattered thunderstorms became better organize...
# 69   36.2107 -105.0880  Continued low level moisture and good shear in...
# 70   36.2107 -105.0880  Continued low level moisture and good shear in...
# 71   36.0700 -105.1200  Continued low level moisture and good shear in...
# 72   36.5700 -105.1000  Continued low level moisture and good shear in...
# 74   33.9800 -103.3173  An unstable atmosphere with plenty of low leve...
# 95   31.9300  -96.8900  A strong line of storms as well as several dis...
# 96   31.6600  -97.4700  A strong line of storms as well as several dis...
# 97   31.6300  -97.3900  A strong line of storms as well as several dis...
# 99   33.7800  -81.9200  Several supercells moved through the midlands ...
# 100  33.8500  -81.6700  Several supercells moved through the midlands ...
# 101  33.8500  -81.6700  Several supercells moved through the midlands ...
# 103  44.6300  -93.7700  Instability ahead of a cold front which moved ...
# 105  43.8134  -93.5700  Instability ahead of a cold front which moved ...
# 111  44.7800  -93.9200  Instability ahead of a cold front which moved ...
# 112  45.4400  -93.5900  Instability ahead of a cold front which moved ...
# 120  34.0000  -82.5000  Thunderstorms produced a couple of small torna...
# 124  31.6300  -97.3900  A strong line of storms as well as several dis...
# 125  31.7000  -97.2200  A strong line of storms as well as several dis...
# 126  31.5328  -97.2029  A strong line of storms as well as several dis...
#
#                                        EVENT_NARRATIVE  DURATION_seconds  \
# 0                                                  NaN               0.0
# 8    Nickel size hail was reported near the Cheraw ...               0.0
# 9    The Highway Patrol reported golf ball size hai...               0.0
# 10    Sheriff reported nickel size hail in Lincolnton.               0.0
# 11         Fire department reported quarter size hail.             720.0
# 12                  Sheriff reported nickel size hail.               0.0
# 14   SKYWARN HAM radio operator reported nickel siz...               0.0
# 15   SKYWARN HAM radio spotters reported quarter to...             900.0
# 16   Golfball-size hail was reported between Belton...               0.0
# 17                                                 NaN               0.0
# 18                                                 NaN               0.0
# 24   Hail occurred at Country Rd. 90 and Hwy. 22 in...               0.0
# 25                                                 NaN               0.0
# 26                                                 NaN               0.0
# 27                                                 NaN               0.0
# 28            Estimated winds of 55 mph also reported.               0.0
# 36   Windows of at least one residence were broken ...               0.0
# 45   Penny-sized hail fell in Stockton, IL at 7:52 ...               0.0
# 47                   Police reported nickel size hail.               0.0
# 48                   Sheriff reported penny size hail.               0.0
# 49                    Public reported penny size hail.               0.0
# 50         Emergency Manager reported penny size hail.               0.0
# 51                   Public reported nickel size hail.               0.0
# 52                   Public reported nickel size hail.               0.0
# 54   Sheriff reported nickel size hail in the Videt...             180.0
# 55   SKYWARN spotters reported quarter to golf ball...             300.0
# 59                                                 NaN               0.0
# 63                                                 NaN               0.0
# 64                                                 NaN               0.0
# 65                                                 NaN               0.0
# 66                                                 NaN               0.0
# 69                                                 NaN               0.0
# 70                                                 NaN               0.0
# 71                                                 NaN               0.0
# 72                                                 NaN               0.0
# 74                                                 NaN               0.0
# 95                                                 NaN               0.0
# 96                                                 NaN               0.0
# 97                                                 NaN               0.0
# 99   TV station reported golf ball size hail in Edg...               0.0
# 100    Penny size hail reported by sheriff department.               0.0
# 101                Penny size hail reported by public.               0.0
# 103         Hail occurred just North of Walnut Street.               0.0
# 105                                                NaN               0.0
# 111                                                NaN               0.0
# 112         Occurred two miles South of County Road 4.               0.0
# 120  Post Office reported 3/4 inch hail and strong ...               0.0
# 124                                                NaN               0.0
# 125                                                NaN               0.0
# 126  Golfball-size hail was reported at the interse...               0.0
#
#     BINNED_PROPERTY_DAMAGE
# 0                  0 to 1k
# 8                  0 to 1k
# 9                  0 to 1k
# 10                 0 to 1k
# 11                 0 to 1k
# 12                 0 to 1k
# 14                 0 to 1k
# 15                 0 to 1k
# 16               1k to 10k
# 17               1k to 10k
# 18                 0 to 1k
# 24                 0 to 1k
# 25                 0 to 1k
# 26                 0 to 1k
# 27                 0 to 1k
# 28                 0 to 1k
# 36               1k to 10k
# 45                 0 to 1k
# 47                 0 to 1k
# 48                 0 to 1k
# 49                 0 to 1k
# 50                 0 to 1k
# 51                 0 to 1k
# 52                 0 to 1k
# 54                 0 to 1k
# 55                 0 to 1k
# 59                 0 to 1k
# 63                 0 to 1k
# 64                 0 to 1k
# 65                 0 to 1k
# 66                 0 to 1k
# 69                 0 to 1k
# 70                 0 to 1k
# 71                 0 to 1k
# 72                 0 to 1k
# 74                 0 to 1k
# 95                 0 to 1k
# 96                 0 to 1k
# 97                 0 to 1k
# 99                 0 to 1k
# 100                0 to 1k
# 101                0 to 1k
# 103                0 to 1k
# 105                0 to 1k
# 111                0 to 1k
# 112                0 to 1k
# 120                0 to 1k
# 124                0 to 1k
# 125                0 to 1k
# 126              1k to 10k

# %% [markdown]
# ## Uploading Information to Darwin
#
# The data is sampled to extract a test dataset. The test and train datasets are then saved to CSV files under the 'event_subsets' folder and uploaded to Darwin. Darwin is then ordered to start cleaning the data.

# %%
# Take out a 500 row subset of test data
hail_data_test=hail_data.sample(1500)
hail_data_train=hail_data.drop(hail_data_test.index)

# convert the test data and the main data to a csv
hail_data_train.to_csv('event_subsets/hail_data_train.csv')
hail_data_test.to_csv('event_subsets/hail_data_test.csv')

# Upload the train to Darwin
s.upload_dataset('event_subsets/hail_data_train.csv', 'hail_data_train')
s.upload_dataset('event_subsets/hail_data_test.csv', 'hail_data_test')

# Clean the training dataset using Darwin
s.clean_data('hail_data_train',target = 'BINNED_PROPERTY_DAMAGE')
# Out:
# (True,
#  {'job_name': 'c0a5a4bb5c504d9cbf1666b9f7ee6299',
#   'artifact_name': 'bd8ba0443f7e44868a4de710d6b44919'})

# %%
s.wait_for_job('f7ee1fc7e5c24158b686fe57389cfc17')
# Out:
# {'status': 'Complete', 'starttime': '2019-04-22T18:21:55.870332', 'endtime': '2019-04-22T18:25:16.682359', 'percent_complete': 100, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['hail_data_train'], 'artifact_names': ['b45f3718c4e14ac0ba5f13f0678378ff'], 'model_name': None, 'job_error': ''}
# (True, 'Job completed')

# %% [markdown]
# We lookup the datasets to confirm that they have been properly uploaded.

# %%
s.lookup_dataset()
# Out:
# (True,
#  [{'name': 'hr_train',
#    'mbytes': 0.6898021697998047,
#    'minimum_recommeded_train_time': '5 minutes',
#    'updated_at': '2019-04-20T23:56:19.042932',
#    'categorical': None,
#    'sequential': None,
#    'imbalanced': None},
#   {'name': 'hr_test',
#    'mbytes': 0.17252063751220703,
#    'minimum_recommeded_train_time': '5 minutes',
#    'updated_at': '2019-04-20T23:56:19.405261',
#    'categorical': None,
#    'sequential': None,
#    'imbalanced': None},
#   {'name': 'flood_data_train',
#    'mbytes': 26.48654079437256,
#    'minimum_recommeded_train_time': '5 minutes',
#    'updated_at': '2019-04-22T11:50:56.337543',
#    'categorical': None,
#    'sequential': None,
#    'imbalanced': None},
#   {'name': 'hail_data_train',
#    'mbytes': 74.30458927154541,
#    'minimum_recommeded_train_time': '5 minutes',
#    'updated_at': '2019-04-22T18:21:54.373038',
#    'categorical': None,
#    'sequential': None,
#    'imbalanced': None},
#   {'name': 'hail_data_test',
#    'mbytes': 0.9263954162597656,
#    'minimum_recommeded_train_time': '5 minutes',
#    'updated_at': '2019-04-22T18:21:54.789861',
#    'categorical': None,
#    'sequential': None,
#    'imbalanced': None},
#   {'name': 'flood_data_test',
#    'mbytes': 0.5362062454223633,
#    'minimum_recommeded_train_time': '5 minutes',
#    'updated_at': '2019-04-22T11:50:56.740305',
#    'categorical': None,
#    'sequential': None,
#    'imbalanced': None}])

# %% [markdown]
# ## Creation of the Model
#
# Next, the Darwin is ordered to create a model based on the training dataset.

# %%
print(s.download_dataset('hail_data_test')[1]['filename'])
# Out:
# (True,
#  {'filename': 'C:\\Users\\freeb\\AppData\\Local\\Temp\\hail_data_test-part0-_4hxk_5c.csv',
#   'part': 0,
#   'note': 'part 0 of 0'})

# %%
print('C:\\Users\\freeb\\AppData\\Local\\Temp\\hail_data_test-part0-_4hxk_5c.csv')
# Out:
# C:\Users\freeb\AppData\Local\Temp\hail_data_test-part0-_4hxk_5c.csv

# %%
# Create the model
s.delete_model('hail_model')
s.create_model(dataset_names='hail_data_train', model_name='hail_model', max_train_time = '00:30')
# Out:
# (True,
#  {'job_name': 'b4a747d0bc2641b384f80c95af86682d',
#   'job_id': '5c98b9b4-6556-11e9-880e-7bf2e0f0470e',
#   'model_name': 'hail_model'})

# %%
s.wait_for_job('b4a747d0bc2641b384f80c95af86682d')
# Out:
# {'status': 'Complete', 'starttime': '2019-04-22T18:28:40.660924', 'endtime': '2019-04-22T19:07:37.443729', 'percent_complete': 100, 'job_type': 'TrainModel', 'loss': 1.249639630317688, 'generations': 8, 'dataset_names': ['hail_data_train'], 'artifact_names': None, 'model_name': 'hail_model', 'job_error': ''}
# (True, 'Job completed')

# %% [markdown]
# We lookup the model to confirm that the model has been properly constructed.

# %%
s.lookup_model()
# Out:
# (True,
#  [{'id': '5301ba46-63f2-11e9-8c21-3b32e5393f40',
#    'name': 'heavy_rain_model_20190421000001',
#    'type': None,
#    'problem_type': None,
#    'updated_at': None,
#    'trained_on': [],
#    'generations': 0,
#    'loss': None,
#    'complete': False,
#    'parameters': {'train_time': '00:05'},
#    'description': None,
#    'train_time_seconds': 0,
#    'algorithm': None,
#    'running_job_id': None},
#   {'id': '5c98461e-6556-11e9-880e-57541405989a',
#    'name': 'hail_model',
#    'type': 'Supervised',
#    'problem_type': None,
#    'updated_at': '2019-04-22T19:07:37.419949',
#    'trained_on': ['hail_data_train'],
#    'generations': 8,
#    'loss': 1.249639630317688,
#    'complete': True,
#    'parameters': {'train_time': '00:30',
#     'target': 'BINNED_PROPERTY_DAMAGE',
#     'recurrent': True,
#     'max_unique_values': 50,
#     'max_int_uniques': 15,
#     'impute': 'ffill',
#     'big_data': False},
#    'description': {'best_genome': {'type': 'RandomForestClassifier',
#      'parameters': {'bootstrap': True,
#       'criterion': 'entropy',
#       'max_depth': 9,
#       'max_features': 0.8386812769125136,
#       'max_leaf_nodes': None,
#       'min_impurity_decrease': 0.0,
#       'min_samples_leaf': 8,
#       'min_samples_split': 11,
#       'n_jobs': -1,
#       'min_weight_fraction_leaf': 0.0,
#       'n_estimators': 91}},
#     'recurrent': True,
#     'genome_type': 'RandomForestClassifier'},
#    'train_time_seconds': 2337,
#    'algorithm': None,
#    'running_job_id': None},
#   {'id': '4269eedc-651f-11e9-901e-d3ce13d215c3',
#    'name': 'flood_data',
#    'type': 'Supervised',
#    'problem_type': None,
#    'updated_at': '2019-04-22T12:13:47.798640',
#    'trained_on': ['flood_data_train'],
#    'generations': 9,
#    'loss': 2.303936243057251,
#    'complete': True,
#    'parameters': {'train_time': '00:10',
#     'target': 'BINNED_PROPERTY_DAMAGE',
#     'recurrent': True,
#     'max_unique_values': 50,
#     'max_int_uniques': 15,
#     'impute': 'ffill',
#     'big_data': False},
#    'description': {'best_genome': [{'layer 1': {'type': 'LinearGene',
#        'parameters': {'activation': 'relu', 'numunits': 59}}},
#      {'layer 2': {'type': 'LinearGene',
#        'parameters': {'activation': 'relu', 'numunits': 19}}}],
#     'recurrent': True,
#     'genome_type': 'DeepNet'},
#    'train_time_seconds': 1173,
#    'algorithm': None,
#    'running_job_id': None},
#   {'id': '03804c0c-63f3-11e9-8c21-cb9cd605b273',
#    'name': 'heavy_rain_model_2',
#    'type': 'Supervised',
#    'problem_type': None,
#    'updated_at': '2019-04-21T00:05:24.618450',
#    'trained_on': ['hr_train'],
#    'generations': 5,
#    'loss': 0.3426899015903473,
#    'complete': True,
#    'parameters': {'train_time': '00:05',
#     'target': 'binary_damage',
#     'recurrent': False,
#     'max_unique_values': 50,
#     'max_int_uniques': 15,
#     'impute': 'mean',
#     'big_data': False},
#    'description': {'best_genome': {'type': 'XGBClassifier',
#      'parameters': {'base_score': 0.5,
#       'colsample_bylevel': 1,
#       'colsample_bytree': 1,
#       'gamma': 0,
#       'learning_rate': 0.8660545691659209,
#       'max_delta_step': 0,
#       'max_depth': 2,
#       'min_child_weight': 2,
#       'n_estimators': 379,
#       'n_jobs': -1,
#       'reg_alpha': 0,
#       'reg_lambda': 1,
#       'scale_pos_weight': 1,
#       'subsample': 0.8274584633546566}},
#     'recurrent': False,
#     'genome_type': 'XGBClassifier'},
#    'train_time_seconds': 25,
#    'algorithm': None,
#    'running_job_id': None},
#   {'id': '9ebcbe5e-63f2-11e9-8c21-5b7958ff8440',
#    'name': 'heavy_rain_model_20190421000208',
#    'type': 'Supervised',
#    'problem_type': None,
#    'updated_at': '2019-04-21T00:02:38.615112',
#    'trained_on': ['hr_train'],
#    'generations': 6,
#    'loss': 0.3452835977077484,
#    'complete': True,
#    'parameters': {'train_time': '00:05',
#     'target': 'binary_damage',
#     'recurrent': False,
#     'max_unique_values': 50,
#     'max_int_uniques': 15,
#     'impute': 'mean',
#     'big_data': False},
#    'description': {'best_genome': {'type': 'XGBClassifier',
#      'parameters': {'base_score': 0.5,
#       'colsample_bylevel': 1,
#       'colsample_bytree': 1,
#       'gamma': 0,
#       'learning_rate': 0.5442624687804244,
#       'max_delta_step': 0,
#       'max_depth': 4,
#       'min_child_weight': 10,
#       'n_estimators': 257,
#       'n_jobs': -1,
#       'reg_alpha': 0,
#       'reg_lambda': 1,
#       'scale_pos_weight': 1,
#       'subsample': 0.6558750103985679}},
#     'recurrent': False,
#     'genome_type': 'XGBClassifier'},
#    'train_time_seconds': 28,
#    'algorithm': None,
#    'running_job_id': None},
#   {'id': '5d10a764-63e2-11e9-9bfe-e7a6bbdc47ff',
#    'name': 'death_any_model',
#    'type': 'Supervised',
#    'problem_type': None,
#    'updated_at': '2019-04-20T22:15:15.558228',
#    'trained_on': ['death_any_data_train'],
#    'generations': 0,
#    'loss': 0.006663320120424032,
#    'complete': True,
#    'parameters': {'train_time': '00:05',
#     'target': 'DEATH_BINARY',
#     'recurrent': False,
#     'max_unique_values': 50,
#     'max_int_uniques': 15,
#     'impute': 'mean',
#     'big_data': True},
#    'description': {'best_genome': {'type': 'XGBRegressor',
#      'parameters': {'base_score': 0.5,
#       'colsample_bylevel': 1,
#       'colsample_bytree': 1,
#       'gamma': 0,
#       'learning_rate': 0.1,
#       'max_delta_step': 0,
#       'max_depth': 3,
#       'min_child_weight': 1,
#       'n_estimators': 100,
#       'n_jobs': -1,
#       'reg_alpha': 0,
#       'reg_lambda': 1,
#       'scale_pos_weight': 1,
#       'subsample': 1.0}},
#     'recurrent': False,
#     'genome_type': 'XGBRegressor'},
#    'train_time_seconds': 567,
#    'algorithm': None,
#    'running_job_id': None},
#   {'id': '67d56334-63dc-11e9-83c4-aff6976b3e96',
#    'name': 'drought_any_model',
#    'type': 'Supervised',
#    'problem_type': None,
#    'updated_at': '2019-04-20T21:28:21.487871',
#    'trained_on': ['drought_any_data_train'],
#    'generations': 4,
#    'loss': None,
#    'complete': True,
#    'parameters': {'train_time': '00:05',
#     'target': 'DAMAGE',
#     'recurrent': True,
#     'max_unique_values': 50,
#     'max_int_uniques': 15,
#     'impute': 'ffill',
#     'big_data': False},
#    'description': None,
#    'train_time_seconds': 312,
#    'algorithm': None,
#    'running_job_id': None},
#   {'id': '37877080-63d9-11e9-a047-7fc7c2652394',
#    'name': 'drought_model',
#    'type': 'Supervised',
#    'problem_type': None,
#    'updated_at': '2019-04-20T21:05:28.860720',
#    'trained_on': ['drought_data_train'],
#    'generations': 4,
#    'loss': None,
#    'complete': True,
#    'parameters': {'train_time': '00:05',
#     'target': 'DAMAGE_PROPERTY',
#     'recurrent': True,
#     'max_unique_values': 50,
#     'max_int_uniques': 15,
#     'impute': 'ffill',
#     'big_data': False},
#    'description': None,
#    'train_time_seconds': 309,
#    'algorithm': None,
#    'running_job_id': None},
#   {'id': '0a06eb7e-63c3-11e9-9ba2-77a6d4a1ecab',
#    'name': 'winter_model',
#    'type': 'Supervised',
#    'problem_type': None,
#    'updated_at': '2019-04-20T18:26:49.988711',
#    'trained_on': ['winter_data_train'],
#    'generations': 2,
#    'loss': None,
#    'complete': True,
#    'parameters': {'train_time': '00:05',
#     'target': 'DAMAGE_PROPERTY',
#     'recurrent': True,
#     'max_unique_values': 50,
#     'max_int_uniques': 15,
#     'impute': 'ffill',
#     'big_data': False},
#    'description': None,
#    'train_time_seconds': 315,
#    'algorithm': None,
#    'running_job_id': None},
#   {'id': 'f49e0a60-63b3-11e9-8940-97ed3fbe26f4',
#    'name': 'wind_model',
#    'type': 'Supervised',
#    'problem_type': None,
#    'updated_at': '2019-04-20T16:36:44.458492',
#    'trained_on': ['wind_data_train'],
#    'generations': 0,
#    'loss': None,
#    'complete': True,
#    'parameters': {'train_time': '00:02',
#     'target': 'DAMAGE_PROPERTY',
#     'recurrent': True,
#     'max_unique_values': 50,
#     'max_int_uniques': 15,
#     'impute': 'ffill',
#     'big_data': False},
#    'description': None,
#    'train_time_seconds': 188,
#    'algorithm': None,
#    'running_job_id': None}])

# %% [markdown]
# We began to clean test data using the cleaning method applied to the model which was just created.

# %%
s.clean_data('hail_data_test',target = 'BINNED_PROPERTY_DAMAGE', model_name = 'hail_model')
# Out:
# (True,
#  {'job_name': 'b544cddd9adb4ca1b107e78a7411223a',
#   'artifact_name': '7123e897eba34e4f91dea165ccae9fd6'})

# %%
s.wait_for_job('b544cddd9adb4ca1b107e78a7411223a')
# Out:
# {'status': 'Running', 'starttime': '2019-04-22T19:12:15.64045', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['hail_data_test'], 'artifact_names': ['7123e897eba34e4f91dea165ccae9fd6'], 'model_name': None, 'job_error': ''}
# {'status': 'Complete', 'starttime': '2019-04-22T19:12:15.64045', 'endtime': '2019-04-22T19:12:23.05567', 'percent_complete': 100, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['hail_data_test'], 'artifact_names': ['7123e897eba34e4f91dea165ccae9fd6'], 'model_name': None, 'job_error': ''}
# (True, 'Job completed')

# %% [markdown]
# ## Analysis of the Model
#
# Concurrently, the exisisting model was analyzed.

# %%
s.analyze_model('hail_model')
# Out:
# (True,
#  {'job_name': '495274422a0242ec856d87f01e82ad24',
#   'artifact_name': '44458749de5b415d82555c4a685c6dac'})

# %%
s.wait_for_job('495274422a0242ec856d87f01e82ad24')
# Out:
# {'status': 'Complete', 'starttime': '2019-04-22T22:12:02.012618', 'endtime': '2019-04-22T22:15:39.282038', 'percent_complete': 100, 'job_type': 'AnalyzeModel', 'loss': 1.249639630317688, 'generations': 8, 'dataset_names': None, 'artifact_names': ['44458749de5b415d82555c4a685c6dac'], 'model_name': 'hail_model', 'job_error': ''}
# (True, 'Job completed')

# %% [markdown]
# The retrieved artifact indicated in descending order of importance the properties most important to the model.

# %%
results = s.download_artifact('44458749de5b415d82555c4a685c6dac')
results[1]
# Out:
# MAGNITUDE                             1.869166e-01
# BEGIN_LON                             1.859738e-01
# END_LON                               1.606392e-01
# BEGIN_LAT                             1.323900e-01
# END_LAT                               1.310332e-01
# Unnamed: 0                            7.057317e-02
# DURATION_seconds                      2.732105e-02
# YEAR = 2014                           7.610505e-03
# MONTH_NAME = June                     6.031469e-03
# MONTH_NAME = May                      5.935985e-03
# SOURCE = Public                       5.617114e-03
# YEAR = 2011                           5.088064e-03
# YEAR = 2013                           4.965488e-03
# SOURCE = Amateur Radio                4.795108e-03
# YEAR = 2015                           4.670378e-03
# MONTH_NAME = March                    4.576735e-03
# YEAR = 2012                           4.449586e-03
# SOURCE = Trained Spotter              3.664951e-03
# YEAR = 2009                           3.496391e-03
# SOURCE = Emergency Manager            3.217847e-03
# YEAR = 2017                           3.025012e-03
# MONTH_NAME = July                     2.929630e-03
# SOURCE = SHAVE Project                2.890620e-03
# YEAR = 2016                           2.742746e-03
# MONTH_NAME = August                   2.722618e-03
# YEAR = 2018                           2.708983e-03
# SOURCE = Law Enforcement              2.623346e-03
# SOURCE = Social Media                 2.617344e-03
# YEAR = 2010                           2.345034e-03
# SOURCE = Broadcast Media              2.169287e-03
# MONTH_NAME = September                2.038404e-03
# MONTH_NAME = February                 1.741328e-03
# SOURCE = Fire Department/Rescue       1.559059e-03
# SOURCE = County Official              1.133042e-03
# MONTH_NAME = October                  1.024455e-03
# SOURCE = NWS Employee                 9.582874e-04
# SOURCE = Storm Chaser                 7.133551e-04
# MONTH_NAME = January                  6.779595e-04
# SOURCE = Newspaper                    6.762740e-04
# SOURCE = CoCoRaHS                     6.001646e-04
# SOURCE = COOP Observer                5.944715e-04
# SOURCE = NWS Storm Survey             4.466280e-04
# SOURCE = Post Office                  4.143496e-04
# MONTH_NAME = November                 3.673164e-04
# MONTH_NAME = December                 2.891867e-04
# SOURCE = Official NWS Observations    2.394181e-04
# SOURCE = State Official               1.664880e-04
# SOURCE = Utility Company              1.497939e-04
# SOURCE = Local Official               1.289351e-04
# SOURCE = Other Federal Agency         9.813445e-05
# SOURCE = ASOS                         7.870370e-05
# EVENT_TYPE = Marine Hail              6.335418e-05
# SOURCE = Department of Highways       4.593553e-05
# SOURCE = Unknown                      3.058171e-05
# SOURCE = Park/Forest Service          2.278506e-05
# SOURCE = Airplane Pilot               3.365553e-07
# SOURCE = AWOS                         1.787512e-10
# SOURCE = Insurance Company            0.000000e+00
# SOURCE = Mariner                      0.000000e+00
# SOURCE = River/Stream Gage            0.000000e+00
# SOURCE = Mesonet                      0.000000e+00
# SOURCE = Drought Monitor              0.000000e+00
# SOURCE = RAWS                         0.000000e+00
# SOURCE = Coast Guard                  0.000000e+00
# SOURCE = NPOP                         0.000000e+00
# dtype: float64

# %% [markdown]
# The model's parameters were also analyzed.

# %%
s.display_population('wind_model')
# Out:
# (True,
#  {'population': {'model_types': {'DeepNeuralNetwork': {'model_description': [{'layer 1': {'type': 'LSTMGene',
#         'parameters': {'activation': 'relu', 'numunits': 70, 'numlayers': 1}}},
#       {'layer 2': {'type': 'LinearGene',
#         'parameters': {'activation': 'relu', 'numunits': 19}}}],
#      'loss_function': 'CrossEntropy',
#      'fitness': 1.6725940973962325},
#     'RandomForest': {'model_description': {'type': 'RandomForestClassifier',
#       'parameters': {'bootstrap': False,
#        'criterion': 'gini',
#        'max_depth': 7,
#        'max_features': 0.8507892505977884,
#        'max_leaf_nodes': None,
#        'min_impurity_decrease': 0.0,
#        'min_samples_leaf': 1,
#        'min_samples_split': 16,
#        'n_jobs': -1,
#        'min_weight_fraction_leaf': 0.0,
#        'n_estimators': 65}},
#      'loss_function': 'CrossEntropy',
#      'fitness': 1.6787765860710828},
#     'GradientBoosted': {'model_description': {'type': 'XGBClassifier',
#       'parameters': {'base_score': 0.5,
#        'colsample_bylevel': 1,
#        'colsample_bytree': 1,
#        'gamma': 0,
#        'learning_rate': 0.7000215340031714,
#        'max_delta_step': 0,
#        'max_depth': 6,
#        'min_child_weight': 12,
#        'n_estimators': 371,
#        'n_jobs': -1,
#        'reg_alpha': 0,
#        'reg_lambda': 1,
#        'scale_pos_weight': 1,
#        'subsample': 0.1123441259128239}},
#      'loss_function': 'CrossEntropy',
#      'fitness': 1.6969451398774313}}}})

# %% [markdown]
# ## Analysis of the Test Results
#
# Finally, the test data property damage was analyzed using the model and cleaned training data.

# %%
s.run_model('hail_data_test','hail_model')
# Out:
# (True,
#  {'job_name': 'ec27c1b0ddbc4fa9bc984b19e94239d7',
#   'artifact_name': '839d1d5494004dceb0eeef2a68f0cc6c'})

# %%
s.wait_for_job('ec27c1b0ddbc4fa9bc984b19e94239d7')
# Out:
# {'status': 'Complete', 'starttime': '2019-04-22T19:20:43.447575', 'endtime': '2019-04-22T19:21:30.114283', 'percent_complete': 100, 'job_type': 'RunModel', 'loss': 1.249639630317688, 'generations': 8, 'dataset_names': ['hail_data_test'], 'artifact_names': ['839d1d5494004dceb0eeef2a68f0cc6c'], 'model_name': 'hail_model', 'job_error': ''}
# (True, 'Job completed')

# %%
s.download_artifact('839d1d5494004dceb0eeef2a68f0cc6c','C:\\Users\\freeb\\Documents\\GitHub\\storm_analytics')
# Out:
# (True,
#  {'filename': 'C:\\Users\\freeb\\Documents\\GitHub\\storm_analytics\\artifact.csv'})

# %% [markdown]
# The resulting artifact determined that the model was over 99% accurate, but was actually mostly missing the rare class, as demonstrated by f1 scores of 0 for every category except the majority class.

# %%
test_results = pd.read_csv('artifact.csv')
test_actual = pd.read_csv('event_subsets\\hail_data_test.csv')
correct_count = 0
incorrect_count = 0

for i, row in test_results.iterrows():
    j = 0
    if test_results.at[j,'BINNED_PROPERTY_DAMAGE'] == row['BINNED_PROPERTY_DAMAGE']:
        correct_count += 1
    else:
        incorrect_count+=1
    j+=1
        
print(correct_count)
print(incorrect_count)
print('Accuracy: ' + str(correct_count/1500))

#sklearn.metrics.precision_recall_fscore_support(test_results,test_actual)

y_pred = test_results['BINNED_PROPERTY_DAMAGE']
y_actual = test_actual['BINNED_PROPERTY_DAMAGE']

precision, recall, fscore, support = sklearn.metrics.precision_recall_fscore_support(y_pred,y_actual)

#labels = [str('0 to 2.5k'), str('2.5k to 5k'),str('5k to 10k'),str('10k to 20k'),str('20k to 30k'),str('30k to 40k'),
#          str('40k to 50k'),str('50k to 75k'),str('75k to 100k'),str('100k to 200k'),str('200k to 300k'),
#          str('300k to 400k'),str('400k to 500k'),str('500k to 600k'),str('600k to 700k'),str('700k to 800k'),
#          str('800k to 900k'),str('900k to 1B'),str('greater than 1B')]

results = pd.DataFrame({'precision': precision, 'Recall' : recall, 'fscore': fscore, 'support' : support})
results
# Out:
# 1454
# 46
# Accuracy: 2.908
# 19
# 7
#    precision    Recall    fscore  support
# 0   0.992063  0.945667  0.968310     1454
# 1   0.108108  0.666667  0.186047        6
# 2   0.000000  0.000000  0.000000        0
# 3   0.321429  0.473684  0.382979       38
# 4   0.000000  0.000000  0.000000        2
# 5   0.000000  0.000000  0.000000        0
# 6   0.000000  0.000000  0.000000        0
