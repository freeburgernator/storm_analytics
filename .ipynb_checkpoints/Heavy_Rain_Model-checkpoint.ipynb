# %%
import os
import datetime
from datetime import timedelta
from amb_sdk.sdk import DarwinSdk
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
# %matplotlib inline

#displays all datasets' columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

s = DarwinSdk()
s.set_url('https://amb-demo-api.sparkcognition.com/v1/')
# s.auth_login_user('','')
s.auth_login_user('FPREIMESBERGER@GMAIL.COM','dRgC88hVfC')
# Out:
# (True,
#  'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJleHAiOjE1NTU4ODIzMDEsImlhdCI6MTU1NTg3NTEwMSwibmJmIjoxNTU1ODc1MTAxLCJqdGkiOiJkMDlhNmU1OS1lYzNmLTQ4YzYtOTJjNC1jZGIwNjc2OTdlMmEiLCJpZGVudGl0eSI6ImFkNTM0YzIyLTRmMzgtMTFlOS05ODE5LTBiYTcxODYyYmJiZSIsImZyZXNoIjpmYWxzZSwidHlwZSI6ImFjY2VzcyJ9.LKiK7EL4LE4og5ZdYDUvznHoAVLsOIodRKJYH6aPll4')

# %%
#read in the storm datasets
s2008 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2008_c20180718.csv.gz', compression='gzip')
s2009 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2009_c20180718.csv.gz', compression='gzip')
s2010 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2010_c20170726.csv.gz', compression='gzip')
s2011 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2011_c20180718.csv.gz', compression='gzip')
s2012 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2012_c20170519.csv.gz', compression='gzip')
s2013 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2013_c20170519.csv.gz', compression='gzip')
s2014 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2014_c20180718.csv.gz', compression='gzip')
s2015 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2015_c20180525.csv.gz', compression='gzip')
s2016 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2016_c20180718.csv.gz', compression='gzip')
s2017 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2017_c20181219.csv.gz', compression='gzip')
s2018 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2018_c20190220.csv.gz', compression='gzip')


raw = pd.concat([s2008,s2009,s2010,s2011,s2012,s2013,s2014,s2015,s2016,s2017,s2018])
raw.head(10)
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           200802         22        1300         200802       22      2200
# 1           200804          1         352         200804        1       352
# 2           200803          1           0         200803        1      1320
# 3           200801         14         500         200801       14      1700
# 4           200812         19        1353         200812       21       200
# 5           200812         11         412         200812       12       953
# 6           200812         21         744         200812       21      2359
# 7           200802          5        1615         200802        5      1615
# 8           200801          8        1320         200801        8      1320
# 9           200801         28         300         200801       28       500
#
#    EPISODE_ID  EVENT_ID          STATE  STATE_FIPS  YEAR MONTH_NAME  \
# 0       14216     79884  NEW HAMPSHIRE          33  2008   February
# 1       15549     88334  NEW HAMPSHIRE          33  2008      April
# 2       14773     83820  NEW HAMPSHIRE          33  2008      March
# 3       13559     75727  NEW HAMPSHIRE          33  2008    January
# 4       25148    146588  NEW HAMPSHIRE          33  2008   December
# 5       25173    146824  NEW HAMPSHIRE          33  2008   December
# 6       25154    146673  NEW HAMPSHIRE          33  2008   December
# 7       12469     68371       ARKANSAS           5  2008   February
# 8       11835     67398       ARKANSAS           5  2008    January
# 9       12423     68005        ARIZONA           4  2008    January
#
#           EVENT_TYPE CZ_TYPE  CZ_FIPS               CZ_NAME  WFO  \
# 0         Heavy Snow       Z       12  EASTERN HILLSBOROUGH  BOX
# 1          High Wind       Z       12  EASTERN HILLSBOROUGH  BOX
# 2         Heavy Snow       Z       12  EASTERN HILLSBOROUGH  BOX
# 3         Heavy Snow       Z       12  EASTERN HILLSBOROUGH  BOX
# 4         Heavy Snow       Z       12  EASTERN HILLSBOROUGH  BOX
# 5          Ice Storm       Z       12  EASTERN HILLSBOROUGH  BOX
# 6         Heavy Snow       Z       12  EASTERN HILLSBOROUGH  BOX
# 7               Hail       C      127                 SCOTT  LZK
# 8  Thunderstorm Wind       C       95                MONROE  LZK
# 9              Flood       C       19                  PIMA  TWC
#
#       BEGIN_DATE_TIME CZ_TIMEZONE       END_DATE_TIME  INJURIES_DIRECT  \
# 0  22-FEB-08 13:00:00       EST-5  22-FEB-08 22:00:00                0
# 1  01-APR-08 03:52:00       EST-5  01-APR-08 03:52:00                0
# 2  01-MAR-08 00:00:00       EST-5  01-MAR-08 13:20:00                0
# 3  14-JAN-08 05:00:00       EST-5  14-JAN-08 17:00:00                0
# 4  19-DEC-08 13:53:00       EST-5  21-DEC-08 02:00:00                0
# 5  11-DEC-08 04:12:00       EST-5  12-DEC-08 09:53:00                0
# 6  21-DEC-08 07:44:00       EST-5  21-DEC-08 23:59:00                0
# 7  05-FEB-08 16:15:00       CST-6  05-FEB-08 16:15:00                0
# 8  08-JAN-08 13:20:00       CST-6  08-JAN-08 13:20:00                0
# 9  28-JAN-08 03:00:00       MST-7  28-JAN-08 05:00:00                0
#
#    INJURIES_INDIRECT  DEATHS_DIRECT  DEATHS_INDIRECT DAMAGE_PROPERTY  \
# 0                  0              0                0           0.00K
# 1                  0              0                0           0.00K
# 2                  0              0                0           0.00K
# 3                  0              0                0          10.00K
# 4                  0              0                0           0.00K
# 5                  0              0                0          15.00M
# 6                  0              0                0           0.00K
# 7                  0              0                0           0.00K
# 8                  0              0                0             NaN
# 9                  0              0                0           0.00K
#
#   DAMAGE_CROPS           SOURCE  MAGNITUDE MAGNITUDE_TYPE FLOOD_CAUSE  \
# 0        0.00K           Public        NaN            NaN         NaN
# 1        0.00K    Amateur Radio      52.00             MG         NaN
# 2        0.00K  Trained Spotter        NaN            NaN         NaN
# 3        0.00K  Trained Spotter        NaN            NaN         NaN
# 4        0.00K  Trained Spotter        NaN            NaN         NaN
# 5        0.00K    Amateur Radio        NaN            NaN         NaN
# 6        0.00K  Trained Spotter        NaN            NaN         NaN
# 7        0.00K  Law Enforcement       1.75            NaN         NaN
# 8          NaN  Law Enforcement      50.00             EG         NaN
# 9        0.00K        Newspaper        NaN            NaN  Heavy Rain
#
#    CATEGORY TOR_F_SCALE  TOR_LENGTH  TOR_WIDTH TOR_OTHER_WFO  \
# 0       NaN         NaN         NaN        NaN           NaN
# 1       NaN         NaN         NaN        NaN           NaN
# 2       NaN         NaN         NaN        NaN           NaN
# 3       NaN         NaN         NaN        NaN           NaN
# 4       NaN         NaN         NaN        NaN           NaN
# 5       NaN         NaN         NaN        NaN           NaN
# 6       NaN         NaN         NaN        NaN           NaN
# 7       NaN         NaN         NaN        NaN           NaN
# 8       NaN         NaN         NaN        NaN           NaN
# 9       NaN         NaN         NaN        NaN           NaN
#
#   TOR_OTHER_CZ_STATE  TOR_OTHER_CZ_FIPS TOR_OTHER_CZ_NAME  BEGIN_RANGE  \
# 0                NaN                NaN               NaN          NaN
# 1                NaN                NaN               NaN          NaN
# 2                NaN                NaN               NaN          NaN
# 3                NaN                NaN               NaN          NaN
# 4                NaN                NaN               NaN          NaN
# 5                NaN                NaN               NaN          NaN
# 6                NaN                NaN               NaN          NaN
# 7                NaN                NaN               NaN          0.0
# 8                NaN                NaN               NaN          0.0
# 9                NaN                NaN               NaN         38.0
#
#   BEGIN_AZIMUTH BEGIN_LOCATION  END_RANGE END_AZIMUTH END_LOCATION  BEGIN_LAT  \
# 0           NaN            NaN        NaN         NaN          NaN        NaN
# 1           NaN            NaN        NaN         NaN          NaN        NaN
# 2           NaN            NaN        NaN         NaN          NaN        NaN
# 3           NaN            NaN        NaN         NaN          NaN        NaN
# 4           NaN            NaN        NaN         NaN          NaN        NaN
# 5           NaN            NaN        NaN         NaN          NaN        NaN
# 6           NaN            NaN        NaN         NaN          NaN        NaN
# 7             N            HON        0.0           N          HON     34.930
# 8             N    HOLLY GROVE        0.0           N  HOLLY GROVE     34.600
# 9             W       CASCABEL       38.0           W     CASCABEL     32.375
#
#    BEGIN_LON  END_LAT   END_LON  \
# 0        NaN      NaN       NaN
# 1        NaN      NaN       NaN
# 2        NaN      NaN       NaN
# 3        NaN      NaN       NaN
# 4        NaN      NaN       NaN
# 5        NaN      NaN       NaN
# 6        NaN      NaN       NaN
# 7   -94.1800  34.9300  -94.1800
# 8   -91.2000  34.6000  -91.2000
# 9  -111.0101  32.3691 -111.0156
#
#                                    EPISODE_NARRATIVE  \
# 0  A noreaster moved up the coast southeast of Ca...
# 1  Strong southwest flow behind a warm front allo...
# 2  Low pressure tracked from the Great Lakes acro...
# 3  Low pressure moved up the Atlantic coast and s...
# 4  An intensifying coastal low spread heavy snow ...
# 5  A cold frontal boundary dropped south of New E...
# 6  A coastal storm moved southeast of Nantucket i...
# 7  Early on the 5th, a strong storm system approa...
# 8  Severe thunderstorms affected a large part of ...
# 9  A trough of low pressure off the Western U.S. ...
#
#                                      EVENT_NARRATIVE DATA_SOURCE
# 0                                                NaN         CSV
# 1  An amateur radio operator recorded a wind gust...         CSV
# 2                                                NaN         CSV
# 3                                                NaN         CSV
# 4  Six to eight inches of snow fell across easter...         CSV
# 5  Half an inch of ice accumulated on exposed sur...         CSV
# 6  Seven to twelve inches of snow fell across eas...         CSV
# 7                                                NaN         CSV
# 8             Trees and power lines were blown down.         CSV
# 9  A swift water rescue occurred about 4 am at th...         CSV

# %%
data = raw.copy()

# --------------------- CLEANING ---------------------
# split and BEGIN_YEARMONTH + END_YEARMONTH columns into 2 columns each --> YEAR + MONTH
begin_year = data['BEGIN_YEARMONTH'].astype(str).str[:4]
begin_month = data['BEGIN_YEARMONTH'].astype(str).str[4:]
data['BEGIN_YEAR'] = begin_year
data['BEGIN_MONTH'] = begin_month
#data.drop(columns=['BEGIN_YEARMONTH'], inplace=True)

end_year = data['END_YEARMONTH'].astype(str).str[:4]
end_month = data['END_YEARMONTH'].astype(str).str[4:]
data['END_YEAR'] = end_year
data['END_MONTH'] = end_month
#data.drop(columns=['END_YEARMONTH'], inplace=True)

# add begin and end dates and times in YYYY-MM-DD HH:MM:SS format
begin = data['BEGIN_YEAR'].map(str) + '-' + data['BEGIN_MONTH'].map(str) + '-' + data['BEGIN_DAY'].map(str) + ' '
hour = data['BEGIN_TIME'].astype(str).str[:-2]
hour = hour.apply(lambda x: '{0:0>2}'.format(x))
minute = data['BEGIN_TIME'].astype(str).str[-2:]
minute = minute.apply(lambda x: '{0:0>2}'.format(x))
time = hour.map(str) + ':' + minute.map(str) + ':00'
data['BEGIN'] = begin+time

end = data['END_YEAR'].map(str) + '-' + data['END_MONTH'].map(str) + '-' + data['END_DAY'].map(str) + ' '
e_hour = data['END_TIME'].astype(str).str[:-2]
e_hour = e_hour.apply(lambda x: '{0:0>2}'.format(x))
e_minute = data['END_TIME'].astype(str).str[-2:]
e_minute = e_minute.apply(lambda x: '{0:0>2}'.format(x))
e_time = e_hour.map(str) + ':' + e_minute.map(str) + ':00'
data['END'] = end+e_time

# add duration column
duration = pd.to_datetime(data['END']) - pd.to_datetime(data['BEGIN'])
                   
data['DURATION_seconds'] = ((duration.dt.total_seconds()))    

#drops
data = data.drop("BEGIN_YEARMONTH", axis = 1)
data = data.drop("END_YEARMONTH", axis = 1)
data = data.drop("EPISODE_ID", axis = 1)
data = data.drop("EVENT_ID", axis = 1)
data = data.drop("STATE_FIPS", axis = 1)
data = data.drop("BEGIN_DAY", axis = 1)
data = data.drop("BEGIN_TIME", axis = 1)
data = data.drop("END_DAY", axis = 1)
data = data.drop("END_TIME", axis = 1)

data = data.drop("CATEGORY", axis = 1)
data = data.drop("CZ_TYPE", axis = 1)
data = data.drop("CZ_FIPS", axis = 1)
data = data.drop("CZ_NAME", axis = 1)
data = data.drop("TOR_OTHER_WFO", axis = 1)
data = data.drop("TOR_OTHER_CZ_NAME", axis = 1)
data = data.drop("TOR_OTHER_CZ_STATE", axis = 1)
data = data.drop("TOR_OTHER_CZ_FIPS", axis = 1)
data = data.drop("DATA_SOURCE", axis = 1)

data = data.drop("WFO",axis = 1)
data = data.drop("END_DATE_TIME",axis = 1)
data = data.drop("CZ_TIMEZONE",axis = 1)
data = data.drop("BEGIN_RANGE",axis = 1)
data = data.drop("END_RANGE",axis = 1)
data = data.drop("BEGIN_AZIMUTH",axis = 1)
data = data.drop("END_AZIMUTH",axis = 1)
data = data.drop("BEGIN_YEAR",axis = 1)
data = data.drop("BEGIN_MONTH",axis = 1)
data = data.drop("END_YEAR",axis = 1)
data = data.drop("END_MONTH",axis = 1)
data = data.drop("BEGIN",axis = 1)
data = data.drop("END",axis = 1)

#change DAMAGE_PROPERTY and DAMAGE_CROPS type from #.##K to float
def convertToFloat(x):
    x = str(x)
    if(x[-1]=='K'):
        return(float(x[0:-1])*1000)
    elif(x[-1]=='M'):
        return(float(x[0:-1])*1000000)
    elif(x[-1]=='B'):
        return(float(x[0:-1])*1000000000)
    else:
        return(0.0)

    
#print(pd.value_counts(data.DAMAGE_PROPERTY))
#print(pd.value_counts(data.DAMAGE_CROPS))
data['DAMAGE_PROPERTY'].fillna(0.0, inplace=True)
data['DAMAGE_PROPERTY'] = data['DAMAGE_PROPERTY'].apply(convertToFloat)

data['DAMAGE_CROPS'].fillna(0.0, inplace=True)
data['DAMAGE_CROPS'] = data['DAMAGE_CROPS'].apply(convertToFloat)


#remove the row if no location information is provided
#note this removes 250501 rows, reducing our dataset by 37%
data = data[pd.notnull(data['BEGIN_LOCATION'])]
data = data[pd.notnull(data['END_LOCATION'])]

# --------------------- FEATURE ENGINEERING ---------------------
#separates hail size / wind speed MAGNITUDE
data['WIND_SPEED'] = np.where(data['MAGNITUDE_TYPE'].isin(['MG','EG']), data['MAGNITUDE'], np.NaN)
data['HAIL_SIZE'] = np.where(data['MAGNITUDE_TYPE'].isna(), data['MAGNITUDE'], np.NaN)


#bin the property damages
bins = [0, 2500, 5000, 10000, 20000, 30000, 40000, 50000, 75000, 100000, 200000, 300000, 400000, 500000,
        600000, 700000, 800000, 900000, 1000000, 1000000000]
labels = [str('0 to 2.5k'), str('2.5k to 5k'),str('5k to 10k'),str('10k to 20k'),str('20k to 30k'),str('30k to 40k'),
          str('40k to 50k'),str('50k to 75k'),str('75k to 100k'),str('100k to 200k'),str('200k to 300k'),
          str('300k to 400k'),str('400k to 500k'),str('500k to 600k'),str('600k to 700k'),str('700k to 800k'),
          str('800k to 900k'),str('900k to 1B'),str('greater than 1B')]

data['BINNED_PROPERTY_DAMAGE'] = pd.cut(data['DAMAGE_PROPERTY'],include_lowest=True, bins=bins, labels=labels)

#divide the data into 12 distinct groups by event type:
pd.value_counts(data.EVENT_TYPE)
"""
Wind (COLE):
    Thunderstorm Wind
    High Wind
    Marine Thunderstorm Wind
    Marine High Wind
    Strong Wind
    Marine Strong Wind

Winter Weather (ETHAN):
    Winter Weather
    Winter Storm
    Heavy Snow
    Blizzard
    Frost/Freeze
    Ice Storm
    Sleet
    Lake-Effect Snow

Rain (FREYA):
    Heavy Rain

Hail (RUOCHEN):
    Hail
    Marine Hail

Flood (FREYA):
    Flash Flood
    Flood
    Coastal Flood
    Lakeshore Flood

Drought (ETHAN):
    Drought

Tornado (COLE):
    Tornado

Heat (ETHAN):
    Heat
    Excessive Heat

Cold (COLE):
    Cold/Wind Chill
    Extreme Cold/Wind Chill

Lightning (FREYA):
    Lightning

Wildfire (RUOCHEN):
    Wildfire

Tides/Currents (RUOCHEN):
    High Surf
    Rip Current
    Astronomical Low Tide
    Storm Surge/Tide
"""
data.columns
data.head(50)
# Out:
#               STATE  YEAR MONTH_NAME                EVENT_TYPE  \
# 7          ARKANSAS  2008   February                      Hail
# 8          ARKANSAS  2008    January         Thunderstorm Wind
# 9           ARIZONA  2008    January                     Flood
# 11         ILLINOIS  2008   December         Thunderstorm Wind
# 12    LAKE MICHIGAN  2008   December  Marine Thunderstorm Wind
# 13          INDIANA  2008   December         Thunderstorm Wind
# 27   SOUTH CAROLINA  2008      March         Thunderstorm Wind
# 28   SOUTH CAROLINA  2008      March         Thunderstorm Wind
# 29   SOUTH CAROLINA  2008        May                      Hail
# 30   SOUTH CAROLINA  2008        May                      Hail
# 31          GEORGIA  2008        May                      Hail
# 32          GEORGIA  2008        May                      Hail
# 33   SOUTH CAROLINA  2008        May                      Hail
# 34   SOUTH CAROLINA  2008        May         Thunderstorm Wind
# 35   SOUTH CAROLINA  2008        May                      Hail
# 36   SOUTH CAROLINA  2008        May                      Hail
# 37            TEXAS  2008      April                      Hail
# 38            TEXAS  2008      April                      Hail
# 39            TEXAS  2008      April                      Hail
# 44        WISCONSIN  2008       July         Thunderstorm Wind
# 45        MINNESOTA  2008       July         Thunderstorm Wind
# 46        MINNESOTA  2008       July         Thunderstorm Wind
# 47        MINNESOTA  2008       July         Thunderstorm Wind
# 50   ATLANTIC SOUTH  2008   December  Marine Thunderstorm Wind
# 70        MINNESOTA  2008       July                      Hail
# 71        MINNESOTA  2008       July                      Hail
# 72        MINNESOTA  2008       July                      Hail
# 73        MINNESOTA  2008       July                      Hail
# 74        MINNESOTA  2008       July                      Hail
# 75        MINNESOTA  2008       July         Thunderstorm Wind
# 79         MISSOURI  2008   December         Thunderstorm Wind
# 80         MISSOURI  2008   December         Thunderstorm Wind
# 81         MISSOURI  2008   December         Thunderstorm Wind
# 82         MISSOURI  2008   December         Thunderstorm Wind
# 83   GULF OF MEXICO  2008   December  Marine Thunderstorm Wind
# 84   GULF OF MEXICO  2008   December  Marine Thunderstorm Wind
# 94            TEXAS  2008   February                      Hail
# 97         ILLINOIS  2008   December               Flash Flood
# 99        TENNESSEE  2008    January         Thunderstorm Wind
# 100       TENNESSEE  2008    January         Thunderstorm Wind
# 101       TENNESSEE  2008    January         Thunderstorm Wind
# 103        ILLINOIS  2008       June         Thunderstorm Wind
# 104        ILLINOIS  2008       June         Thunderstorm Wind
# 105        ILLINOIS  2008       June         Thunderstorm Wind
# 106        ILLINOIS  2008       June         Thunderstorm Wind
# 107        ILLINOIS  2008       June                      Hail
# 108        ILLINOIS  2008       June         Thunderstorm Wind
# 109  SOUTH CAROLINA  2008        May                      Hail
# 110  SOUTH CAROLINA  2008        May                      Hail
# 111  SOUTH CAROLINA  2008        May                      Hail
#
#         BEGIN_DATE_TIME  INJURIES_DIRECT  INJURIES_INDIRECT  DEATHS_DIRECT  \
# 7    05-FEB-08 16:15:00                0                  0              0
# 8    08-JAN-08 13:20:00                0                  0              0
# 9    28-JAN-08 03:00:00                0                  0              0
# 11   27-DEC-08 14:04:00                0                  0              0
# 12   27-DEC-08 15:20:00                0                  0              0
# 13   27-DEC-08 14:45:00                0                  0              0
# 27   04-MAR-08 20:58:00                0                  0              0
# 28   04-MAR-08 21:12:00                0                  0              0
# 29   05-MAY-08 18:30:00                0                  0              0
# 30   05-MAY-08 14:15:00                0                  0              0
# 31   10-MAY-08 04:30:00                0                  0              0
# 32   10-MAY-08 19:47:00                0                  0              0
# 33   10-MAY-08 04:42:00                0                  0              0
# 34   10-MAY-08 05:17:00                0                  0              0
# 35   10-MAY-08 05:12:00                0                  0              0
# 36   10-MAY-08 05:30:00                0                  0              0
# 37   25-APR-08 17:49:00                0                  0              0
# 38   25-APR-08 17:58:00                0                  0              0
# 39   25-APR-08 18:00:00                0                  0              0
# 44   11-JUL-08 21:00:00                0                  0              0
# 45   11-JUL-08 20:18:00                0                  0              0
# 46   11-JUL-08 19:48:00                0                  0              0
# 47   11-JUL-08 18:25:00                0                  0              0
# 50   11-DEC-08 12:22:00                0                  0              0
# 70   11-JUL-08 20:20:00                0                  0              0
# 71   11-JUL-08 20:36:00                0                  0              0
# 72   11-JUL-08 20:45:00                0                  0              0
# 73   11-JUL-08 21:11:00                0                  0              0
# 74   11-JUL-08 21:14:00                0                  0              0
# 75   11-JUL-08 18:00:00                0                  0              0
# 79   27-DEC-08 12:59:00                0                  0              0
# 80   27-DEC-08 12:30:00                0                  0              0
# 81   27-DEC-08 12:25:00                0                  0              0
# 82   27-DEC-08 11:53:00                0                  0              0
# 83   11-DEC-08 12:26:00                0                  0              0
# 84   11-DEC-08 12:40:00                0                  0              0
# 94   05-FEB-08 19:40:00                0                  0              0
# 97   27-DEC-08 16:00:00                0                  0              0
# 99   29-JAN-08 19:48:00                0                  0              0
# 100  29-JAN-08 19:50:00                0                  0              0
# 101  29-JAN-08 19:55:00                0                  0              0
# 103  07-JUN-08 13:49:00                0                  0              0
# 104  07-JUN-08 13:55:00                0                  0              0
# 105  07-JUN-08 14:30:00                0                  0              0
# 106  07-JUN-08 14:47:00                0                  0              0
# 107  08-JUN-08 18:52:00                0                  0              0
# 108  08-JUN-08 19:06:00                0                  0              0
# 109  10-MAY-08 06:30:00                0                  0              0
# 110  10-MAY-08 06:50:00                0                  0              0
# 111  10-MAY-08 15:26:00                0                  0              0
#
#      DEATHS_INDIRECT  DAMAGE_PROPERTY  DAMAGE_CROPS                  SOURCE  \
# 7                  0              0.0           0.0         Law Enforcement
# 8                  0              0.0           0.0         Law Enforcement
# 9                  0              0.0           0.0               Newspaper
# 11                 0              0.0           0.0                  Public
# 12                 0              0.0           0.0           C-MAN Station
# 13                 0              0.0           0.0       Emergency Manager
# 27                 0              0.0           0.0           Amateur Radio
# 28                 0              0.0           0.0         Law Enforcement
# 29                 0              0.0           0.0                  Public
# 30                 0              0.0           0.0         Law Enforcement
# 31                 0              0.0           0.0         Law Enforcement
# 32                 0              0.0           0.0  Fire Department/Rescue
# 33                 0              0.0           0.0         Law Enforcement
# 34                 0              0.0           0.0           Amateur Radio
# 35                 0              0.0           0.0           Amateur Radio
# 36                 0              0.0           0.0           Amateur Radio
# 37                 0           5000.0           0.0           Amateur Radio
# 38                 0           5000.0           0.0           Amateur Radio
# 39                 0              0.0           0.0           Amateur Radio
# 44                 0              0.0           0.0       Emergency Manager
# 45                 0              0.0           0.0         Trained Spotter
# 46                 0              0.0           0.0            Storm Chaser
# 47                 0              0.0           0.0         Trained Spotter
# 50                 0              0.0           0.0                 Mesonet
# 70                 0              0.0           0.0         Trained Spotter
# 71                 0              0.0           0.0         Trained Spotter
# 72                 0              0.0           0.0         Trained Spotter
# 73                 0              0.0           0.0         Trained Spotter
# 74                 0              0.0           0.0         Trained Spotter
# 75                 0              0.0           0.0         Trained Spotter
# 79                 0            500.0           0.0           Amateur Radio
# 80                 0           5000.0           0.0           Amateur Radio
# 81                 0           5000.0           0.0                  Public
# 82                 0           5000.0           0.0         Law Enforcement
# 83                 0              0.0           0.0           C-MAN Station
# 84                 0              0.0           0.0                 Mesonet
# 94                 0           3000.0           0.0         Law Enforcement
# 97                 0              0.0           0.0         Trained Spotter
# 99                 0            500.0           0.0         Law Enforcement
# 100                0           1000.0           0.0         Law Enforcement
# 101                0           1000.0           0.0         Law Enforcement
# 103                0              0.0           0.0                  Public
# 104                0              0.0           0.0         Law Enforcement
# 105                0              0.0           0.0         Law Enforcement
# 106                0              0.0           0.0         Law Enforcement
# 107                0              0.0           0.0         Trained Spotter
# 108                0              0.0           0.0       Emergency Manager
# 109                0              0.0           0.0         Law Enforcement
# 110                0              0.0           0.0         Law Enforcement
# 111                0              0.0           0.0                  Public
#
#      MAGNITUDE MAGNITUDE_TYPE             FLOOD_CAUSE TOR_F_SCALE  TOR_LENGTH  \
# 7         1.75            NaN                     NaN         NaN         NaN
# 8        50.00             EG                     NaN         NaN         NaN
# 9          NaN            NaN              Heavy Rain         NaN         NaN
# 11       65.00             EG                     NaN         NaN         NaN
# 12       39.00             MG                     NaN         NaN         NaN
# 13       52.00             EG                     NaN         NaN         NaN
# 27       55.00             EG                     NaN         NaN         NaN
# 28       50.00             EG                     NaN         NaN         NaN
# 29        0.88            NaN                     NaN         NaN         NaN
# 30        1.75            NaN                     NaN         NaN         NaN
# 31        0.88            NaN                     NaN         NaN         NaN
# 32        1.00            NaN                     NaN         NaN         NaN
# 33        0.88            NaN                     NaN         NaN         NaN
# 34       70.00             EG                     NaN         NaN         NaN
# 35        0.88            NaN                     NaN         NaN         NaN
# 36        1.75            NaN                     NaN         NaN         NaN
# 37        1.75            NaN                     NaN         NaN         NaN
# 38        1.75            NaN                     NaN         NaN         NaN
# 39        1.50            NaN                     NaN         NaN         NaN
# 44       52.00             EG                     NaN         NaN         NaN
# 45       60.00             EG                     NaN         NaN         NaN
# 46       50.00             EG                     NaN         NaN         NaN
# 47       55.00             EG                     NaN         NaN         NaN
# 50       34.00             MG                     NaN         NaN         NaN
# 70        0.75            NaN                     NaN         NaN         NaN
# 71        0.75            NaN                     NaN         NaN         NaN
# 72        0.75            NaN                     NaN         NaN         NaN
# 73        0.88            NaN                     NaN         NaN         NaN
# 74        0.75            NaN                     NaN         NaN         NaN
# 75       50.00             EG                     NaN         NaN         NaN
# 79       50.00             EG                     NaN         NaN         NaN
# 80       50.00             EG                     NaN         NaN         NaN
# 81       50.00             EG                     NaN         NaN         NaN
# 82       50.00             EG                     NaN         NaN         NaN
# 83       37.00             MG                     NaN         NaN         NaN
# 84       37.00             MG                     NaN         NaN         NaN
# 94        1.75            NaN                     NaN         NaN         NaN
# 97         NaN            NaN  Heavy Rain / Snow Melt         NaN         NaN
# 99       50.00             EG                     NaN         NaN         NaN
# 100      50.00             EG                     NaN         NaN         NaN
# 101      50.00             EG                     NaN         NaN         NaN
# 103      52.00             EG                     NaN         NaN         NaN
# 104      52.00             EG                     NaN         NaN         NaN
# 105      56.00             EG                     NaN         NaN         NaN
# 106      56.00             EG                     NaN         NaN         NaN
# 107       0.75            NaN                     NaN         NaN         NaN
# 108      56.00             EG                     NaN         NaN         NaN
# 109       0.88            NaN                     NaN         NaN         NaN
# 110       0.75            NaN                     NaN         NaN         NaN
# 111       0.75            NaN                     NaN         NaN         NaN
#
#      TOR_WIDTH          BEGIN_LOCATION            END_LOCATION  BEGIN_LAT  \
# 7          NaN                     HON                     HON    34.9300
# 8          NaN             HOLLY GROVE             HOLLY GROVE    34.6000
# 9          NaN                CASCABEL                CASCABEL    32.3750
# 11         NaN                  ASHKUM                  ASHKUM    40.8800
# 12         NaN            BURNS HARBOR            BURNS HARBOR    41.6470
# 13         NaN                  FOWLER                  FOWLER    40.6200
# 27         NaN                    IRMO                    IRMO    34.0800
# 28         NaN                    WARD               BATESBURG    33.8500
# 29         NaN        CHERAW MUNI ARPT        CHERAW MUNI ARPT    34.7200
# 30         NaN               CLAREMONT               CLAREMONT    33.9460
# 31         NaN              LINCOLNTON              LINCOLNTON    33.7800
# 32         NaN              WAYNESBORO              WAYNESBORO    33.0800
# 33         NaN              MERIWETHER              MERIWETHER    33.6500
# 34         NaN               BELVEDERE               BELVEDERE    33.5700
# 35         NaN                 MORGANA                 MORGANA    33.5900
# 36         NaN                   AIKEN                   AIKEN    33.5211
# 37         NaN              TAYLOR VLY              TAYLOR VLY    31.0300
# 38         NaN  LITTLE RIVER - ACADEMY  LITTLE RIVER - ACADEMY    30.9864
# 39         NaN                  TEMPLE                  TEMPLE    31.1000
# 44         NaN         NORTH MENOMONIE         NORTH MENOMONIE    44.9000
# 45         NaN            BUFFALO LAKE            BUFFALO LAKE    44.7300
# 46         NaN                 MANKATO                 MANKATO    44.1700
# 47         NaN                ST CLOUD                ST CLOUD    45.5700
# 50         NaN        PORT ROYAL SOUND        PORT ROYAL SOUND    32.2200
# 70         NaN                 MANKATO                 MANKATO    44.1400
# 71         NaN             BRIDGEWATER             BRIDGEWATER    44.4000
# 72         NaN          MINNESOTA LAKE          MINNESOTA LAKE    43.8400
# 73         NaN                FREEBORN                FREEBORN    43.8000
# 74         NaN                FREEBORN                FREEBORN    43.8100
# 75         NaN               ST JOSEPH               ST JOSEPH    45.5600
# 79         NaN                  WASOLA                  WASOLA    36.7900
# 80         NaN                  WASOLA                  WASOLA    36.7900
# 81         NaN             SILOAM SPGS             SILOAM SPGS    36.8000
# 82         NaN          ROCKAWAY BEACH          ROCKAWAY BEACH    36.7000
# 83         NaN                KEY WEST                KEY WEST    24.4600
# 84         NaN                KEY WEST                KEY WEST    24.5672
# 94         NaN              SHENANDOAH              SHENANDOAH    30.1800
# 97         NaN               WADSWORTH          GRANDWOOD PARK    42.4508
# 99         NaN            MURFREESBORO            MURFREESBORO    35.7632
# 100        NaN            MURFREESBORO            MURFREESBORO    35.8500
# 101        NaN                    ROME                CARTHAGE    36.2454
# 103        NaN                MORRISON                MORRISON    41.8100
# 104        NaN            PROPHETSTOWN            PROPHETSTOWN    41.6700
# 105        NaN                  RODDEN                  RODDEN    42.2938
# 106        NaN                  WARREN             APPLE RIVER    42.4962
# 107        NaN                STOCKTON                STOCKTON    42.3500
# 108        NaN                    NORA                    NORA    42.4600
# 109        NaN              BLACKVILLE              BLACKVILLE    33.3500
# 110        NaN                 DENMARK                 DENMARK    33.3200
# 111        NaN                 WINDSOR                 WINDSOR    33.5005
#
#      BEGIN_LON  END_LAT   END_LON  \
# 7     -94.1800  34.9300  -94.1800
# 8     -91.2000  34.6000  -91.2000
# 9    -111.0101  32.3691 -111.0156
# 11    -87.9500  40.8800  -87.9500
# 12    -87.1470  41.6470  -87.1470
# 13    -87.3200  40.6200  -87.3200
# 27    -81.1800  34.0800  -81.1800
# 28    -81.7300  33.9000  -81.5500
# 29    -79.9700  34.7200  -79.9700
# 30    -80.6280  33.9460  -80.6280
# 31    -82.4800  33.7800  -82.4800
# 32    -82.1927  33.0800  -82.1582
# 33    -82.1700  33.6500  -82.1700
# 34    -82.0200  33.5700  -82.0200
# 35    -82.0200  33.5900  -82.0200
# 36    -81.7200  33.5500  -81.7200
# 37    -97.4200  31.0300  -97.4200
# 38    -97.3554  30.9864  -97.3554
# 39    -97.3500  31.1000  -97.3500
# 44    -91.9300  44.9000  -91.9300
# 45    -94.6200  44.7300  -94.6200
# 46    -94.0200  44.1700  -94.0200
# 47    -94.1700  45.5700  -94.1700
# 50    -80.7500  32.2200  -80.7500
# 70    -93.9900  44.1400  -93.9900
# 71    -93.2400  44.4000  -93.2400
# 72    -93.8300  43.8400  -93.8300
# 73    -93.5600  43.8000  -93.5600
# 74    -93.5600  43.8100  -93.5600
# 75    -94.3100  45.5600  -94.3100
# 79    -92.5800  36.7900  -92.5800
# 80    -92.5800  36.7900  -92.5800
# 81    -92.0400  36.8000  -92.0400
# 82    -93.1600  36.7000  -93.1600
# 83    -81.8800  24.4600  -81.8800
# 84    -81.7982  24.5672  -81.7982
# 94    -95.4500  30.1800  -95.4500
# 97    -87.9123  42.4000  -87.9126
# 99    -86.4200  35.7632  -86.4200
# 100   -86.3307  35.8500  -86.2236
# 101   -86.0395  36.3012  -85.8665
# 103   -89.9700  41.8100  -89.9700
# 104   -89.9300  41.6700  -89.9300
# 105   -90.3340  42.2938  -90.3340
# 106   -90.0065  42.4962  -90.0803
# 107   -90.0100  42.3500  -90.0100
# 108   -89.9400  42.4600  -89.9400
# 109   -81.2700  33.3500  -81.2700
# 110   -81.1500  33.3200  -81.1500
# 111   -81.4955  33.5005  -81.4955
#
#                                      EPISODE_NARRATIVE  \
# 7    Early on the 5th, a strong storm system approa...
# 8    Severe thunderstorms affected a large part of ...
# 9    A trough of low pressure off the Western U.S. ...
# 11   Heavy rain fell across northern Illinois durin...
# 12   Strong thunderstorms moved across parts of far...
# 13   Heavy rain fell across northwest Indiana durin...
# 27   Thunderstorms produced a couple of small torna...
# 28   Thunderstorms produced a couple of small torna...
# 29   A cluster of pulse storms moved through the Mi...
# 30   A cluster of pulse storms moved through the Mi...
# 31   Cluster pulse storms moved through the CSRA an...
# 32   Cluster pulse storms moved through the CSRA an...
# 33   Clusters of pulse storms moved across the CSRA...
# 34   Clusters of pulse storms moved across the CSRA...
# 35   Clusters of pulse storms moved across the CSRA...
# 36   Clusters of pulse storms moved across the CSRA...
# 37   A strong line of storms as well as several dis...
# 38   A strong line of storms as well as several dis...
# 39   A strong line of storms as well as several dis...
# 44   Instability ahead of a cold front which moved ...
# 45   Instability ahead of a cold front which moved ...
# 46   Instability ahead of a cold front which moved ...
# 47   Instability ahead of a cold front which moved ...
# 50   A squall line developed in advance of a cold f...
# 70   Instability ahead of a cold front which moved ...
# 71   Instability ahead of a cold front which moved ...
# 72   Instability ahead of a cold front which moved ...
# 73   Instability ahead of a cold front which moved ...
# 74   Instability ahead of a cold front which moved ...
# 75   Instability ahead of a cold front which moved ...
# 79   A large squall line of thunderstorms impacted ...
# 80   A large squall line of thunderstorms impacted ...
# 81   A large squall line of thunderstorms impacted ...
# 82   A large squall line of thunderstorms impacted ...
# 83   A narrow squall line moved eastward at 20 to 2...
# 84   A narrow squall line moved eastward at 20 to 2...
# 94   Isolated severe thunderstorms passed across th...
# 97   Heavy rain fell across northern Illinois durin...
# 99   On the evening of January 29, 2008, severe thu...
# 100  On the evening of January 29, 2008, severe thu...
# 101  On the evening of January 29, 2008, severe thu...
# 103  Scattered showers and thunderstorms moved nort...
# 104  Scattered showers and thunderstorms moved nort...
# 105  Scattered showers and thunderstorms moved nort...
# 106  Scattered showers and thunderstorms moved nort...
# 107  Thunderstorms moved across parts of northwest ...
# 108  Thunderstorms moved across parts of northwest ...
# 109  Clusters of pulse storms moved across the CSRA...
# 110  Clusters of pulse storms moved across the CSRA...
# 111  Clusters of pulse storms moved across the CSRA...
#
#                                        EVENT_NARRATIVE  DURATION_seconds  \
# 7                                                  NaN               0.0
# 8               Trees and power lines were blown down.               0.0
# 9    A swift water rescue occurred about 4 am at th...            7200.0
# 11   A farmer reported buildings and vehicles moved...               0.0
# 12                                                 NaN               0.0
# 13                Wind gusts were estimated to 60 mph.               0.0
# 27   SKYWARN spotter reported trees and signs down ...               0.0
# 28   Sheriff reported small sheds destroyed and the...             720.0
# 29   Nickel size hail was reported near the Cheraw ...               0.0
# 30   The Highway Patrol reported golf ball size hai...               0.0
# 31    Sheriff reported nickel size hail in Lincolnton.               0.0
# 32         Fire department reported quarter size hail.             720.0
# 33                  Sheriff reported nickel size hail.               0.0
# 34   SKYWARN spotters reported trees and powerlines...               0.0
# 35   SKYWARN HAM radio operator reported nickel siz...               0.0
# 36   SKYWARN HAM radio spotters reported quarter to...             900.0
# 37   Golfball-size hail was reported between Belton...               0.0
# 38                                                 NaN               0.0
# 39                                                 NaN               0.0
# 44                           One tree reported felled.               0.0
# 45      Damage to grain tower, multipal trees toppled.               0.0
# 46   Medium size branch toppled onto automobile. Wi...               0.0
# 47   Two foot diameter tree toppled near corner of ...               0.0
# 50   A wind gust of 39 mph was measured by the Salt...               0.0
# 70   Hail occurred at Country Rd. 90 and Hwy. 22 in...               0.0
# 71                                                 NaN               0.0
# 72                                                 NaN               0.0
# 73                                                 NaN               0.0
# 74            Estimated winds of 55 mph also reported.               0.0
# 75                      One foot diameter tree downed.               0.0
# 79   Thunderstorm wind gusts knocked over a power p...               0.0
# 80   Severe thunderstorm wind gusts damaged a roof ...               0.0
# 81   A roof of a home was damaged from thunderstorm...               0.0
# 82   Numerous trees and power poles were knocked ov...               0.0
# 83   A wind gust of 37 knots (43 mph) was measured ...               0.0
# 84   A wind gust of 37 knots (43 mph) was measured ...               0.0
# 94   Windows of at least one residence were broken ...               0.0
# 97   Flood water was reported up to the foundations...           16200.0
# 99   Utility pole was snapped on Barfield-Crescent Rd.               0.0
# 100  Trees were blown down in the eastern part of t...             600.0
# 101  Trees and power lines were down around the cou...             600.0
# 103  Wind gusts estimated to be 60 mph blew down a ...               0.0
# 104  Wind gusts estimated to be 60 mph blew down a ...               0.0
# 105  Wind gusts estimated to be 65 mph blew down so...               0.0
# 106  Wind gusts estimated to be 65 mph blew down so...               0.0
# 107  Penny-sized hail fell in Stockton, IL at 7:52 ...               0.0
# 108  Winds estimated to be 65 mph blew a two and a ...               0.0
# 109                  Police reported nickel size hail.               0.0
# 110                  Sheriff reported penny size hail.               0.0
# 111                   Public reported penny size hail.               0.0
#
#      WIND_SPEED  HAIL_SIZE BINNED_PROPERTY_DAMAGE
# 7           NaN       1.75              0 to 2.5k
# 8          50.0        NaN              0 to 2.5k
# 9           NaN        NaN              0 to 2.5k
# 11         65.0        NaN              0 to 2.5k
# 12         39.0        NaN              0 to 2.5k
# 13         52.0        NaN              0 to 2.5k
# 27         55.0        NaN              0 to 2.5k
# 28         50.0        NaN              0 to 2.5k
# 29          NaN       0.88              0 to 2.5k
# 30          NaN       1.75              0 to 2.5k
# 31          NaN       0.88              0 to 2.5k
# 32          NaN       1.00              0 to 2.5k
# 33          NaN       0.88              0 to 2.5k
# 34         70.0        NaN              0 to 2.5k
# 35          NaN       0.88              0 to 2.5k
# 36          NaN       1.75              0 to 2.5k
# 37          NaN       1.75             2.5k to 5k
# 38          NaN       1.75             2.5k to 5k
# 39          NaN       1.50              0 to 2.5k
# 44         52.0        NaN              0 to 2.5k
# 45         60.0        NaN              0 to 2.5k
# 46         50.0        NaN              0 to 2.5k
# 47         55.0        NaN              0 to 2.5k
# 50         34.0        NaN              0 to 2.5k
# 70          NaN       0.75              0 to 2.5k
# 71          NaN       0.75              0 to 2.5k
# 72          NaN       0.75              0 to 2.5k
# 73          NaN       0.88              0 to 2.5k
# 74          NaN       0.75              0 to 2.5k
# 75         50.0        NaN              0 to 2.5k
# 79         50.0        NaN              0 to 2.5k
# 80         50.0        NaN             2.5k to 5k
# 81         50.0        NaN             2.5k to 5k
# 82         50.0        NaN             2.5k to 5k
# 83         37.0        NaN              0 to 2.5k
# 84         37.0        NaN              0 to 2.5k
# 94          NaN       1.75             2.5k to 5k
# 97          NaN        NaN              0 to 2.5k
# 99         50.0        NaN              0 to 2.5k
# 100        50.0        NaN              0 to 2.5k
# 101        50.0        NaN              0 to 2.5k
# 103        52.0        NaN              0 to 2.5k
# 104        52.0        NaN              0 to 2.5k
# 105        56.0        NaN              0 to 2.5k
# 106        56.0        NaN              0 to 2.5k
# 107         NaN       0.75              0 to 2.5k
# 108        56.0        NaN              0 to 2.5k
# 109         NaN       0.88              0 to 2.5k
# 110         NaN       0.75              0 to 2.5k
# 111         NaN       0.75              0 to 2.5k

# %%
# HEAVY RAIN MODEL
heavy_rain = data.copy()
heavy_rain = heavy_rain.loc[(heavy_rain['EVENT_TYPE'] == 'Heavy Rain')]

# Drop data that we don't want included in the model
heavy_rain = heavy_rain.drop(["INJURIES_DIRECT", 'INJURIES_INDIRECT', 'DEATHS_DIRECT', 'DEATHS_INDIRECT', 'DAMAGE_CROPS', 'DAMAGE_PROPERTY'], axis = 1)

# Drap data irrevelent to the Tornado Model
heavy_rain = heavy_rain.drop(["FLOOD_CAUSE",'HAIL_SIZE'], axis = 1)
# Drop columns with all null values
heavy_rain.loc[:, (heavy_rain != 0).any(axis=0)]
heavy_rain.dropna(how='all', axis=1, inplace=True)
heavy_rain.head(50)
# Out:
#                STATE  YEAR MONTH_NAME  EVENT_TYPE     BEGIN_DATE_TIME  \
# 216           HAWAII  2008   December  Heavy Rain  31-DEC-08 00:16:00
# 762           HAWAII  2008   December  Heavy Rain  31-DEC-08 01:33:00
# 764           HAWAII  2008   December  Heavy Rain  31-DEC-08 16:26:00
# 863   NORTH CAROLINA  2008   December  Heavy Rain  11-DEC-08 16:03:00
# 864   NORTH CAROLINA  2008   December  Heavy Rain  11-DEC-08 18:25:00
# 926          GEORGIA  2008   February  Heavy Rain  22-FEB-08 10:00:00
# 1209         FLORIDA  2008       June  Heavy Rain  10-JUN-08 14:30:00
# 1210         FLORIDA  2008       June  Heavy Rain  10-JUN-08 15:00:00
# 1360      CALIFORNIA  2008    January  Heavy Rain  04-JAN-08 00:00:00
# 1430         FLORIDA  2008       June  Heavy Rain  10-JUN-08 14:00:00
# 1692  NORTH CAROLINA  2008   December  Heavy Rain  11-DEC-08 17:30:00
# 1879         GEORGIA  2008   February  Heavy Rain  22-FEB-08 12:00:00
# 2078          HAWAII  2008   December  Heavy Rain  15-DEC-08 18:05:00
# 2079          HAWAII  2008   December  Heavy Rain  15-DEC-08 21:20:00
# 2080          HAWAII  2008   December  Heavy Rain  18-DEC-08 22:29:00
# 2081          HAWAII  2008   December  Heavy Rain  19-DEC-08 01:52:00
# 2435        NEW YORK  2008   December  Heavy Rain  25-DEC-08 15:30:00
# 2554  AMERICAN SAMOA  2008   November  Heavy Rain  24-NOV-08 16:58:00
# 2686            IOWA  2008       June  Heavy Rain  03-JUN-08 05:30:00
# 2986    RHODE ISLAND  2008   February  Heavy Rain  13-FEB-08 14:00:00
# 3160     PUERTO RICO  2008    October  Heavy Rain  07-OCT-08 17:10:00
# 3386         FLORIDA  2008       June  Heavy Rain  23-JUN-08 17:40:00
# 3473  NORTH CAROLINA  2008   December  Heavy Rain  10-DEC-08 22:00:00
# 3474  NORTH CAROLINA  2008   December  Heavy Rain  10-DEC-08 22:00:00
# 3475  NORTH CAROLINA  2008   December  Heavy Rain  10-DEC-08 22:00:00
# 3476  NORTH CAROLINA  2008   December  Heavy Rain  10-DEC-08 22:00:00
# 3735         GEORGIA  2008     August  Heavy Rain  07-AUG-08 16:08:00
# 3981         FLORIDA  2008       June  Heavy Rain  26-JUN-08 13:00:00
# 4287  NORTH CAROLINA  2008   December  Heavy Rain  10-DEC-08 22:00:00
# 4288  NORTH CAROLINA  2008   December  Heavy Rain  10-DEC-08 22:00:00
# 4289  NORTH CAROLINA  2008   December  Heavy Rain  10-DEC-08 22:00:00
# 4290  NORTH CAROLINA  2008   December  Heavy Rain  10-DEC-08 22:00:00
# 4292          NEVADA  2008   November  Heavy Rain  26-NOV-08 07:00:00
# 4295      CALIFORNIA  2008   November  Heavy Rain  08-NOV-08 22:22:00
# 5086         FLORIDA  2008       July  Heavy Rain  05-JUL-08 00:00:00
# 5417         ARIZONA  2008    January  Heavy Rain  06-JAN-08 00:00:00
# 5465       LOUISIANA  2008        May  Heavy Rain  14-MAY-08 15:30:00
# 5503         ARIZONA  2008    January  Heavy Rain  27-JAN-08 08:00:00
# 5504         ARIZONA  2008    January  Heavy Rain  27-JAN-08 09:00:00
# 5583         FLORIDA  2008       July  Heavy Rain  14-JUL-08 15:00:00
# 5584         FLORIDA  2008       July  Heavy Rain  15-JUL-08 11:00:00
# 5585         FLORIDA  2008       July  Heavy Rain  17-JUL-08 16:28:00
# 5586         FLORIDA  2008       July  Heavy Rain  17-JUL-08 17:00:00
# 5587         FLORIDA  2008       July  Heavy Rain  16-JUL-08 23:00:00
# 6029         FLORIDA  2008       July  Heavy Rain  25-JUL-08 16:58:00
# 6064         FLORIDA  2008       July  Heavy Rain  07-JUL-08 17:00:00
# 6252         ARIZONA  2008   February  Heavy Rain  04-FEB-08 07:00:00
# 6455         FLORIDA  2008       June  Heavy Rain  25-JUN-08 14:23:00
# 6456         FLORIDA  2008       June  Heavy Rain  25-JUN-08 16:00:00
# 6629          HAWAII  2008   February  Heavy Rain  09-FEB-08 02:39:00
#
#                          SOURCE        BEGIN_LOCATION          END_LOCATION  \
# 216   Official NWS Observations                 HUELO                  HANA
# 762   Official NWS Observations                KAHUKU         MILILANI TOWN
# 764   Official NWS Observations                  HANA              KIPAHULU
# 863               Amateur Radio             MILLBROOK             MILLBROOK
# 864             Trained Spotter             GOLDSBORO             GOLDSBORO
# 926             Trained Spotter              WAYCROSS              WAYCROSS
# 1209               NWS Employee              HIBERNIA              HIBERNIA
# 1210               NWS Employee         DOCTORS INLET         DOCTORS INLET
# 1360                       ASOS      (BIH)BISHOP ARPT      (BIH)BISHOP ARPT
# 1430            Trained Spotter             ARREDONDA             ARREDONDA
# 1692     Fire Department/Rescue          FAYETTEVILLE          FAYETTEVILLE
# 1879            Trained Spotter                BAXLEY                BAXLEY
# 2078  Official NWS Observations                KEKAHA                 KAPAA
# 2079  Official NWS Observations               PUNALUU               HALEIWA
# 2080  Official NWS Observations                PUUWAI                PUUWAI
# 2081  Official NWS Observations       KALALAU LOOKOUT          WAIMEA KAUAI
# 2435            Law Enforcement             NEW PALTZ             NEW PALTZ
# 2554  Official NWS Observations               VAITOGI             PAGO PAGO
# 2686            Trained Spotter               OTTUMWA               OTTUMWA
# 2986              Amateur Radio            PROVIDENCE            PROVIDENCE
# 3160          Emergency Manager             VEGA ALTA             VEGA ALTA
# 3386            Trained Spotter             ROCKLEDGE             ROCKLEDGE
# 3473            Trained Spotter            GATESVILLE            GATESVILLE
# 3474            Trained Spotter               AHOSKIE               AHOSKIE
# 3475                   CoCoRaHS               HENRICO               HENRICO
# 3476                       ASOS   (ECG)ELIZABETH CITY   (ECG)ELIZABETH CITY
# 3735            Trained Spotter                ARGYLE                ARGYLE
# 3981            Trained Spotter          JENSEN BEACH          JENSEN BEACH
# 4287            Trained Spotter               WINDSOR               WINDSOR
# 4288                   CoCoRaHS       JOHNSONS CORNER       JOHNSONS CORNER
# 4289            Trained Spotter               EDENTON               EDENTON
# 4290            Trained Spotter                MOYOCK                MOYOCK
# 4292            Broadcast Media        EAST LAS VEGAS        EAST LAS VEGAS
# 4295            Trained Spotter                MELVIN                FRESNO
# 5086                     Public          PENNEY FARMS          PENNEY FARMS
# 5417                  Newspaper    (PRC)PRESCOTT ARPT    (PRC)PRESCOTT ARPT
# 5465              COOP Observer            LIVINGSTON            LIVINGSTON
# 5503                  Newspaper   (FLG)FLAGSTAFF ARPT   (FLG)FLAGSTAFF ARPT
# 5504                  Newspaper      (0E4)PAYSON ARPT      (0E4)PAYSON ARPT
# 5583            Trained Spotter             HOLLISTER             HOLLISTER
# 5584            Trained Spotter         SANTA FE LAKE         SANTA FE LAKE
# 5585          Emergency Manager           PALM HARBOR           PALM HARBOR
# 5586            Trained Spotter         INDIAN TRAILS         INDIAN TRAILS
# 5587            Trained Spotter            PALM COAST            PALM COAST
# 6029              Amateur Radio           CEDAR HILLS           CEDAR HILLS
# 6064                     Public                WILCOX                WILCOX
# 6252                  Newspaper             SUNNYSIDE             SUNNYSIDE
# 6455              Amateur Radio              MONTAGUE              MONTAGUE
# 6456                       ASOS  (JAX)JACKSNVILLE INT  (JAX)JACKSNVILLE INT
# 6629  Official NWS Observations               PAAUHAU               NAALEHU
#
#       BEGIN_LAT  BEGIN_LON  END_LAT   END_LON  \
# 216     20.9172  -156.2428  20.7532 -155.9837
# 762     21.6788  -157.9444  21.4308 -158.0260
# 764     20.7614  -155.9875  20.6511 -156.0663
# 863     35.8500   -78.6200  35.8500  -78.6200
# 864     35.4000   -78.0100  35.4000  -78.0100
# 926     31.2100   -82.3600  31.2100  -82.3600
# 1209    30.0700   -81.7000  30.0700  -81.7000
# 1210    30.1000   -81.7300  30.1000  -81.7300
# 1360    37.3700  -118.3700  37.3700 -118.3700
# 1430    29.6300   -82.4200  29.6300  -82.4200
# 1692    35.0700   -78.9000  35.0700  -78.9000
# 1879    31.7600   -82.3500  31.7600  -82.3500
# 2078    21.9711  -159.7194  22.1080 -159.3292
# 2079    21.5828  -157.8900  21.5963 -158.1056
# 2080    21.9916  -160.0749  21.8055 -160.2246
# 2081    22.1570  -159.6533  21.9616 -159.6677
# 2435    41.7633   -74.0963  41.7633  -74.0963
# 2554   -14.3323  -170.8278 -14.2604 -170.5641
# 2686    41.0200   -92.4200  41.0200  -92.4200
# 2986    41.8200   -71.4300  41.8200  -71.4300
# 3160    18.4005   -66.3443  18.4002  -66.3438
# 3386    28.3200   -80.7300  28.3200  -80.7300
# 3473    36.4000   -76.7500  36.4000  -76.7500
# 3474    36.2800   -76.9800  36.2800  -76.9800
# 3475    36.5300   -77.8200  36.5300  -77.8200
# 3476    36.2700   -76.1800  36.2700  -76.1800
# 3735    31.0700   -82.6500  31.0700  -82.6500
# 3981    27.2500   -80.2300  27.2500  -80.2300
# 4287    36.0000   -76.9500  36.0000  -76.9500
# 4288    36.4300   -76.3000  36.4300  -76.3000
# 4289    36.0700   -76.6200  36.0700  -76.6200
# 4290    36.5300   -76.1800  36.5300  -76.1800
# 4292    36.1047  -115.0733  36.1047 -115.0733
# 4295    36.8300  -119.6800  36.8061 -119.7716
# 5086    29.9800   -81.8100  29.9800  -81.8100
# 5417    34.6500  -112.4200  34.6500 -112.4200
# 5465    30.5000   -90.7500  30.5000  -90.7500
# 5503    35.0481  -111.7701  34.8626 -111.8052
# 5504    34.0329  -111.3500  33.7434 -111.3500
# 5583    29.6200   -81.8100  29.6200  -81.8100
# 5584    29.7100   -82.0600  29.7100  -82.0600
# 5585    29.5700   -81.2300  29.5700  -81.2300
# 5586    29.5700   -81.2800  29.5700  -81.2800
# 5587    29.5700   -81.2100  29.5700  -81.2100
# 6029    30.2800   -81.7600  30.2800  -81.7600
# 6064    29.6366   -82.8839  29.6366  -82.8839
# 6252    31.4609  -110.9918  31.4609 -110.9918
# 6455    29.1500   -82.0100  29.1500  -82.0100
# 6456    30.4800   -81.7100  30.4800  -81.7100
# 6629    20.0766  -155.4126  19.0154 -155.5994
#
#                                       EPISODE_NARRATIVE  \
# 216   A persistent upper low/trough system continued...
# 762   A persistent upper low/trough system continued...
# 764   A persistent upper low/trough system continued...
# 863   A powerful upper level disturbance with associ...
# 864   A powerful upper level disturbance with associ...
# 926   A cold front swept across the region with a st...
# 1209  A passing upper level low enhanced sea breeze ...
# 1210  A passing upper level low enhanced sea breeze ...
# 1360  A series of powerful Pacific storms brought he...
# 1430  A passing upper level low enhanced sea breeze ...
# 1692  A powerful upper level disturbance with associ...
# 1879  A cold front swept across the region with a st...
# 2078  The Kona low that had severely impacted the is...
# 2079  The Kona low that had severely impacted the is...
# 2080  Another Kona low formed to the west of the Alo...
# 2081  Another Kona low formed to the west of the Alo...
# 2435  Heavy rainfall, combined with snowmelt led to ...
# 2554  An intense trough associated with a low pressu...
# 2686  A complex weather situation was in place durin...
# 2986  A low pressure system developed off the Mid-At...
# 3160  A low to mid level low pressure trough meander...
# 3386  The afternoon sea breeze remained close to the...
# 3473  The combination of a frontal boundary laying a...
# 3474  The combination of a frontal boundary laying a...
# 3475  The combination of a frontal boundary laying a...
# 3476  The combination of a frontal boundary laying a...
# 3735  A weak deformation zone was over the area whic...
# 3981         Coastal thunderstorms produced heavy rain.
# 4287  The combination of a frontal boundary laying a...
# 4288  The combination of a frontal boundary laying a...
# 4289  The combination of a frontal boundary laying a...
# 4290  The combination of a frontal boundary laying a...
# 4292  A Pacific storm system brought valley rain and...
# 4295  A Pacific storm arrived in Central California ...
# 5086  A weak short wave upper level trough and surfa...
# 5417  A strong pacific storm brought significant rai...
# 5465  Widespread heavy rainfall and strong to severe...
# 5503  A strong storm system moved across northern Ar...
# 5504  A strong storm system moved across northern Ar...
# 5583  An upper level trough was over the area with a...
# 5584  An upper level trough was over the area with a...
# 5585  An area of low pressure offshore of the Florid...
# 5586  An area of low pressure offshore of the Florid...
# 5587  An area of low pressure offshore of the Florid...
# 6029  A mean 1000-500 mb layer trough was offshore o...
# 6064  Slow moving storms in an unstable and moist en...
# 6252  A classic cold mid to upper level trough origi...
# 6455  A mid level trough over the Florida west coast...
# 6456  A mid level trough over the Florida west coast...
# 6629  Heavy showers and thunderstorms continued acro...
#
#                                         EVENT_NARRATIVE  DURATION_seconds  \
# 216                                                 NaN            9960.0
# 762                                                 NaN           14580.0
# 764                                                 NaN           27180.0
# 863   Law enforcement reported one foot of water ove...            1620.0
# 864   A trained spotter reported three to six inches...            1800.0
# 926   A spotter reported street flooding in the Wayc...           21600.0
# 1209  A NWS employee measured 2.32 inches of rainfal...            3600.0
# 1210  A NWS employee measured 3.75 inches of rainfal...            7200.0
# 1360  The Bishop, CA ASOS recorded 4.00 of rain on J...           86400.0
# 1430  A spotter reported three inches of rain near t...               0.0
# 1692  A man ran off the road and into a ditch which ...               0.0
# 1879  A spotter reported heavy rainfall with street ...           23400.0
# 2078                                                NaN           26340.0
# 2079                                                NaN           19980.0
# 2080                                                NaN           32280.0
# 2081                                                NaN           21000.0
# 2435  The combination of heavy rain and snowmelt led...          315000.0
# 2554  Numerous cumulonimbus embedded within the trou...          519600.0
# 2686  Street flooding was reported in Ottumwa.  A nu...            2640.0
# 2986  Over two and a half inches of rain fell in the...           10800.0
# 3160  Minor flooding was reported in the flood plain...            7200.0
# 3386   A rainfall spotter reported 3.64 inches of rain.            5400.0
# 3473  Rainfall amounts between one and four inches o...          115200.0
# 3474  Rainfall amounts between one and four inches o...          115200.0
# 3475  Rainfall amounts between one and four inches o...          115200.0
# 3476  Rainfall amounts between one and four inches o...          115200.0
# 3735  A spotter reported 6 inches of standing water ...               0.0
# 3981  Spotters reported 4 inches of rain in less tha...            3600.0
# 4287  Rainfall amounts between one and four inches o...          115200.0
# 4288  Rainfall amounts between one and four inches o...          115200.0
# 4289  Rainfall amounts between one and four inches o...          115200.0
# 4290  Rainfall amounts between one and four inches o...          115200.0
# 4292  Minor flooding occurred on Mountain Vista Stre...             900.0
# 4295  A strong thunderstorm produced 0.36 inches of ...           16140.0
# 5086  The Penny Farms Auto Repair Shop measured 5.0 ...           86340.0
# 5417  Heavy rain caused streams and creeks to flow a...           57600.0
# 5465  Five inches of rain were measured in a one hou...            4800.0
# 5503  Heavy rain caused rock slides on Highway 89A i...          108000.0
# 5504  Heavy rain (nearly 4 inches) on Jan 27 and 28t...          104400.0
# 5583  A spotter reported heavy rainfall from 3 pm ED...           28800.0
# 5584  A spotter near lake Sante Fe measured 2.80 inc...           43200.0
# 5585  Storm total rainfall measured in West Palm Coa...               0.0
# 5586  A spotter measured 3.0 inches of rainfall in P...               0.0
# 5587  A spotter measured 4 inches of rainfall since ...           70560.0
# 6029  Flooding occurred due to poor drainage on 105t...               0.0
# 6064  The public measured 5.5 inches of rainfall wit...            7200.0
# 6252  Heavy rainfall led to a vehicle accident on In...           39600.0
# 6455  A HAM radio operator measured 2.9 inches in on...            3600.0
# 6456  The Jacksonville International Airport ASOS st...            3600.0
# 6629                                                NaN           10380.0
#
#      BINNED_PROPERTY_DAMAGE
# 216               0 to 2.5k
# 762               0 to 2.5k
# 764               0 to 2.5k
# 863               0 to 2.5k
# 864               0 to 2.5k
# 926               0 to 2.5k
# 1209              0 to 2.5k
# 1210              0 to 2.5k
# 1360              0 to 2.5k
# 1430              0 to 2.5k
# 1692        greater than 1B
# 1879              0 to 2.5k
# 2078              0 to 2.5k
# 2079              0 to 2.5k
# 2080              0 to 2.5k
# 2081              0 to 2.5k
# 2435              0 to 2.5k
# 2554              0 to 2.5k
# 2686             10k to 20k
# 2986             20k to 30k
# 3160              0 to 2.5k
# 3386              0 to 2.5k
# 3473              0 to 2.5k
# 3474              0 to 2.5k
# 3475              0 to 2.5k
# 3476              0 to 2.5k
# 3735              0 to 2.5k
# 3981              0 to 2.5k
# 4287              0 to 2.5k
# 4288              0 to 2.5k
# 4289              0 to 2.5k
# 4290              0 to 2.5k
# 4292              0 to 2.5k
# 4295              0 to 2.5k
# 5086              0 to 2.5k
# 5417              0 to 2.5k
# 5465              0 to 2.5k
# 5503              0 to 2.5k
# 5504              0 to 2.5k
# 5583              0 to 2.5k
# 5584              0 to 2.5k
# 5585              0 to 2.5k
# 5586              0 to 2.5k
# 5587              0 to 2.5k
# 6029              0 to 2.5k
# 6064              0 to 2.5k
# 6252              0 to 2.5k
# 6455              0 to 2.5k
# 6456              0 to 2.5k
# 6629              0 to 2.5k

# %%
# Take out a 500 row subset of test data
heavy_rain_test=heavy_rain.sample(500)
heavy_rain_train=heavy_rain.drop(heavy_rain_test.index)

# convert the test data and the main data to a csv
heavy_rain_train.to_csv('event_subsets/heavy_rain_train.csv')
heavy_rain_test.to_csv('event_subsets/heavy_rain_test.csv')
TRAIN_DATA = 'heavy_rain_train.csv'
TEST_DATA = 'heavy_rain_test.csv'

#  Upload the training dataset to Darwin
status, message = s.delete_dataset(TRAIN_DATA)
status, heavy_rain_train = s.upload_dataset(os.path.join('event_subsets/', TRAIN_DATA))
if not status:
    print(heavy_rain_train)

# status, message = s.delete_dataset('heavy_rain_train')
# status, dataset = s.upload_dataset('event_subsets/heavy_rain_train.csv', 'heavy_rain_train')
# if not status:
#     print(dataset)
# print(dataset)

# Clean the training dataset using Darwin
status2, job_id = s.clean_data(TRAIN_DATA,target='BINNED_PROPERTY_DAMAGE')
if status2: s.wait_for_job(job_id['job_name'])
else: print(job_id)
# Out:
# {'status': 'Requested', 'starttime': '2019-04-21T15:42:56.968543', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': ['67bd70ff5e734ee0b96a155bb82fb27f'], 'model_name': None, 'job_error': None}
# {'status': 'Complete', 'starttime': '2019-04-21T15:42:56.968543', 'endtime': '2019-04-21T15:43:08.737938', 'percent_complete': 100, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': ['67bd70ff5e734ee0b96a155bb82fb27f'], 'model_name': None, 'job_error': ''}

# %%
# Upload test set to Darwin
status, message = s.delete_dataset('heavy_rain_test.csv')
status, message = s.delete_dataset('heavy_rain_test')
status, message = s.delete_dataset('heavy_rain_train')
status, heavy_rain_test1 = s.upload_dataset(os.path.join('event_subsets/', TEST_DATA))
if not status:
    print(heavy_rain_test1)

# %%
s.lookup_dataset()
# Out:
# (True,
#  [{'categorical': None,
#    'imbalanced': None,
#    'mbytes': 12.468260765075684,
#    'minimum_recommeded_train_time': '5 minutes',
#    'name': 'heavy_rain_train.csv',
#    'sequential': None,
#    'updated_at': '2019-04-21T15:42:55.860589'},
#   {'categorical': None,
#    'imbalanced': None,
#    'mbytes': 0.421722412109375,
#    'minimum_recommeded_train_time': '5 minutes',
#    'name': 'heavy_rain_test.csv',
#    'sequential': None,
#    'updated_at': '2019-04-21T15:44:28.608886'}])

# %%
# Create the model
ts = '{:%Y%m%d%H%M%S}'.format(datetime.datetime.now())
model0 = 'heavy_rain_model_' + ts

status, job_id = s.create_model(dataset_names=TRAIN_DATA, model_name=model0, max_train_time = '00:05')
if status: s.wait_for_job(job_id['job_name'])
else: print(job_id)
# Out:
# {'status': 'Requested', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 0, 'job_type': 'TrainModel', 'loss': None, 'generations': 0, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 1, 'job_type': 'TrainModel', 'loss': 2.019498586654663, 'generations': 0, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 4, 'job_type': 'TrainModel', 'loss': 2.01108717918396, 'generations': 1, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 8, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 2, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': None, 'percent_complete': 16, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Complete', 'starttime': '2019-04-21T15:46:24.847615', 'endtime': '2019-04-21T15:51:34.08964', 'percent_complete': 100, 'job_type': 'TrainModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_train.csv'], 'artifact_names': None, 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}

# %%
s.lookup_model()
# Out:
# (True,
#  [{'algorithm': None,
#    'complete': False,
#    'description': None,
#    'generations': 0,
#    'id': 'f9623912-63f0-11e9-a75a-271ba02c2f14',
#    'loss': None,
#    'name': 'heavy_rain_model_20190420235021',
#    'parameters': {'train_time': '00:02'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 1,
#    'trained_on': [],
#    'type': None,
#    'updated_at': None},
#   {'algorithm': None,
#    'complete': False,
#    'description': None,
#    'generations': 0,
#    'id': '2684d6b6-6225-11e9-bfea-4f44bb44c9e4',
#    'loss': None,
#    'name': 'heavy_rain_model20190418165849',
#    'parameters': {'big_data': False,
#     'impute': 'ffill',
#     'max_int_uniques': 15,
#     'max_unique_values': 50,
#     'recurrent': True,
#     'target': 'DAMAGE_PROPERTY',
#     'train_time': '00:01'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 6,
#    'trained_on': [],
#    'type': 'Supervised',
#    'updated_at': None},
#   {'algorithm': None,
#    'complete': False,
#    'description': None,
#    'generations': 0,
#    'id': '2a8a62d2-6223-11e9-a0ca-474e38203757',
#    'loss': None,
#    'name': 'DAMAGE_PROPERTY_model120190418164437',
#    'parameters': {'big_data': False,
#     'impute': 'ffill',
#     'max_int_uniques': 15,
#     'max_unique_values': 50,
#     'recurrent': True,
#     'target': 'DAMAGE_PROPERTY',
#     'train_time': '00:01'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 4,
#    'trained_on': [],
#    'type': 'Supervised',
#    'updated_at': None},
#   {'algorithm': None,
#    'complete': False,
#    'description': None,
#    'generations': 0,
#    'id': '36b02a3c-6472-11e9-8912-673e9a982d07',
#    'loss': None,
#    'name': 'heavy_rain_model_20190421151530',
#    'parameters': {'train_time': '00:01'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 1,
#    'trained_on': [],
#    'type': None,
#    'updated_at': None},
#   {'algorithm': None,
#    'complete': False,
#    'description': None,
#    'generations': 0,
#    'id': '4ec697da-63ed-11e9-adae-636c79845668',
#    'loss': None,
#    'name': 'heavy_rain_model_20190420232359',
#    'parameters': {'train_time': '00:02'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 15,
#    'trained_on': [],
#    'type': None,
#    'updated_at': None},
#   {'algorithm': None,
#    'complete': False,
#    'description': None,
#    'generations': 0,
#    'id': '505486b8-6472-11e9-8912-9359a58be8ff',
#    'loss': None,
#    'name': 'heavy_rain_model_20190421151613',
#    'parameters': {'train_time': '00:01'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 0,
#    'trained_on': [],
#    'type': None,
#    'updated_at': None},
#   {'algorithm': None,
#    'complete': False,
#    'description': None,
#    'generations': 0,
#    'id': '68dfd636-646a-11e9-8f47-131d2f8d8942',
#    'loss': None,
#    'name': 'heavy_rain_model_20190421141938',
#    'parameters': {'train_time': '00:02'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 1,
#    'trained_on': [],
#    'type': None,
#    'updated_at': None},
#   {'algorithm': None,
#    'complete': False,
#    'description': None,
#    'generations': 0,
#    'id': '769d362a-646e-11e9-be2c-5b075fa0fa8f',
#    'loss': None,
#    'name': 'heavy_rain_model_20190421144840',
#    'parameters': {'train_time': '00:05'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 0,
#    'trained_on': [],
#    'type': None,
#    'updated_at': None},
#   {'algorithm': None,
#    'complete': False,
#    'description': None,
#    'generations': 0,
#    'id': '793e0650-6376-11e9-adcb-27db82ef2e5f',
#    'loss': None,
#    'name': 'heavy_rain_model20190420091331',
#    'parameters': {'big_data': False,
#     'impute': 'ffill',
#     'max_int_uniques': 15,
#     'max_unique_values': 50,
#     'recurrent': True,
#     'target': 'DAMAGE_PROPERTY',
#     'train_time': '00:01'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 4,
#    'trained_on': [],
#    'type': 'Supervised',
#    'updated_at': None},
#   {'algorithm': None,
#    'complete': False,
#    'description': None,
#    'generations': 0,
#    'id': '91cd13a2-63f1-11e9-8d5a-27a381d7d641',
#    'loss': None,
#    'name': 'heavy_rain_model_20190420235437',
#    'parameters': {'train_time': '00:02'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 0,
#    'trained_on': [],
#    'type': None,
#    'updated_at': None},
#   {'algorithm': None,
#    'complete': False,
#    'description': None,
#    'generations': 0,
#    'id': '9a828906-6382-11e9-9035-573a56e5492b',
#    'loss': None,
#    'name': 'heavy_rain_model_20190420104018',
#    'parameters': {'train_time': '00:02'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 16,
#    'trained_on': [],
#    'type': None,
#    'updated_at': None},
#   {'algorithm': None,
#    'complete': False,
#    'description': None,
#    'generations': 0,
#    'id': 'd13b56f2-6473-11e9-9875-1b2f16437b8a',
#    'loss': None,
#    'name': 'aaa',
#    'parameters': {'train_time': '00:01'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 0,
#    'trained_on': [],
#    'type': None,
#    'updated_at': None},
#   {'algorithm': None,
#    'complete': False,
#    'description': None,
#    'generations': 0,
#    'id': 'da2084ec-63ef-11e9-a463-e7bb547b8d01',
#    'loss': None,
#    'name': 'heavy_rain_model_20190420234220',
#    'parameters': {'train_time': '00:02'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 15,
#    'trained_on': [],
#    'type': None,
#    'updated_at': None},
#   {'algorithm': None,
#    'complete': False,
#    'description': None,
#    'generations': 0,
#    'id': 'db70fae2-63eb-11e9-86da-87ea6a90f597',
#    'loss': None,
#    'name': 'heavy_rain_model_20190420231344',
#    'parameters': {'train_time': '00:02'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 1,
#    'trained_on': [],
#    'type': None,
#    'updated_at': None},
#   {'algorithm': None,
#    'complete': False,
#    'description': None,
#    'generations': 0,
#    'id': 'f33ae9c2-63ef-11e9-a75a-770a44711744',
#    'loss': None,
#    'name': 'heavy_rain_model_20190420234301',
#    'parameters': {'train_time': '00:02'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 15,
#    'trained_on': [],
#    'type': None,
#    'updated_at': None},
#   {'algorithm': None,
#    'complete': False,
#    'description': None,
#    'generations': 0,
#    'id': '0bd6f858-63f1-11e9-a463-d782e0c99fc2',
#    'loss': None,
#    'name': 'heavy_rain_model_20190420235052',
#    'parameters': {'train_time': '00:02'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 16,
#    'trained_on': [],
#    'type': None,
#    'updated_at': None},
#   {'algorithm': None,
#    'complete': True,
#    'description': {'best_genome': [{'layer 1': {'parameters': {'activation': 'relu',
#         'numunits': 37},
#        'type': 'LinearGene'}},
#      {'layer 2': {'parameters': {'activation': 'relu', 'numunits': 18},
#        'type': 'LinearGene'}}],
#     'genome_type': 'DeepNet',
#     'recurrent': True},
#    'generations': 4,
#    'id': '872f496c-6476-11e9-b381-9749a1e71b8b',
#    'loss': 2.010779857635498,
#    'name': 'heavy_rain_model_20190421154623',
#    'parameters': {'big_data': False,
#     'impute': 'ffill',
#     'max_int_uniques': 15,
#     'max_unique_values': 50,
#     'recurrent': True,
#     'target': 'BINNED_PROPERTY_DAMAGE',
#     'train_time': '00:05'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 309,
#    'trained_on': ['heavy_rain_train.csv'],
#    'type': 'Supervised',
#    'updated_at': '2019-04-21T15:51:34.062845'},
#   {'algorithm': None,
#    'complete': True,
#    'description': {'best_genome': {'parameters': {'bootstrap': True,
#       'criterion': 'gini',
#       'max_depth': 3,
#       'max_features': 0.5,
#       'max_leaf_nodes': None,
#       'min_impurity_decrease': 0.0,
#       'min_samples_leaf': 1,
#       'min_samples_split': 2,
#       'min_weight_fraction_leaf': 0.0,
#       'n_estimators': 100,
#       'n_jobs': -1},
#      'type': 'RandomForestClassifier'},
#     'genome_type': 'RandomForestClassifier',
#     'recurrent': True},
#    'generations': 2,
#    'id': '658d656e-6476-11e9-b07e-abf895097e92',
#    'loss': 2.0206403732299805,
#    'name': 'heavy_rain_model_20190421154527',
#    'parameters': {'big_data': False,
#     'impute': 'ffill',
#     'max_int_uniques': 15,
#     'max_unique_values': 50,
#     'recurrent': True,
#     'target': 'BINNED_PROPERTY_DAMAGE',
#     'train_time': '00:01'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 40,
#    'trained_on': ['heavy_rain_train.csv'],
#    'type': 'Supervised',
#    'updated_at': '2019-04-21T15:46:08.551441'},
#   {'algorithm': None,
#    'complete': True,
#    'description': {'best_genome': [{'layer 1': {'parameters': {'activation': 'relu',
#         'numunits': 50},
#        'type': 'LinearGene'}},
#      {'layer 2': {'parameters': {'activation': 'relu', 'numunits': 18},
#        'type': 'LinearGene'}}],
#     'genome_type': 'DeepNet',
#     'recurrent': True},
#    'generations': 2,
#    'id': '541650ac-6476-11e9-a36e-bf56d96a8471',
#    'loss': 2.019869089126587,
#    'name': 'lifeispain',
#    'parameters': {'big_data': False,
#     'impute': 'ffill',
#     'max_int_uniques': 15,
#     'max_unique_values': 50,
#     'recurrent': True,
#     'target': 'BINNED_PROPERTY_DAMAGE',
#     'train_time': '00:01'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 67,
#    'trained_on': ['heavy_rain_train.csv'],
#    'type': 'Supervised',
#    'updated_at': '2019-04-21T15:46:06.589158'},
#   {'algorithm': None,
#    'complete': True,
#    'description': {'best_genome': [{'layer 1': {'parameters': {'activation': 'relu',
#         'numlayers': 1,
#         'numunits': 45},
#        'type': 'LSTMGene'}},
#      {'layer 2': {'parameters': {'activation': 'relu', 'numunits': 18},
#        'type': 'LinearGene'}}],
#     'genome_type': 'DeepNet',
#     'recurrent': True},
#    'generations': 0,
#    'id': '4c375b72-6473-11e9-a723-5bb859c1f50d',
#    'loss': None,
#    'name': 'heavy_rain_model_20190421152316',
#    'parameters': {'big_data': False,
#     'impute': 'ffill',
#     'max_int_uniques': 15,
#     'max_unique_values': 50,
#     'recurrent': True,
#     'target': 'BINNED_PROPERTY_DAMAGE',
#     'train_time': '00:01'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 69,
#    'trained_on': ['heavy_rain_train'],
#    'type': 'Supervised',
#    'updated_at': '2019-04-21T15:24:26.102544'},
#   {'algorithm': None,
#    'complete': True,
#    'description': {'best_genome': [{'layer 1': {'parameters': {'depth': 7,
#         'dropout': 0.0,
#         'kernelsize': 9,
#         'numfilters': 9,
#         'numunits': 17,
#         'seqlength': 202},
#        'type': 'TemporalConvolutionalNet'}},
#      {'layer 2': {'parameters': {'activation': 'relu', 'numunits': 18},
#        'type': 'LinearGene'}}],
#     'genome_type': 'DeepNet',
#     'recurrent': True},
#    'generations': 0,
#    'id': 'cd8327f0-646f-11e9-9083-b3f9861922db',
#    'loss': None,
#    'name': 'heavy_rain_model_20190421145815',
#    'parameters': {'big_data': False,
#     'impute': 'ffill',
#     'max_int_uniques': 15,
#     'max_unique_values': 50,
#     'recurrent': True,
#     'target': 'BINNED_PROPERTY_DAMAGE',
#     'train_time': '00:05'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 309,
#    'trained_on': ['heavy_rain_train'],
#    'type': 'Supervised',
#    'updated_at': '2019-04-21T15:03:25.187529'},
#   {'algorithm': None,
#    'complete': True,
#    'description': {'best_genome': [{'layer 1': {'parameters': {'depth': 6,
#         'dropout': 0.0,
#         'kernelsize': 9,
#         'numfilters': 8,
#         'numunits': 100,
#         'seqlength': 83},
#        'type': 'TemporalConvolutionalNet'}},
#      {'layer 2': {'parameters': {'activation': 'relu', 'numunits': 18},
#        'type': 'LinearGene'}}],
#     'genome_type': 'DeepNet',
#     'recurrent': True},
#    'generations': 0,
#    'id': '65f72114-646e-11e9-be2c-171ea9bd7932',
#    'loss': None,
#    'name': 'heavy_rain_model_20190421144811',
#    'parameters': {'big_data': False,
#     'impute': 'ffill',
#     'max_int_uniques': 15,
#     'max_unique_values': 50,
#     'recurrent': True,
#     'target': 'BINNED_PROPERTY_DAMAGE',
#     'train_time': '00:05'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 308,
#    'trained_on': ['heavy_rain_train'],
#    'type': 'Supervised',
#    'updated_at': '2019-04-21T14:53:21.444065'},
#   {'algorithm': None,
#    'complete': True,
#    'description': {'best_genome': [{'layer 1': {'parameters': {'activation': 'relu',
#         'numunits': 61},
#        'type': 'LinearGene'}},
#      {'layer 2': {'parameters': {'activation': 'relu', 'numunits': 66},
#        'type': 'LinearGene'}},
#      {'layer 3': {'parameters': {'activation': 'relu', 'numunits': 2},
#        'type': 'LinearGene'}}],
#     'genome_type': 'DeepNet',
#     'recurrent': False},
#    'generations': 0,
#    'id': '84513b2c-6469-11e9-a5d4-9b9a4f01a568',
#    'loss': None,
#    'name': 'heavy_rain_model_20190421141315',
#    'parameters': {'big_data': False,
#     'impute': 'mean',
#     'max_int_uniques': 15,
#     'max_unique_values': 50,
#     'recurrent': False,
#     'target': 'binary_damage',
#     'train_time': '00:02'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 125,
#    'trained_on': ['heavy_rain_train.csv'],
#    'type': 'Supervised',
#    'updated_at': '2019-04-21T14:15:22.036215'},
#   {'algorithm': None,
#    'complete': True,
#    'description': {'best_genome': [{'layer 1': {'parameters': {'activation': 'relu',
#         'numunits': 67},
#        'type': 'LinearGene'}},
#      {'layer 2': {'parameters': {'activation': 'relu', 'numunits': 64},
#        'type': 'LinearGene'}},
#      {'layer 3': {'parameters': {'activation': 'relu', 'numunits': 2},
#        'type': 'LinearGene'}}],
#     'genome_type': 'DeepNet',
#     'recurrent': False},
#    'generations': 0,
#    'id': '7a7e9bf4-6468-11e9-b439-4b94e6692e5b',
#    'loss': None,
#    'name': 'heavy_rain_model_20190421140549',
#    'parameters': {'big_data': False,
#     'impute': 'mean',
#     'max_int_uniques': 15,
#     'max_unique_values': 50,
#     'recurrent': False,
#     'target': 'binary_damage',
#     'train_time': '00:02'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 127,
#    'trained_on': ['heavy_rain_train.csv'],
#    'type': 'Supervised',
#    'updated_at': '2019-04-21T14:07:57.089186'},
#   {'algorithm': None,
#    'complete': True,
#    'description': {'best_genome': [{'layer 1': {'parameters': {'activation': 'relu',
#         'numunits': 41},
#        'type': 'LinearGene'}},
#      {'layer 2': {'parameters': {'activation': 'relu', 'numunits': 2},
#        'type': 'LinearGene'}}],
#     'genome_type': 'DeepNet',
#     'recurrent': False},
#    'generations': 0,
#    'id': '4fa721ec-63f2-11e9-a75a-4313670f39e7',
#    'loss': None,
#    'name': 'heavy_rain_model_20190420235956',
#    'parameters': {'big_data': False,
#     'impute': 'mean',
#     'max_int_uniques': 15,
#     'max_unique_values': 50,
#     'recurrent': False,
#     'target': 'binary_damage',
#     'train_time': '00:02'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 125,
#    'trained_on': ['heavy_rain_train.csv'],
#    'type': 'Supervised',
#    'updated_at': '2019-04-21T00:02:03.391042'},
#   {'algorithm': None,
#    'complete': True,
#    'description': {'best_genome': [{'layer 1': {'parameters': {'activation': 'relu',
#         'numunits': 58},
#        'type': 'LinearGene'}},
#      {'layer 2': {'parameters': {'activation': 'relu', 'numunits': 2},
#        'type': 'LinearGene'}}],
#     'genome_type': 'DeepNet',
#     'recurrent': False},
#    'generations': 3,
#    'id': '2ab1dc8c-63e4-11e9-8d5a-dbb205712e4a',
#    'loss': 0.3478119969367981,
#    'name': 'heavy_rain_model_20190420221842',
#    'parameters': {'big_data': False,
#     'impute': 'mean',
#     'max_int_uniques': 15,
#     'max_unique_values': 50,
#     'recurrent': False,
#     'target': 'binary_damage',
#     'train_time': '00:02'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 129,
#    'trained_on': ['heavy_rain_train.csv'],
#    'type': 'Supervised',
#    'updated_at': '2019-04-20T22:20:51.937414'},
#   {'algorithm': None,
#    'complete': True,
#    'description': {'best_genome': {'parameters': {'base_score': 0.5,
#       'colsample_bylevel': 1,
#       'colsample_bytree': 1,
#       'gamma': 0,
#       'learning_rate': 0.3598275658810431,
#       'max_delta_step': 0,
#       'max_depth': 9,
#       'min_child_weight': 12,
#       'n_estimators': 252,
#       'n_jobs': -1,
#       'reg_alpha': 0,
#       'reg_lambda': 1,
#       'scale_pos_weight': 1,
#       'subsample': 0.9742854994000655},
#      'type': 'XGBClassifier'},
#     'genome_type': 'XGBClassifier',
#     'recurrent': False},
#    'generations': 4,
#    'id': 'de83fb96-63da-11e9-83c4-f325c3faf9af',
#    'loss': 0.34524235129356384,
#    'name': 'heavy_rain_model_20190420211208',
#    'parameters': {'big_data': False,
#     'impute': 'mean',
#     'max_int_uniques': 15,
#     'max_unique_values': 50,
#     'recurrent': False,
#     'target': 'binary_damage',
#     'train_time': '00:02'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 126,
#    'trained_on': ['heavy_rain_train.csv'],
#    'type': 'Supervised',
#    'updated_at': '2019-04-20T21:14:16.316715'},
#   {'algorithm': None,
#    'complete': True,
#    'description': {'best_genome': {'parameters': {'base_score': 0.5,
#       'colsample_bylevel': 1,
#       'colsample_bytree': 1,
#       'gamma': 0,
#       'learning_rate': 0.659910042928117,
#       'max_delta_step': 0,
#       'max_depth': 5,
#       'min_child_weight': 18,
#       'n_estimators': 450,
#       'n_jobs': -1,
#       'reg_alpha': 0,
#       'reg_lambda': 1,
#       'scale_pos_weight': 1,
#       'subsample': 0.3499572218835456},
#      'type': 'XGBRegressor'},
#     'genome_type': 'XGBRegressor',
#     'recurrent': False},
#    'generations': 4,
#    'id': '3caf4f2c-6255-11e9-97a9-27b72d7eff94',
#    'loss': 1.2170851230621338,
#    'name': 'heavy_rain_model_20190418224303',
#    'parameters': {'big_data': False,
#     'impute': 'mean',
#     'max_int_uniques': 15,
#     'max_unique_values': 50,
#     'recurrent': False,
#     'target': 'DAMAGE_PROPERTY',
#     'train_time': '00:01'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 67,
#    'trained_on': ['heavy_rain_train.csv'],
#    'type': 'Supervised',
#    'updated_at': '2019-04-18T22:44:10.795835'},
#   {'algorithm': None,
#    'complete': True,
#    'description': {'best_genome': {'parameters': {'bootstrap': True,
#       'criterion': 'mse',
#       'max_depth': 5,
#       'max_features': 0.2030760808036782,
#       'max_leaf_nodes': None,
#       'min_impurity_decrease': 0.0,
#       'min_samples_leaf': 10,
#       'min_samples_split': 19,
#       'min_weight_fraction_leaf': 0.0,
#       'n_estimators': 311,
#       'n_jobs': -1},
#      'type': 'RandomForestRegressor'},
#     'genome_type': 'RandomForestRegressor',
#     'recurrent': False},
#    'generations': 5,
#    'id': 'ac3dc6b2-624a-11e9-ada6-1316c0be50e7',
#    'loss': 0.27992695569992065,
#    'name': 'heavy_rain_model_20190418212725',
#    'parameters': {'big_data': False,
#     'impute': 'mean',
#     'max_int_uniques': 15,
#     'max_unique_values': 50,
#     'recurrent': False,
#     'target': 'DAMAGE_PROPERTY',
#     'train_time': '00:01'},
#    'problem_type': None,
#    'running_job_id': None,
#    'train_time_seconds': 66,
#    'trained_on': ['heavy_rain.csv'],
#    'type': 'Supervised',
#    'updated_at': '2019-04-18T21:28:32.856096'}])

# %%
status, job_id = s.clean_data(TEST_DATA, target='BINNED_PROPERTY_DAMAGE', model_name='heavy_rain_model_20190421154623')

if status: s.wait_for_job(job_id['job_name'])
else: print(job_id)
# Out:
# {'status': 'Requested', 'starttime': '2019-04-21T16:05:10.65638', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['heavy_rain_test.csv'], 'artifact_names': ['0e88db95f4634fe7ba382d992f3344cb'], 'model_name': None, 'job_error': None}
# {'status': 'Complete', 'starttime': '2019-04-21T16:05:10.65638', 'endtime': '2019-04-21T16:05:13.510589', 'percent_complete': 100, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['heavy_rain_test.csv'], 'artifact_names': ['0e88db95f4634fe7ba382d992f3344cb'], 'model_name': None, 'job_error': ''}

# %%
from time import sleep

status, artifact = s.analyze_model('heavy_rain_model_20190421154623')
sleep(1)
if status:
    s.wait_for_job(artifact['job_name'])
else:
    print(artifact)
status, feature_importance = s.download_artifact(artifact['artifact_name'])

feature_importance[:10]
# Out:
# {'status': 'Running', 'starttime': '2019-04-21T16:06:13.56137', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzeModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': None, 'artifact_names': ['affa3fa5049949f6ae04726cd40e9e49'], 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Complete', 'starttime': '2019-04-21T16:06:13.56137', 'endtime': '2019-04-21T16:06:23.008158', 'percent_complete': 100, 'job_type': 'AnalyzeModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': None, 'artifact_names': ['affa3fa5049949f6ae04726cd40e9e49'], 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# SOURCE = Department of Highways       0.153113
# END_LON                               0.141858
# Unnamed: 0                            0.113787
# BEGIN_LON                             0.102749
# END_LAT                               0.080895
# DURATION_seconds                      0.074894
# BEGIN_LAT                             0.069149
# YEAR = 2017                           0.062491
# SOURCE = Official NWS Observations    0.027946
# SOURCE = Local Official               0.023476
# dtype: float64

# %%
s.display_population('heavy_rain_model_20190421154623')
# Out:
# (True,
#  {'population': {'model_types': {'DeepNeuralNetwork': {'fitness': 1.9833571852501297,
#      'loss_function': 'CrossEntropy',
#      'model_description': [{'layer 1': {'parameters': {'activation': 'relu',
#          'numunits': 37},
#         'type': 'LinearGene'}},
#       {'layer 2': {'parameters': {'activation': 'relu', 'numunits': 18},
#         'type': 'LinearGene'}}]},
#     'GradientBoosted': {'fitness': 1.9805443768885762,
#      'loss_function': 'CrossEntropy',
#      'model_description': {'parameters': {'base_score': 0.5,
#        'colsample_bylevel': 1,
#        'colsample_bytree': 1,
#        'gamma': 0,
#        'learning_rate': 0.6732567094261407,
#        'max_delta_step': 0,
#        'max_depth': 2,
#        'min_child_weight': 8,
#        'n_estimators': 360,
#        'n_jobs': -1,
#        'reg_alpha': 0,
#        'reg_lambda': 1,
#        'scale_pos_weight': 1,
#        'subsample': 0.35486438340609133},
#       'type': 'XGBClassifier'}},
#     'RandomForest': {'fitness': 1.9808173804168177,
#      'loss_function': 'CrossEntropy',
#      'model_description': {'parameters': {'bootstrap': False,
#        'criterion': 'gini',
#        'max_depth': 8,
#        'max_features': 0.554179176771887,
#        'max_leaf_nodes': None,
#        'min_impurity_decrease': 0.0,
#        'min_samples_leaf': 14,
#        'min_samples_split': 9,
#        'min_weight_fraction_leaf': 0.0,
#        'n_estimators': 350,
#        'n_jobs': -1},
#       'type': 'RandomForestClassifier'}}}}})

# %%
# Run Model on test data
status, artifact = s.run_model(TEST_DATA,'heavy_rain_model_20190421154623')
sleep(1)
s.wait_for_job(artifact['job_name'])
# Out:
# {'status': 'Running', 'starttime': '2019-04-21T16:08:47.205076', 'endtime': None, 'percent_complete': 0, 'job_type': 'RunModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_test.csv'], 'artifact_names': ['ec604799fe7f4ff0a7cf0154f739c93f'], 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# {'status': 'Complete', 'starttime': '2019-04-21T16:08:47.205076', 'endtime': '2019-04-21T16:08:48.881428', 'percent_complete': 100, 'job_type': 'RunModel', 'loss': 2.010779857635498, 'generations': 4, 'dataset_names': ['heavy_rain_test.csv'], 'artifact_names': ['ec604799fe7f4ff0a7cf0154f739c93f'], 'model_name': 'heavy_rain_model_20190421154623', 'job_error': ''}
# (True, 'Job completed')

# %%
# Create plots comparing predictions with actual target
status, prediction = s.download_artifact(artifact['artifact_name'])
df = pd.read_csv(os.path.join('event_subsets/', TEST_DATA))
unq = prediction['BINNED_PROPERTY_DAMAGE'].unique()[::-1]
p = np.zeros((len(prediction),))
a = np.zeros((len(prediction),))
for i,q in enumerate(unq):
    p += i*(prediction['BINNED_PROPERTY_DAMAGE'] == q).values
    a += i*(df['BINNED_PROPERTY_DAMAGE'] == q).values
#Plot predictions vs actual
plt.plot(a)
plt.plot(p)
plt.legend(['Actual','Predicted'])
plt.yticks([i for i in range(len(unq))],[q for q in unq]);
print(classification_report(df['BINNED_PROPERTY_DAMAGE'], prediction['BINNED_PROPERTY_DAMAGE']))
# Out:
#                  precision    recall  f1-score   support
#
#       0 to 2.5k       0.97      1.00      0.99       483
#    100k to 200k       0.00      0.00      0.00         3
#      10k to 20k       0.00      0.00      0.00         4
#      2.5k to 5k       0.00      0.00      0.00         2
#      30k to 40k       0.00      0.00      0.00         1
#      40k to 50k       0.00      0.00      0.00         1
#       5k to 10k       0.00      0.00      0.00         1
#    600k to 700k       0.00      0.00      0.00         1
#    700k to 800k       0.00      0.00      0.00         2
# greater than 1B       0.67      1.00      0.80         2
#
#       micro avg       0.97      0.97      0.97       500
#       macro avg       0.16      0.20      0.18       500
#    weighted avg       0.94      0.97      0.96       500
# /home/freya/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
status, model_type = s.lookup_model_name('heavy_rain_model_20190421154623')
print(model_type['description']['best_genome'])
# Out:
# [{'layer 1': {'type': 'LinearGene', 'parameters': {'activation': 'relu', 'numunits': 37}}}, {'layer 2': {'type': 'LinearGene', 'parameters': {'activation': 'relu', 'numunits': 18}}}]

# %%
s.download_artifact('ec604799fe7f4ff0a7cf0154f739c93f','event_subsets')
# Out:
# (True, {'filename': 'event_subsets/artifact.csv'})

# %%
heavy_rain_test_results = pd.read_csv('event_subsets/artifact.csv')
correct_count = 0
incorrect_count = 0

h = pd.read_csv(os.path.join('event_subsets/', 'heavy_rain_test.csv'))

for row in h.iterrows():
    j = 0
    print(row['BINNED_PROPERTY_DAMAGE'])
#     if heavy_rain_test_results.at[j,'BINNED_PROPERTY_DAMAGE'] == row['BINNED_PROPERTY_DAMAGE']:
#         correct_count += 1
#     else:
#         incorrect_count+=1
    j+=1
        
print(correct_count)
print(incorrect_count)
print('Accuracy: ' + str(correct_count/500))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-4d5e6a30f6b3> in <module>()
#       7 for row in h.iterrows():
#       8     j = 0
# ----> 9     print(row['BINNED_PROPERTY_DAMAGE'])
#      10 #     if heavy_rain_test_results.at[j,'BINNED_PROPERTY_DAMAGE'] == row['BINNED_PROPERTY_DAMAGE']:
#      11 #         correct_count += 1
#
# TypeError: tuple indices must be integers or slices, not str
