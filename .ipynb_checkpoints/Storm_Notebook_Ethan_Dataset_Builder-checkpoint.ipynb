# %% [markdown]
# ## Load imports and datasets

# %%
# Runs all imports
import pandas as pd
import datetime
from datetime import timedelta
import numpy as np

# Displays all datasets' columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %matplotlib inline

# %%
if True:
    # Log into Darwin SDK
    from amb_sdk.sdk import DarwinSdk
    s = DarwinSdk()
    s.set_url('https://amb-demo-api.sparkcognition.com/v1/')
    s.auth_login_user('ethan.freeburg@utexas.edu','AAn7WQfgqk')

# %% [markdown]
# ## Load Main Dataset

# %%
# Creates a table from compressed csvs in a directory
import os

DIR = 'data_details'

os.chdir(DIR)

tables = []
for file in os.listdir():
    tables.append(pd.read_csv(file, compression='gzip'))

os.chdir('../')

raw = pd.concat(tables)
    
raw.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           200802         22        1300         200802       22      2200
# 1           200804          1         352         200804        1       352
# 2           200803          1           0         200803        1      1320
# 3           200801         14         500         200801       14      1700
# 4           200812         19        1353         200812       21       200
#
#    EPISODE_ID  EVENT_ID          STATE  STATE_FIPS  YEAR MONTH_NAME  \
# 0       14216     79884  NEW HAMPSHIRE          33  2008   February
# 1       15549     88334  NEW HAMPSHIRE          33  2008      April
# 2       14773     83820  NEW HAMPSHIRE          33  2008      March
# 3       13559     75727  NEW HAMPSHIRE          33  2008    January
# 4       25148    146588  NEW HAMPSHIRE          33  2008   December
#
#    EVENT_TYPE CZ_TYPE  CZ_FIPS               CZ_NAME  WFO     BEGIN_DATE_TIME  \
# 0  Heavy Snow       Z       12  EASTERN HILLSBOROUGH  BOX  22-FEB-08 13:00:00
# 1   High Wind       Z       12  EASTERN HILLSBOROUGH  BOX  01-APR-08 03:52:00
# 2  Heavy Snow       Z       12  EASTERN HILLSBOROUGH  BOX  01-MAR-08 00:00:00
# 3  Heavy Snow       Z       12  EASTERN HILLSBOROUGH  BOX  14-JAN-08 05:00:00
# 4  Heavy Snow       Z       12  EASTERN HILLSBOROUGH  BOX  19-DEC-08 13:53:00
#
#   CZ_TIMEZONE       END_DATE_TIME  INJURIES_DIRECT  INJURIES_INDIRECT  \
# 0       EST-5  22-FEB-08 22:00:00                0                  0
# 1       EST-5  01-APR-08 03:52:00                0                  0
# 2       EST-5  01-MAR-08 13:20:00                0                  0
# 3       EST-5  14-JAN-08 17:00:00                0                  0
# 4       EST-5  21-DEC-08 02:00:00                0                  0
#
#    DEATHS_DIRECT  DEATHS_INDIRECT DAMAGE_PROPERTY DAMAGE_CROPS  \
# 0              0                0           0.00K        0.00K
# 1              0                0           0.00K        0.00K
# 2              0                0           0.00K        0.00K
# 3              0                0          10.00K        0.00K
# 4              0                0           0.00K        0.00K
#
#             SOURCE  MAGNITUDE MAGNITUDE_TYPE FLOOD_CAUSE  CATEGORY  \
# 0           Public        NaN            NaN         NaN       NaN
# 1    Amateur Radio       52.0             MG         NaN       NaN
# 2  Trained Spotter        NaN            NaN         NaN       NaN
# 3  Trained Spotter        NaN            NaN         NaN       NaN
# 4  Trained Spotter        NaN            NaN         NaN       NaN
#
#   TOR_F_SCALE  TOR_LENGTH  TOR_WIDTH TOR_OTHER_WFO TOR_OTHER_CZ_STATE  \
# 0         NaN         NaN        NaN           NaN                NaN
# 1         NaN         NaN        NaN           NaN                NaN
# 2         NaN         NaN        NaN           NaN                NaN
# 3         NaN         NaN        NaN           NaN                NaN
# 4         NaN         NaN        NaN           NaN                NaN
#
#    TOR_OTHER_CZ_FIPS TOR_OTHER_CZ_NAME  BEGIN_RANGE BEGIN_AZIMUTH  \
# 0                NaN               NaN          NaN           NaN
# 1                NaN               NaN          NaN           NaN
# 2                NaN               NaN          NaN           NaN
# 3                NaN               NaN          NaN           NaN
# 4                NaN               NaN          NaN           NaN
#
#   BEGIN_LOCATION  END_RANGE END_AZIMUTH END_LOCATION  BEGIN_LAT  BEGIN_LON  \
# 0            NaN        NaN         NaN          NaN        NaN        NaN
# 1            NaN        NaN         NaN          NaN        NaN        NaN
# 2            NaN        NaN         NaN          NaN        NaN        NaN
# 3            NaN        NaN         NaN          NaN        NaN        NaN
# 4            NaN        NaN         NaN          NaN        NaN        NaN
#
#    END_LAT  END_LON                                  EPISODE_NARRATIVE  \
# 0      NaN      NaN  A noreaster moved up the coast southeast of Ca...
# 1      NaN      NaN  Strong southwest flow behind a warm front allo...
# 2      NaN      NaN  Low pressure tracked from the Great Lakes acro...
# 3      NaN      NaN  Low pressure moved up the Atlantic coast and s...
# 4      NaN      NaN  An intensifying coastal low spread heavy snow ...
#
#                                      EVENT_NARRATIVE DATA_SOURCE
# 0                                                NaN         CSV
# 1  An amateur radio operator recorded a wind gust...         CSV
# 2                                                NaN         CSV
# 3                                                NaN         CSV
# 4  Six to eight inches of snow fell across easter...         CSV

# %% [markdown]
# ## Reformat Data

# %%
data = raw.copy()

# --------------------- CLEANING ---------------------
# split and BEGIN_YEARMONTH + END_YEARMONTH columns into 2 columns each --> YEAR + MONTH
begin_year = data['BEGIN_YEARMONTH'].astype(str).str[:4]
begin_month = data['BEGIN_YEARMONTH'].astype(str).str[4:]
data['BEGIN_YEAR'] = begin_year
data['BEGIN_MONTH'] = begin_month
#data.drop(columns=['BEGIN_YEARMONTH'], inplace=True)

end_year = data['END_YEARMONTH'].astype(str).str[:4]
end_month = data['END_YEARMONTH'].astype(str).str[4:]
data['END_YEAR'] = end_year
data['END_MONTH'] = end_month
#data.drop(columns=['END_YEARMONTH'], inplace=True)

# add begin and end dates and times in YYYY-MM-DD HH:MM:SS format
begin = data['BEGIN_YEAR'].map(str) + '-' + data['BEGIN_MONTH'].map(str) + '-' + data['BEGIN_DAY'].map(str) + ' '
hour = data['BEGIN_TIME'].astype(str).str[:-2]
hour = hour.apply(lambda x: '{0:0>2}'.format(x))
minute = data['BEGIN_TIME'].astype(str).str[-2:]
minute = minute.apply(lambda x: '{0:0>2}'.format(x))
time = hour.map(str) + ':' + minute.map(str) + ':00'
data['BEGIN'] = begin+time

end = data['END_YEAR'].map(str) + '-' + data['END_MONTH'].map(str) + '-' + data['END_DAY'].map(str) + ' '
e_hour = data['END_TIME'].astype(str).str[:-2]
e_hour = e_hour.apply(lambda x: '{0:0>2}'.format(x))
e_minute = data['END_TIME'].astype(str).str[-2:]
e_minute = e_minute.apply(lambda x: '{0:0>2}'.format(x))
e_time = e_hour.map(str) + ':' + e_minute.map(str) + ':00'
data['END'] = end+e_time

# add duration column
duration = pd.to_datetime(data['END']) - pd.to_datetime(data['BEGIN'])
data['DURATION_seconds'] = ((duration.dt.total_seconds())) 

#change DAMAGE_PROPERTY and DAMAGE_CROPS type from #.##K to float
def convertToFloat(x):
    x = str(x)
    if(x[-1]=='K'):
        return(float(x[0:-1])*1000)
    elif(x[-1]=='M'):
        return(float(x[0:-1])*1000000)
    elif(x[-1]=='B'):
        return(float(x[0:-1])*1000000000)
    else:
        return(0.0)

    
#print(pd.value_counts(data.DAMAGE_PROPERTY))
#print(pd.value_counts(data.DAMAGE_CROPS))
data['DAMAGE_PROPERTY'].fillna(0.0, inplace=True)
data['DAMAGE_PROPERTY'] = data['DAMAGE_PROPERTY'].apply(convertToFloat)

data['DAMAGE_CROPS'].fillna(0.0, inplace=True)
data['DAMAGE_CROPS'] = data['DAMAGE_CROPS'].apply(convertToFloat)

# %% [markdown]
# # Explore Data Components

# %%
desc = data.describe(include='all')
desc
# Out:
#         BEGIN_YEARMONTH      BEGIN_DAY     BEGIN_TIME  END_YEARMONTH  \
# count     683982.000000  683982.000000  683982.000000  683982.000000
# unique              NaN            NaN            NaN            NaN
# top                 NaN            NaN            NaN            NaN
# freq                NaN            NaN            NaN            NaN
# mean      201286.661820      14.923438    1276.620968  201286.661822
# std          315.112678       9.215241     680.820287     315.112676
# min       200801.000000       1.000000       0.000000  200801.000000
# 25%       201007.000000       7.000000     753.000000  201007.000000
# 50%       201302.000000      15.000000    1452.000000  201302.000000
# 75%       201601.000000      23.000000    1802.000000  201601.000000
# max       201811.000000      31.000000    2359.000000  201811.000000
#
#               END_DAY       END_TIME     EPISODE_ID       EVENT_ID   STATE  \
# count   683982.000000  683982.000000  683982.000000  683982.000000  683982
# unique            NaN            NaN            NaN            NaN      68
# top               NaN            NaN            NaN            NaN   TEXAS
# freq              NaN            NaN            NaN            NaN   47599
# mean        16.625633    1465.462794   72095.015774  432003.999851     NaN
# std          9.207156     612.990317   34440.257262  208244.474812     NaN
# min          1.000000       0.000000   11748.000000   64592.000000     NaN
# 25%          9.000000    1100.000000   42904.000000  251659.250000     NaN
# 50%         17.000000    1600.000000   71618.000000  432052.500000     NaN
# 75%         25.000000    1900.000000  102405.000000  612699.750000     NaN
# max         31.000000    2359.000000  133235.000000  797027.000000     NaN
#
#            STATE_FIPS           YEAR MONTH_NAME         EVENT_TYPE CZ_TYPE  \
# count   683982.000000  683982.000000     683982             683982  683982
# unique            NaN            NaN         12                 56       3
# top               NaN            NaN       June  Thunderstorm Wind       C
# freq              NaN            NaN     104721             172886  412313
# mean        32.312742    2012.807284        NaN                NaN     NaN
# std         18.154240       3.151748        NaN                NaN     NaN
# min          1.000000    2008.000000        NaN                NaN     NaN
# 25%         19.000000    2010.000000        NaN                NaN     NaN
# 50%         31.000000    2013.000000        NaN                NaN     NaN
# 75%         46.000000    2016.000000        NaN                NaN     NaN
# max         99.000000    2018.000000        NaN                NaN     NaN
#
#               CZ_FIPS     CZ_NAME     WFO     BEGIN_DATE_TIME CZ_TIMEZONE  \
# count   683982.000000      683982  683982              683982      683982
# unique            NaN        4181     123              354343           9
# top               NaN  WASHINGTON     LWX  01-JUL-12 00:00:00       CST-6
# freq              NaN        5422   23416                1163      324875
# mean        98.374020         NaN     NaN                 NaN         NaN
# std        122.789436         NaN     NaN                 NaN         NaN
# min          1.000000         NaN     NaN                 NaN         NaN
# 25%         25.000000         NaN     NaN                 NaN         NaN
# 50%         63.000000         NaN     NaN                 NaN         NaN
# 75%        117.000000         NaN     NaN                 NaN         NaN
# max        876.000000         NaN     NaN                 NaN         NaN
#
#              END_DATE_TIME  INJURIES_DIRECT  INJURIES_INDIRECT  DEATHS_DIRECT  \
# count               683982    683982.000000      683982.000000  683982.000000
# unique              347741              NaN                NaN            NaN
# top     31-JUL-12 23:59:00              NaN                NaN            NaN
# freq                  1107              NaN                NaN            NaN
# mean                   NaN         0.043320           0.016777       0.008594
# std                    NaN         2.577603           3.045148       0.277897
# min                    NaN         0.000000           0.000000       0.000000
# 25%                    NaN         0.000000           0.000000       0.000000
# 50%                    NaN         0.000000           0.000000       0.000000
# 75%                    NaN         0.000000           0.000000       0.000000
# max                    NaN      1150.000000        2400.000000     158.000000
#
#         DEATHS_INDIRECT DAMAGE_PROPERTY DAMAGE_CROPS           SOURCE  \
# count     683982.000000          568908       565471           683982
# unique              NaN            1502          455               44
# top                 NaN           0.00K        0.00K  Trained Spotter
# freq                NaN          404084       551922           125634
# mean           0.003300             NaN          NaN              NaN
# std            0.135616             NaN          NaN              NaN
# min            0.000000             NaN          NaN              NaN
# 25%            0.000000             NaN          NaN              NaN
# 50%            0.000000             NaN          NaN              NaN
# 75%            0.000000             NaN          NaN              NaN
# max           86.000000             NaN          NaN              NaN
#
#             MAGNITUDE MAGNITUDE_TYPE FLOOD_CAUSE    CATEGORY TOR_F_SCALE  \
# count   365516.000000         235847       69724  277.000000       15134
# unique            NaN              4           7         NaN           7
# top               NaN             EG  Heavy Rain         NaN         EF0
# freq              NaN         171868       62904         NaN        7901
# mean        33.951083            NaN         NaN    1.490975         NaN
# std         25.179454            NaN         NaN    1.048165         NaN
# min          0.000000            NaN         NaN    1.000000         NaN
# 25%          1.250000            NaN         NaN    1.000000         NaN
# 50%         50.000000            NaN         NaN    1.000000         NaN
# 75%         52.000000            NaN         NaN    1.000000         NaN
# max        174.000000            NaN         NaN    5.000000         NaN
#
#           TOR_LENGTH     TOR_WIDTH TOR_OTHER_WFO TOR_OTHER_CZ_STATE  \
# count   15134.000000  15134.000000          1903               1903
# unique           NaN           NaN            85                 39
# top              NaN           NaN           JAN                 AL
# freq             NaN           NaN           140                192
# mean        3.067298    182.755379           NaN                NaN
# std         4.246596    287.020573           NaN                NaN
# min         0.010000      1.000000           NaN                NaN
# 25%         0.430000     50.000000           NaN                NaN
# 50%         1.500000     75.000000           NaN                NaN
# 75%         4.000000    200.000000           NaN                NaN
# max        41.880000   4576.000000           NaN                NaN
#
#         TOR_OTHER_CZ_FIPS TOR_OTHER_CZ_NAME    BEGIN_RANGE BEGIN_AZIMUTH  \
# count           1903.0000              1903  433481.000000        433481
# unique                NaN               731            NaN            16
# top                   NaN           MADISON            NaN             N
# freq                  NaN                22            NaN        104554
# mean             103.7299               NaN       2.410599           NaN
# std               83.1857               NaN       4.446881           NaN
# min                1.0000               NaN       0.000000           NaN
# 25%               47.0000               NaN       1.000000           NaN
# 50%               93.0000               NaN       1.000000           NaN
# 75%              139.0000               NaN       3.000000           NaN
# max              810.0000               NaN     185.000000           NaN
#
#        BEGIN_LOCATION      END_RANGE END_AZIMUTH END_LOCATION      BEGIN_LAT  \
# count          433481  433481.000000      433481       433481  433481.000000
# unique          42528            NaN          16        42878            NaN
# top       SPRINGFIELD            NaN           N  SPRINGFIELD            NaN
# freq              483            NaN       96475          465            NaN
# mean              NaN       2.444181         NaN          NaN      37.838124
# std               NaN       4.471382         NaN          NaN       5.022057
# min               NaN       0.000000         NaN          NaN     -14.400000
# 25%               NaN       1.000000         NaN          NaN      34.602600
# 50%               NaN       1.000000         NaN          NaN      38.125300
# 75%               NaN       3.000000         NaN          NaN      41.330700
# max               NaN     185.000000         NaN          NaN      70.502900
#
#             BEGIN_LON        END_LAT        END_LON  \
# count   433481.000000  433481.000000  433481.000000
# unique            NaN            NaN            NaN
# top               NaN            NaN            NaN
# freq              NaN            NaN            NaN
# mean       -90.261514      37.835244     -90.254036
# std         11.126900       5.022675      11.124569
# min       -170.919800     -14.456000    -170.868900
# 25%        -97.140000      34.600000     -97.137700
# 50%        -89.937700      38.123200     -89.920000
# 75%        -81.980000      41.330000     -81.980000
# max        171.366100      70.434200     171.366100
#
#                                         EPISODE_NARRATIVE  \
# count                                              683982
# unique                                             102145
# top     A strong upper-level disturbance passed throug...
# freq                                                  294
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                              EVENT_NARRATIVE DATA_SOURCE BEGIN_YEAR  \
# count                                 492890      683982     683982
# unique                                428398           1         11
# top     Wind gusts were estimated at 60 mph.         CSV       2011
# freq                                     684      683982      79091
# mean                                     NaN         NaN        NaN
# std                                      NaN         NaN        NaN
# min                                      NaN         NaN        NaN
# 25%                                      NaN         NaN        NaN
# 50%                                      NaN         NaN        NaN
# 75%                                      NaN         NaN        NaN
# max                                      NaN         NaN        NaN
#
#        BEGIN_MONTH END_YEAR END_MONTH               BEGIN                  END
# count       683982   683982    683982              683982               683982
# unique          12       11        12              354343               347741
# top             06     2011        06  2012-07-1 00:00:00  2012-07-31 23:59:00
# freq        104721    79091    104721                1163                 1107
# mean           NaN      NaN       NaN                 NaN                  NaN
# std            NaN      NaN       NaN                 NaN                  NaN
# min            NaN      NaN       NaN                 NaN                  NaN
# 25%            NaN      NaN       NaN                 NaN                  NaN
# 50%            NaN      NaN       NaN                 NaN                  NaN
# 75%            NaN      NaN       NaN                 NaN                  NaN
# max            NaN      NaN       NaN                 NaN                  NaN

# %% [markdown]
# Upstream analysis suggets that several fields do not have sufficient information to perform data analysis upon. The following code block determines which do not meet a predefined threshold of missing values before recommending dropping.

# %%
row_count = len(data.index)

threshold = 0.5

analysis = pd.DataFrame(columns=['Field','Missing','Reccomendation'])

for a in desc.columns.values:
    missing = 1 - desc[a]['count'] / row_count
    rec = 'Keep'
    if missing > threshold:
        rec = 'Drop'
    
    analysis = analysis.append({'Field': a,'Missing': missing,'Reccomendation':rec},ignore_index=True)
    
            
analysis
# Out:
#                  Field   Missing Reccomendation
# 0      BEGIN_YEARMONTH  0.000000           Keep
# 1            BEGIN_DAY  0.000000           Keep
# 2           BEGIN_TIME  0.000000           Keep
# 3        END_YEARMONTH  0.000000           Keep
# 4              END_DAY  0.000000           Keep
# 5             END_TIME  0.000000           Keep
# 6           EPISODE_ID  0.000000           Keep
# 7             EVENT_ID  0.000000           Keep
# 8                STATE  0.000000           Keep
# 9           STATE_FIPS  0.000000           Keep
# 10                YEAR  0.000000           Keep
# 11          MONTH_NAME  0.000000           Keep
# 12          EVENT_TYPE  0.000000           Keep
# 13             CZ_TYPE  0.000000           Keep
# 14             CZ_FIPS  0.000000           Keep
# 15             CZ_NAME  0.000000           Keep
# 16                 WFO  0.000000           Keep
# 17     BEGIN_DATE_TIME  0.000000           Keep
# 18         CZ_TIMEZONE  0.000000           Keep
# 19       END_DATE_TIME  0.000000           Keep
# 20     INJURIES_DIRECT  0.000000           Keep
# 21   INJURIES_INDIRECT  0.000000           Keep
# 22       DEATHS_DIRECT  0.000000           Keep
# 23     DEATHS_INDIRECT  0.000000           Keep
# 24     DAMAGE_PROPERTY  0.168241           Keep
# 25        DAMAGE_CROPS  0.173266           Keep
# 26              SOURCE  0.000000           Keep
# 27           MAGNITUDE  0.465606           Keep
# 28      MAGNITUDE_TYPE  0.655185           Drop
# 29         FLOOD_CAUSE  0.898062           Drop
# 30            CATEGORY  0.999595           Drop
# 31         TOR_F_SCALE  0.977874           Drop
# 32          TOR_LENGTH  0.977874           Drop
# 33           TOR_WIDTH  0.977874           Drop
# 34       TOR_OTHER_WFO  0.997218           Drop
# 35  TOR_OTHER_CZ_STATE  0.997218           Drop
# 36   TOR_OTHER_CZ_FIPS  0.997218           Drop
# 37   TOR_OTHER_CZ_NAME  0.997218           Drop
# 38         BEGIN_RANGE  0.366239           Keep
# 39       BEGIN_AZIMUTH  0.366239           Keep
# 40      BEGIN_LOCATION  0.366239           Keep
# 41           END_RANGE  0.366239           Keep
# 42         END_AZIMUTH  0.366239           Keep
# 43        END_LOCATION  0.366239           Keep
# 44           BEGIN_LAT  0.366239           Keep
# 45           BEGIN_LON  0.366239           Keep
# 46             END_LAT  0.366239           Keep
# 47             END_LON  0.366239           Keep
# 48   EPISODE_NARRATIVE  0.000000           Keep
# 49     EVENT_NARRATIVE  0.279382           Keep
# 50         DATA_SOURCE  0.000000           Keep
# 51          BEGIN_YEAR  0.000000           Keep
# 52         BEGIN_MONTH  0.000000           Keep
# 53            END_YEAR  0.000000           Keep
# 54           END_MONTH  0.000000           Keep
# 55               BEGIN  0.000000           Keep
# 56                 END  0.000000           Keep

# %% [markdown]
# ## Narrow and Flatten Data

# %%
#drops
drop_list = ["BEGIN_YEARMONTH",
             "END_YEARMONTH",
             "EPISODE_ID",
             "EVENT_ID",
             "STATE_FIPS",
             "BEGIN_DAY",
             "BEGIN_TIME",
             "END_DAY",
             "END_TIME",
             "CATEGORY",
             "CZ_TYPE",
             "CZ_FIPS",             
             "CZ_NAME",
             "TOR_OTHER_WFO",
             "TOR_OTHER_CZ_NAME",
             "TOR_OTHER_CZ_STATE",
             "TOR_OTHER_CZ_FIPS",
             "WFO",
             "END_DATE_TIME",
             "CZ_TIMEZONE",
             "BEGIN_RANGE",
             "BEGIN_AZIMUTH",
             "BEGIN_YEAR",            
             "BEGIN_MONTH",
             "END_YEAR",
             "END_MONTH",
             "BEGIN",
             "END"            
            ]

data_narrow = data.drop(drop_list, axis = 1)


#remove the row if no location information is provided
#note this removes 250501 rows, reducing our dataset by 37%
data_flat = data_narrow.copy()

#print(data_flat.head())

#print(pd.notnull(data['BEGIN_LOCATION']).head())

#data_flat = data_flat[pd.notnull(data_flat['BEGIN_LOCATION'])]
#data_flat = data_flat[pd.notnull(data_flat['END_LOCATION'])]

# %% [markdown]
# ## Read in More Data

# %%
cat_map = pd.read_csv('data_other/analyst_defined_weather_category_map.csv')
cat_map.head(20)
# Out:
#    Weather Category                Event Type
# 0              Wind         Thunderstorm Wind
# 1              Wind                 High Wind
# 2              Wind  Marine Thunderstorm Wind
# 3              Wind          Marine High Wind
# 4              Wind               Strong Wind
# 5              Wind        Marine Strong Wind
# 6    Winter Weather            Winter Weather
# 7    Winter Weather              Winter Storm
# 8    Winter Weather                Heavy Snow
# 9    Winter Weather                  Blizzard
# 10   Winter Weather              Frost/Freeze
# 11   Winter Weather                 Ice Storm
# 12   Winter Weather                     Sleet
# 13   Winter Weather          Lake-Effect Snow
# 14             Rain                Heavy Rain
# 15             Hail                      Hail
# 16             Hail               Marine Hail
# 17            Flood               Flash Flood
# 18            Flood                     Flood
# 19            Flood             Coastal Flood

# %%
# Merge data together
data_mapped = data_flat.merge(cat_map,how="left",left_on='EVENT_TYPE',right_on='Event Type')

# %% [markdown]
# ## Analyize property Damage properties

# %%
print(0.01*data['DAMAGE_PROPERTY'].max())
data_cut = data.loc[(data['DAMAGE_PROPERTY'] > 1) & (data['DAMAGE_PROPERTY'] < 50000)]
#data_cut = data.loc[(data['DAMAGE_PROPERTY'] > 1) & (data['DAMAGE_PROPERTY'] < 25000)]
data_cut['DAMAGE_PROPERTY'].plot.hist()
#data_mapped.groupby('Weather Category').count()['Event Type']
# Out:
# 170000000.0

# %% [markdown]
# ## Engineer Extra Data Points

# %%
# --------------------- FEATURE ENGINEERING ---------------------  

#separates hail size / wind speed MAGNITUDE
data_mapped['WIND_SPEED'] = np.where(data_mapped['MAGNITUDE_TYPE'].isin(['MG','EG']), data_mapped['MAGNITUDE'], np.NaN)
data_mapped['HAIL_SIZE'] = np.where(data_mapped['MAGNITUDE_TYPE'].isna(), data_mapped['MAGNITUDE'], np.NaN)

# Create a binary 
data_mapped['DEATH_BINARY'] = (data_mapped['DEATHS_DIRECT'] > 0) | (data_mapped['DEATHS_INDIRECT'] > 0)

#divide the data into 12 distinct groups by event type:
#pd.value_counts(data.EVENT_TYPE)
"""
Wind (COLE):
Winter Weather (ETHAN):
Rain (FREYA):
Hail (RUOCHEN):
Flood (FREYA):
Drought (ETHAN):
Tornado (COLE):
Heat (ETHAN):
Cold (COLE):
Lightning (FREYA):
Wildfire (RUOCHEN)
Tides/Currents (RUOCHEN)
"""

#data.columns
#data.head(50)
# Out:
# '\nWind (COLE):\nWinter Weather (ETHAN):\nRain (FREYA):\nHail (RUOCHEN):\nFlood (FREYA):\nDrought (ETHAN):\nTornado (COLE):\nHeat (ETHAN):\nCold (COLE):\nLightning (FREYA):\nWildfire (RUOCHEN)\nTides/Currents (RUOCHEN)\n'

# %%
data_mapped.columns
# Out:
# Index(['STATE', 'YEAR', 'MONTH_NAME', 'EVENT_TYPE', 'BEGIN_DATE_TIME',
#        'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT',
#        'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'SOURCE',
#        'MAGNITUDE', 'MAGNITUDE_TYPE', 'FLOOD_CAUSE', 'TOR_F_SCALE',
#        'TOR_LENGTH', 'TOR_WIDTH', 'BEGIN_LOCATION', 'END_RANGE', 'END_AZIMUTH',
#        'END_LOCATION', 'BEGIN_LAT', 'BEGIN_LON', 'END_LAT', 'END_LON',
#        'EPISODE_NARRATIVE', 'EVENT_NARRATIVE', 'DATA_SOURCE',
#        'DURATION_seconds', 'Weather Category', 'Event Type', 'WIND_SPEED',
#        'HAIL_SIZE', 'DEATH_BINARY'],
#       dtype='object')

# %% [markdown]
# ## Construct Model

# %%
# WINTER MODEL
event_title = 'death_any'

darwin_train_name = event_title + '_data_train'
darwin_test_name = event_title + '_data_test'
target_name = 'DEATH_BINARY'
darwin_model_name = event_title + '_model'

model_data = data_mapped#.loc[(data_mapped['Weather Category'] == 'Drought')]

# Drop data that we don't want included in the model
model_data = model_data.drop(["INJURIES_DIRECT", 
                            'INJURIES_INDIRECT', 
                            'DEATHS_DIRECT', 
                            'DEATHS_INDIRECT',
                              'DATA_SOURCE', 
                            'DAMAGE_PROPERTY',
                              'DAMAGE_CROPS'
                             ], axis = 1)

# Drap data irrevelent to the Wind Model
model_data = model_data.drop(["Event Type",
                            "Weather Category",
                            "FLOOD_CAUSE", 
                            'TOR_F_SCALE', 
                            'TOR_LENGTH', 
                            'TOR_WIDTH',
                            'HAIL_SIZE'], axis = 1)

# Take out a 500 row subset of test data
sample_size = min(1000, int(0.05*len(model_data.index)))

data_test = model_data.sample( sample_size )
data_train = model_data.drop(data_test.index)

# convert the test data and the main data to a csv
print('Creating CSVs')
data_test.to_csv('temp/'+event_title+'_data_test.csv')
data_train.to_csv('temp/'+event_title+'_data_train.csv')
# Out:
# Creating CSVs

# %%
#s.lookup_dataset()
#s.delete_dataset('winter_data_train')
#s.delete_dataset('winter_data_test')
#s.delete_dataset('wind_data_train')
#s.delete_dataset('wind_data_test')
# Out:
# (True,
#  [{'id': '0a06eb7e-63c3-11e9-9ba2-77a6d4a1ecab',
#    'name': 'winter_model',
#    'type': 'Supervised',
#    'problem_type': None,
#    'updated_at': '2019-04-20T18:26:49.988711',
#    'trained_on': ['winter_data_train'],
#    'generations': 2,
#    'loss': None,
#    'complete': True,
#    'parameters': {'train_time': '00:05',
#     'target': 'DAMAGE_PROPERTY',
#     'recurrent': True,
#     'max_unique_values': 50,
#     'max_int_uniques': 15,
#     'impute': 'ffill',
#     'big_data': False},
#    'description': None,
#    'train_time_seconds': 315,
#    'algorithm': None,
#    'running_job_id': None},
#   {'id': 'f49e0a60-63b3-11e9-8940-97ed3fbe26f4',
#    'name': 'wind_model',
#    'type': 'Supervised',
#    'problem_type': None,
#    'updated_at': '2019-04-20T16:36:44.458492',
#    'trained_on': ['wind_data_train'],
#    'generations': 0,
#    'loss': None,
#    'complete': True,
#    'parameters': {'train_time': '00:02',
#     'target': 'DAMAGE_PROPERTY',
#     'recurrent': True,
#     'max_unique_values': 50,
#     'max_int_uniques': 15,
#     'impute': 'ffill',
#     'big_data': False},
#    'description': None,
#    'train_time_seconds': 188,
#    'algorithm': None,
#    'running_job_id': None}])

# %%
# Upload the train to Darwin
#print('Deleting existing datasets')
print('Uploading to Darwin')


s.upload_dataset('temp/'+event_title+'_data_train.csv', darwin_train_name)
s.upload_dataset('temp/'+event_title+'_data_test.csv',  darwin_test_name)

# Clean the training dataset using Darwin
print('starting Clean')
out = s.clean_data(darwin_train_name, target = target_name)
print(out)

# Cleaning the data
print('Waiting on Cleaning')
print(s.wait_for_job( out[1]['job_name'] ))
# Out:
# Uploading to Darwin
# starting Clean
# (True, {'job_name': 'c9b63836135c4ddfa008eed951ee76aa', 'artifact_name': '8361aa2130234ab3aebf70dc7057026c'})
# Waiting on Cleaning
# {'status': 'Requested', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': None, 'percent_complete': 10, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': None}
# (False, 'Waited for 10.0 minutes. Re-run wait_for_job to wait longer.')

# %%
print(s.wait_for_job('c9b63836135c4ddfa008eed951ee76aa'))
# Out:
# {'status': 'Complete', 'starttime': '2019-04-20T21:42:35.874318', 'endtime': '2019-04-20T21:53:52.072', 'percent_complete': 100, 'job_type': 'CleanData', 'loss': None, 'generations': None, 'dataset_names': ['death_any_data_train'], 'artifact_names': ['8361aa2130234ab3aebf70dc7057026c'], 'model_name': None, 'job_error': ''}
# (True, 'Job completed')

# %%
#s.lookup_dataset_name('winter_data_train')
#s.download_dataset('wind_data_test')
#darwin_model_name = event_title + '_model'

# %%
# Create the model
print('Creating Model')
#print(s.delete_model('winter_model'))
out = s.create_model(dataset_names=darwin_train_name, model_name=darwin_model_name, max_train_time = '00:05')
print(out)
print()

# Waiting for the model
print(s.wait_for_job(out[1]['job_name']))
# Out:
# Creating Model
# (False, '400: BAD REQUEST - {"message": "A model with this name already exists"}\n')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-57c0dc5c3148> in <module>
#       7
#       8 # Waiting for the model
# ----> 9 print(s.wait_for_job(out[1]['job_name']))
#
# TypeError: string indices must be integers

# %%
out = s.clean_data(darwin_test_name, model_name=darwin_model_name)
print(out)
print()

print(s.wait_for_job(out[1]['job_name']))

out = s.run_model(darwin_test_name, darwin_model_name) 
print(s.wait_for_job( out[1]['job_name'] ))

artifact = s.download_artifact( out[1]['artifact_name'])
'''
pred = artifact[1][target_name]
y_col = data_test[target_name]

#print(pred)

xs = []
ys = []
for i in range(500):
    xs.append(y_col.iloc[i])
    ys.append(pred.iloc[i])

accuracy = pd.DataFrame({'Actual':xs,'Predicted':ys})
'''
# Out:
# (False, '500: INTERNAL SERVER ERROR - {"message": "Internal Server Error"}\n')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-7f82a69d83e0> in <module>
#       4 print()
#       5
# ----> 6 print(s.wait_for_job(out[1]['job_name']))
#       7
#       8 out = s.run_model(darwin_test_name, darwin_model_name)
#
# TypeError: string indices must be integers

# %%
 
s.clean_data(darwin_test_name, model_name='death_any_model')
s.lookup_job()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-3f5330ffa28f> in <module>
#       1
#       2 s.clean_data(darwin_test_name, model_name='death_any_model')
# ----> 3 s.lookup_job()
#
# AttributeError: 'DarwinSdk' object has no attribute 'lookup_job'

# %%
accuracy.plot.scatter('Actual','Predicted')
