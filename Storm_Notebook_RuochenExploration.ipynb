# %%
import pandas as pd
import datetime
from datetime import timedelta
import numpy as np

#displays all datasets' columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)


from amb_sdk.sdk import DarwinSdk
s = DarwinSdk()
s.set_url('https://amb-demo-api.sparkcognition.com/v1/')
s.auth_login_user('dustincforsythe@utexas.edu','Rkje65JJyb')
# Out:
# (True,
#  'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJleHAiOjE1NTU3NzY5MzIsImlhdCI6MTU1NTc2OTczMiwibmJmIjoxNTU1NzY5NzMyLCJqdGkiOiI1NTY1ZmM4My0yOTA5LTRkYzMtYjc3NC0zMzljMjM2NmQxOGEiLCJpZGVudGl0eSI6Ijk1MDhlMDQ2LTRmMzgtMTFlOS05ODE5LTQzZDZkODczZTBlNSIsImZyZXNoIjpmYWxzZSwidHlwZSI6ImFjY2VzcyJ9.cPwpCsYveT5733s08SCzOPSzbGblWnU_lvTukB3qiv0')

# %%
#read in the storm datasets
s2008 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2008_c20180718.csv.gz', compression='gzip')
s2009 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2009_c20180718.csv.gz', compression='gzip')
s2010 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2010_c20170726.csv.gz', compression='gzip')
s2011 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2011_c20180718.csv.gz', compression='gzip')
s2012 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2012_c20170519.csv.gz', compression='gzip')
s2013 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2013_c20170519.csv.gz', compression='gzip')
s2014 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2014_c20180718.csv.gz', compression='gzip')
s2015 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2015_c20180525.csv.gz', compression='gzip')
s2016 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2016_c20180718.csv.gz', compression='gzip')
s2017 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2017_c20181219.csv.gz', compression='gzip')
s2018 = pd.read_csv('data_details/StormEvents_details-ftp_v1.0_d2018_c20190220.csv.gz', compression='gzip')


raw = pd.concat([s2008,s2009,s2010,s2011,s2012,s2013,s2014,s2015,s2016,s2017,s2018])
raw.head(10)
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           200802         22        1300         200802       22      2200
# 1           200804          1         352         200804        1       352
# 2           200803          1           0         200803        1      1320
# 3           200801         14         500         200801       14      1700
# 4           200812         19        1353         200812       21       200
# 5           200812         11         412         200812       12       953
# 6           200812         21         744         200812       21      2359
# 7           200802          5        1615         200802        5      1615
# 8           200801          8        1320         200801        8      1320
# 9           200801         28         300         200801       28       500
#
#    EPISODE_ID  EVENT_ID          STATE  STATE_FIPS  YEAR MONTH_NAME  \
# ...

# %%
data = raw.copy()

# --------------------- CLEANING ---------------------
# split and BEGIN_YEARMONTH + END_YEARMONTH columns into 2 columns each --> YEAR + MONTH
begin_year = data['BEGIN_YEARMONTH'].astype(str).str[:4]
begin_month = data['BEGIN_YEARMONTH'].astype(str).str[4:]
data['BEGIN_YEAR'] = begin_year
data['BEGIN_MONTH'] = begin_month
#data.drop(columns=['BEGIN_YEARMONTH'], inplace=True)

end_year = data['END_YEARMONTH'].astype(str).str[:4]
end_month = data['END_YEARMONTH'].astype(str).str[4:]
data['END_YEAR'] = end_year
data['END_MONTH'] = end_month
#data.drop(columns=['END_YEARMONTH'], inplace=True)

# add begin and end dates and times in YYYY-MM-DD HH:MM:SS format
begin = data['BEGIN_YEAR'].map(str) + '-' + data['BEGIN_MONTH'].map(str) + '-' + data['BEGIN_DAY'].map(str) + ' '
hour = data['BEGIN_TIME'].astype(str).str[:-2]
hour = hour.apply(lambda x: '{0:0>2}'.format(x))
minute = data['BEGIN_TIME'].astype(str).str[-2:]
minute = minute.apply(lambda x: '{0:0>2}'.format(x))
time = hour.map(str) + ':' + minute.map(str) + ':00'
data['BEGIN'] = begin+time

end = data['END_YEAR'].map(str) + '-' + data['END_MONTH'].map(str) + '-' + data['END_DAY'].map(str) + ' '
e_hour = data['END_TIME'].astype(str).str[:-2]
e_hour = e_hour.apply(lambda x: '{0:0>2}'.format(x))
e_minute = data['END_TIME'].astype(str).str[-2:]
e_minute = e_minute.apply(lambda x: '{0:0>2}'.format(x))
e_time = e_hour.map(str) + ':' + e_minute.map(str) + ':00'
data['END'] = end+e_time

# add duration column
duration = pd.to_datetime(data['END']) - pd.to_datetime(data['BEGIN'])
                   
data['DURATION_seconds'] = ((duration.dt.total_seconds()))    

#drops
data = data.drop("BEGIN_YEARMONTH", axis = 1)
data = data.drop("END_YEARMONTH", axis = 1)
data = data.drop("EPISODE_ID", axis = 1)
data = data.drop("EVENT_ID", axis = 1)
data = data.drop("STATE_FIPS", axis = 1)
data = data.drop("BEGIN_DAY", axis = 1)
data = data.drop("BEGIN_TIME", axis = 1)
data = data.drop("END_DAY", axis = 1)
data = data.drop("END_TIME", axis = 1)

data = data.drop("CATEGORY", axis = 1)
data = data.drop("CZ_TYPE", axis = 1)
data = data.drop("CZ_FIPS", axis = 1)
data = data.drop("CZ_NAME", axis = 1)
data = data.drop("TOR_OTHER_WFO", axis = 1)
data = data.drop("TOR_OTHER_CZ_NAME", axis = 1)
data = data.drop("TOR_OTHER_CZ_STATE", axis = 1)
data = data.drop("TOR_OTHER_CZ_FIPS", axis = 1)
data = data.drop("DATA_SOURCE", axis = 1)

data = data.drop("WFO",axis = 1)
data = data.drop("END_DATE_TIME",axis = 1)
data = data.drop("CZ_TIMEZONE",axis = 1)
data = data.drop("BEGIN_RANGE",axis = 1)
data = data.drop("END_RANGE",axis = 1)
data = data.drop("BEGIN_AZIMUTH",axis = 1)
data = data.drop("END_AZIMUTH",axis = 1)
data = data.drop("BEGIN_YEAR",axis = 1)
data = data.drop("BEGIN_MONTH",axis = 1)
data = data.drop("END_YEAR",axis = 1)
data = data.drop("END_MONTH",axis = 1)
data = data.drop("BEGIN",axis = 1)
data = data.drop("END",axis = 1)

#change DAMAGE_PROPERTY and DAMAGE_CROPS type from #.##K to float
def convertToFloat(x):
    x = str(x)
    if(x[-1]=='K'):
        return(float(x[0:-1])*1000)
    elif(x[-1]=='M'):
        return(float(x[0:-1])*1000000)
    elif(x[-1]=='B'):
        return(float(x[0:-1])*1000000000)
    else:
        return(0.0)

    
#print(pd.value_counts(data.DAMAGE_PROPERTY))
#print(pd.value_counts(data.DAMAGE_CROPS))
data['DAMAGE_PROPERTY'].fillna(0.0, inplace=True)
data['DAMAGE_PROPERTY'] = data['DAMAGE_PROPERTY'].apply(convertToFloat)

data['DAMAGE_CROPS'].fillna(0.0, inplace=True)
data['DAMAGE_CROPS'] = data['DAMAGE_CROPS'].apply(convertToFloat)


#remove the row if no location information is provided
#note this removes 250501 rows, reducing our dataset by 37%
data = data[pd.notnull(data['BEGIN_LOCATION'])]
data = data[pd.notnull(data['END_LOCATION'])]

# --------------------- FEATURE ENGINEERING ---------------------
#separates hail size / wind speed MAGNITUDE
data['WIND_SPEED'] = np.where(data['MAGNITUDE_TYPE'].isin(['MG','EG']), data['MAGNITUDE'], np.NaN)
data['HAIL_SIZE'] = np.where(data['MAGNITUDE_TYPE'].isna(), data['MAGNITUDE'], np.NaN)

#divide the data into 12 distinct groups by event type:
pd.value_counts(data.EVENT_TYPE)
"""
Wind (COLE):
    Thunderstorm Wind
    High Wind
    Marine Thunderstorm Wind
    Marine High Wind
    Strong Wind
    Marine Strong Wind

Winter Weather (ETHAN):
    Winter Weather
    Winter Storm
    Heavy Snow
    Blizzard
    Frost/Freeze
    Ice Storm
    Sleet
    Lake-Effect Snow

Rain (FREYA):
    Heavy Rain

Hail (RUOCHEN):
    Hail
    Marine Hail

Flood (FREYA):
    Flash Flood
    Flood
    Coastal Flood
    Lakeshore Flood

Drought (ETHAN):
    Drought

Tornado (COLE):
    Tornado

Heat (ETHAN):
    Heat
    Excessive Heat

Cold (COLE):
    Cold/Wind Chill
    Extreme Cold/Wind Chill

Lightning (FREYA):
    Lightning

Wildfire (RUOCHEN):
    Wildfire

Tides/Currents (RUOCHEN):
    High Surf
    Rip Current
    Astronomical Low Tide
    Storm Surge/Tide
"""
data.columns
data.head(50)
# Out:
#               STATE  YEAR MONTH_NAME                EVENT_TYPE  \
# 7          ARKANSAS  2008   February                      Hail
# 8          ARKANSAS  2008    January         Thunderstorm Wind
# 9           ARIZONA  2008    January                     Flood
# 11         ILLINOIS  2008   December         Thunderstorm Wind
# 12    LAKE MICHIGAN  2008   December  Marine Thunderstorm Wind
# 13          INDIANA  2008   December         Thunderstorm Wind
# 27   SOUTH CAROLINA  2008      March         Thunderstorm Wind
# 28   SOUTH CAROLINA  2008      March         Thunderstorm Wind
# 29   SOUTH CAROLINA  2008        May                      Hail
# 30   SOUTH CAROLINA  2008        May                      Hail
# 31          GEORGIA  2008        May                      Hail
# 32          GEORGIA  2008        May                      Hail
# 33   SOUTH CAROLINA  2008        May                      Hail
# 34   SOUTH CAROLINA  2008        May         Thunderstorm Wind
# ...

# %%
# WIND MODEL
wind_data = data.copy()
wind_data = wind_data.loc[(wind_data['EVENT_TYPE'] == 'Thunderstorm Wind') | (wind_data['EVENT_TYPE'] == 'High Wind')
                         | (wind_data['EVENT_TYPE'] == 'Marine Thunderstorm Wind') | (wind_data['EVENT_TYPE'] == 'Marine High Wind')
                         | (wind_data['EVENT_TYPE'] == 'Strong Wind') | (wind_data['EVENT_TYPE'] == 'Marine Strong Wind')]

# Drop data that we don't want included in the model
wind_data = wind_data.drop(["INJURIES_DIRECT", 'INJURIES_INDIRECT', 'DEATHS_DIRECT', 'DEATHS_INDIRECT', 'DAMAGE_CROPS'], axis = 1)

# Drap data irrevelent to the Wind Model
wind_data = wind_data.drop(["FLOOD_CAUSE", 'TOR_F_SCALE', 'TOR_LENGTH', 'TOR_WIDTH','HAIL_SIZE'], axis = 1)
wind_data.head(50)

# Take out a 500 row subset of test data
wind_data_test=wind_data.sample(500)
wind_data_train=wind_data.drop(wind_data_test.index)

# convert the test data and the main data to a csv
#wind_csv = wind_data_train.to_csv(r'C:\Users\df201\CS329E_DataAnalytics\storm_analytics\wind_data_train.csv')
#wind_test_csv = wind_data_test.to_csv(r'C:\Users\df201\CS329E_DataAnalytics\storm_analytics\wind_data_test.csv')

# Upload the train to Darwin
# s.upload_dataset('wind_data_train.csv', 'wind_data_train')
# s.upload_dataset('wind_data_test.csv', 'wind_data_test')
s.upload_dataset('wind_data_train')
s.upload_dataset('wind_data_test')


# Clean the training dataset using Darwin
s.clean_data('wind_data_train',target = 'DAMAGE_PROPERTY')
# Out:
# (True,
#  {'job_name': '8ca60d6809da4ee68abd376c087df350',
#   'artifact_name': '83285b72690e4fcc9a3063c5606f74dc'})

# %%
s.wait_for_job('8daf0ed580674eba930c5525e7997e85')
# Out:
# {'status': 'Complete', 'starttime': '2019-04-18T22:51:13.631904', 'endtime': '2019-04-18T22:52:55.405554', 'percent_complete': 100, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['wind_data_train'], 'artifact_names': ['ddbc5b601bd94ae3b195fe3eb1876c56'], 'model_name': None, 'job_error': ''}
# (True, 'Job completed')

# %%
# Create the model
s.create_model(dataset_names='wind_data_train', model_name='wind_model', max_train_time = '00:02')
# Out:
# (False,
#  '400: BAD REQUEST - {"message": "A model with this name already exists"}\n')

# %%
s.wait_for_job('adcfdbe2dad944c3a4592c5438747e1e')
# Out:
# {'status': 'Complete', 'starttime': '2019-04-18T22:55:37.120549', 'endtime': '2019-04-18T22:58:12.643879', 'percent_complete': 100, 'job_type': 'TrainModel', 'loss': None, 'generations': 0, 'dataset_names': ['wind_data_train'], 'artifact_names': None, 'model_name': 'wind_model', 'job_error': ''}
# (True, 'Job completed')

# %%
s.lookup_model()
# Out:
# (True,
#  [{'id': 'fd7ee586-6256-11e9-8dd8-6b7969a1c67f',
#    'name': 'wind_model',
#    'type': 'Supervised',
#    'problem_type': None,
#    'updated_at': '2019-04-18T22:58:12.625717',
#    'trained_on': ['wind_data_train'],
#    'generations': 0,
#    'loss': None,
#    'complete': True,
#    'parameters': {'train_time': '00:02',
#     'target': 'DAMAGE_PROPERTY',
#     'recurrent': True,
#     'max_unique_values': 50,
#     'max_int_uniques': 15,
#     'impute': 'ffill',
#     'big_data': False},
#    'description': None,
#    'train_time_seconds': 156,
#    'algorithm': None,
#    'running_job_id': None}])

# %%
s.clean_data('wind_data_test',target = 'DAMAGE_PROPERTY', model_name = 'wind_model')
# Out:
# (True,
#  {'job_name': '3346e63633e740b8acee57f53002763f',
#   'artifact_name': '92f3f28889914bedbf19ef545c0521d2'})

# %%
s.wait_for_job('6525cafd11144f468c9704dd507a5356')
# Out:
# {'status': 'Complete', 'starttime': '2019-04-18T23:01:59.277232', 'endtime': '2019-04-18T23:02:09.560079', 'percent_complete': 100, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['wind_data_test'], 'artifact_names': ['9f102d4dd07e4f1e9756a8e405e75d3d'], 'model_name': None, 'job_error': ''}
# (True, 'Job completed')

# %%
s.analyze_data('wind_data_train')
# Out:
# (True,
#  {'job_name': '8c526977b18d4c9288785c9b8918054f',
#   'artifact_name': 'ebedcafd7d8c4109a4adec3b9c3568ff'})

# %%
s.wait_for_job('6d8142cf768b469cb7e1b0a5863bcb19')
# Out:
# {'status': 'Complete', 'starttime': '2019-04-18T23:23:21.927189', 'endtime': '2019-04-18T23:24:10.792', 'percent_complete': 100, 'job_type': 'AnalyzeData', 'loss': None, 'generations': None, 'dataset_names': ['wind_data_train'], 'artifact_names': ['6cc5f21d1ae74f5fb14d8882de328571'], 'model_name': None, 'job_error': ''}
# (True, 'Job completed')

# %%
s.download_artifact('6cc5f21d1ae74f5fb14d8882de328571')
# Out:
# (True,
#               col_name num_uniques                mean              stddev  \
#  0                 _c0       65180   33138.64087279627  18932.430807682882
#  1               STATE          62                None                None
#  2                YEAR          11    2012.96169394155  3.1534716020047897
#  3          MONTH_NAME          11                None                None
#  4          EVENT_TYPE           4                None                None
#  5     BEGIN_DATE_TIME      150425                None                None
#  6     DAMAGE_PROPERTY         333  27335.983924947956  2592689.1756618125
#  7              SOURCE          43                None                None
#  8           MAGNITUDE          94    52.5577621419348   7.416288993579045
#  9      MAGNITUDE_TYPE           4                None                None
#  10     BEGIN_LOCATION       33207                None                None
# ...

# %%
s.analyze_model('wind_model')
# Out:
# (True,
#  {'job_name': '059e5682ec4746669408c2c5ac2b3f69',
#   'artifact_name': 'ca0819baac3449bfbd3e0233fbcf9f34'})

# %%
s.wait_for_job('258ec7c1141347b6840653330e001f08')
# Out:
# {'status': 'Complete', 'starttime': '2019-04-18T23:27:10.249596', 'endtime': '2019-04-18T23:27:50.230493', 'percent_complete': 100, 'job_type': 'AnalyzeModel', 'loss': None, 'generations': 0, 'dataset_names': None, 'artifact_names': ['e87787d97ba74e71a2d3ecba4c0566eb'], 'model_name': 'wind_model', 'job_error': ''}
# (True, 'Job completed')

# %%
from time import sleep 
from sklearn.metrics import classification_report
s.download_artifact('e87787d97ba74e71a2d3ecba4c0566eb')


status, artifact = s.analyze_model('wind_model')
sleep(1)
s.wait_for_job(artifact['job_name'])
target='DAMAGE_PROPERTY'

status, prediction = s.download_artifact(artifact['artifact_name'])
print(prediction.head())

# unq = prediction[target].unique()[::-1]
# p = np.zeros((len(prediction),))
# a = np.zeros((len(prediction),))
# for i,q in enumerate(unq):
#     p += i*(prediction[target] == q).values
#     a += i*(wind_train[target] == q).values
    
# # plot predictions vs actual
# plt.plot(a)
# plt.plot(p)
# plt.legend(['Actual','Predicted'])
# plt.yticks([i for i in range(len(unq))],[q for q in unq]);

print(classification_report(wind_data_train[target], prediction[target]))
# Out:
# {'status': 'Running', 'starttime': '2019-04-20T14:42:37.423628', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzeModel', 'loss': None, 'generations': 0, 'dataset_names': None, 'artifact_names': ['703db06dc55a4c9195aef7e78aa179ee'], 'model_name': 'wind_model', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-20T14:42:37.423628', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzeModel', 'loss': None, 'generations': 0, 'dataset_names': None, 'artifact_names': ['703db06dc55a4c9195aef7e78aa179ee'], 'model_name': 'wind_model', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-20T14:42:37.423628', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzeModel', 'loss': None, 'generations': 0, 'dataset_names': None, 'artifact_names': ['703db06dc55a4c9195aef7e78aa179ee'], 'model_name': 'wind_model', 'job_error': ''}
# ...

# %%
# the above model didn't use the text fields at all, which hold a lot of information
# try to us a bag-of-words model

import string, re
unique_word_counts = {}
# list of common words from https://gist.github.com/sebleier/554280
stop_words = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

# function to retrieve the unique words and the frequency of them from the text fields
def get_unique_count(x):
    words = str(x)
    words = words.lower()
    translator=str.maketrans('','',string.punctuation)
    words=words.translate(translator)
    words = words.split()
    
    for word in words:
        if(word in unique_word_counts):
            unique_word_counts[word] += 1
        elif(word not in stop_words) :
            unique_word_counts[word] = 1

wind_data['EPISODE_NARRATIVE'].apply(get_unique_count)
wind_data['EVENT_NARRATIVE'].apply(get_unique_count)

# disregard words that appear less than 500 times
dict2 = unique_word_counts.copy()
for word, frequency in dict2.items():
    if frequency < 500:
        del unique_word_counts[word]

# sort the words in descending order and show them
sorted_words = sorted(unique_word_counts.items(), key=lambda kv: kv[1], reverse=True)
print(len(sorted_words))
print((sorted_words))
# Out:
# 1667
# ...

# %%
# add a column for every unique word
wind_words_data = wind_data[['DAMAGE_PROPERTY','EPISODE_NARRATIVE','EVENT_NARRATIVE']].copy()
for word in sorted_words:
    wind_words_data[word[0]] = 0
wind_words_data.head(10)

# %%
# this code is very inefficient and does not work properly
# needs to be improved
wind_words_data

columns = list(wind_words_data)

for row in wind_words_data.index:
    words = str(wind_words_data.get_value(row, 'EPISODE_NARRATIVE')) + ' ' + str(wind_words_data.get_value(row, 'EVENT_NARRATIVE'))
    words = words.lower()
    translator=str.maketrans('','',string.punctuation)
    words=words.translate(translator)
    words = words.split()
    
    for word in words:
        if word in columns:
            wind_words_data.set_value(row, word, wind_words_data.get_value(row, word)+1)

wind_words_data.head(10)
